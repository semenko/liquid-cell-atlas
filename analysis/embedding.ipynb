# %% [markdown]
# # Liquid Cell Atlas — Embedding Exploration
# **By Nick Semenkovich \<semenko@alum.mit.edu\>**
#
# The goal here is to try storing all CpG sites in a single embedding space (or as a COO sparse tensor) and
# train a model to deconvolute the methylation profiles of the different cell types.

# %%
import gc
import os
import random
import sys
import json
import time

# %%
import socket
print(f"Running on: {socket.gethostname()}")
print(f"Python version: {sys.version}")

# Require Python 3.11, welcome to the future! :P
if sys.version_info < (3, 11):
    raise RuntimeError("Python 3.11 or greater is required")

# Parallel multithreading limit
NUM_USABLE_CPUS = len(os.sched_getaffinity(0))
print(f"Usable CPUs: {NUM_USABLE_CPUS}")
# Out:
# Running on: acln3
# Python version: 3.11.0 | packaged by conda-forge | (main, Jan 14 2023, 12:27:40) [GCC 11.3.0]
# Usable CPUs: 40

# %%
# External libraries
import matplotlib.pyplot as plt
import numpy as np
# import polars as pl # Pandas but good
import pandas as pd
from scipy.sparse import coo_matrix
# import pybedtools # Blocking Py3.11, using Pandas instead (lol)
# import sklearn.metrics
# import sklearn.model_selection
#import tensorflow as tf
import torch
import torchmetrics
# import tensorflow_decision_forests as tfdf
import zarr

import pysam

import altair as alt
alt.renderers.enable('default')

# We use SeqIO to parse the reference .fa file
from Bio import SeqIO

from tqdm.notebook import tqdm

#import plotly.io as pio
#import plotly.graph_objects as go
#pio.renderers.default = 'colab'

if "google.colab" in sys.modules:
    from google.colab import data_table
    print("Loading pretty datatable formatter.")
    data_table.enable_dataframe_formatter()

# %%
# PyTorch version
print(f"PyTorch version: {torch.__version__}")
print(f"PySam version: {pysam.__version__}")

# Tensorflow Decision Forests version
# print(f"Tensorflow Decision Forests version: {tfdf.__version__}")

# Require PyTorch 2.0, welcome to the future! :P
if torch.__version__ < "2.0":
    raise RuntimeError("PyTorch 2.0 or greater is required")

# Set random seeds
RUN_SEED = 42
random.seed(RUN_SEED)
np.random.seed(RUN_SEED)
torch.manual_seed(RUN_SEED)
# Out:
# PyTorch version: 2.0.0
# PySam version: 0.20.0

# %%
# Run Settings
CHROMOSOMES = ["chr" + str(i) for i in range(1, 23)] + ["chrX", "chrY"]

# For development, forcably re-run parsing even if a cache exists
IGNORE_CACHE = True

# %%
# First, we need to see how many CpG sites exist in our genomic annotation.
# We do this flexibly by loading our reference .fa file and counting the number of CpG sites
# We'll later use this to define our embedding size.

# Path to reference .fa file
REFERENCE_FA = "/r5n/liquid-cell-atlas/reference/GRCh38-DAC-U2AF1.fna"


# TODO: Improve caching here, store hash/metadata, read size, etc.

# Maximum read size (our window for padding)
# TODO: Shrink this a little to account for trimming?
READ_SIZE = 150

CACHE_AVAILABLE = os.path.exists("cpg_sites_dict.json") and os.path.exists("chr_lengths.json") and not IGNORE_CACHE

if CACHE_AVAILABLE:
    print("Loading cpg_sites_dict.json from disk")
    with open("cpg_sites_dict.json", "r") as f:
        cpg_sites_dict = json.load(f)
    with open("chr_lengths.json", "r") as f:
        chr_lengths = json.load(f)

    print("Loading cpg_sites_dict.zarr from disk")
    # TODO: Implement -- currentl loads as a zarr Array format, not a dict
    # zarr_cpg_sites_dict = zarr.open("cpg_sites_dict.zarr", mode="r")
    # cpg_sites_dict = {}
    # for k in zarr_cpg_sites_dict:
    #    cpg_sites_dict[k] = zarr_cpg_sites_dict[k]
    #zarr_chr_lengths = zarr.open("chr_lengths.zarr", mode="r")
    #chr_lengths = {}
    #for k in zarr_chr_lengths:
    #    chr_lengths[k] = zarr_chr_lengths[k]
else:
    print("Cache not available, parsing reference .fa file")
    print(f"Loading reference .fa file: {REFERENCE_FA}")

    # We want a list of all CpG sites in the reference genome, including the chromosome and position
    # We'll use this to define our embedding size
    # Each chromosome is identified with a line starting with ">" followed by the chromosome name

    # Store the CpG sites in a dict per chromosome
    cpg_sites_dict = {}
    chr_lengths = {}

    # Iterate over sequences
    for seqrecord in tqdm(SeqIO.parse(REFERENCE_FA, "fasta"), total=len(CHROMOSOMES)):
        if seqrecord.id not in CHROMOSOMES:
            tqdm.write(f"\tSkipping chromosome {seqrecord.id}")
            continue
        # The sequence
        sequence = seqrecord.seq

        # Find all CpG sites
        # The i+1 is because we want to store the 1-based position, because .bed is wild and arguably 1-based maybe:
        # e.g. https://genome-blog.soe.ucsc.edu/blog/2016/12/12/the-ucsc-genome-browser-coordinate-counting-systems/
        # Regardless, $ samtools faidx GRCh38-DAC-U2AF1.fna chr1:0-0 throws an error, while
        # $ samtools faidx GRCh38-DAC-U2AF1.fna chr1:1-1 returns the correct base.
        # cpg_sites_dict[seqrecord.id] = [i+1 for i in range(len(sequence)-1) if sequence[i:i+2]=="CG"]

        cpg_indices = []
        search_str = "CG"
        pos = sequence.find(search_str)

        while pos != -1:
            cpg_indices.append(pos + 1)
            pos = sequence.find(search_str, pos + 1)

        cpg_sites_dict[seqrecord.id] = cpg_indices
        chr_lengths[seqrecord.id] = len(sequence)

    # Save the cpg_sites_dict and chr_lengths to disk as a json
    # TODO: Store this more efficiently as an array using zarr?
    print(f"Saving cpg_sites_dict and chr_lengths to disk as json")
    with open("cpg_sites_dict.json", "w") as f:
        json.dump(cpg_sites_dict, f)
    with open("chr_lengths.json", "w") as f:
        json.dump(chr_lengths, f)

    # TODO: Clean up this trash
    # we need to specify object_codec to store the dict
    zarr_cpg_sites_dict = zarr.open("cpg_sites_dict.zarr", mode="w")
    for k, v in cpg_sites_dict.items():
        zarr_cpg_sites_dict[k] = v
    # Lame. Shove these into one df...
    zarr_chr_lengths = zarr.open("chr_lengths.zarr", mode="w")
    for k, v in chr_lengths.items():
        zarr_chr_lengths[k] = v
# Out:
# Cache not available, parsing reference .fa file
# Loading reference .fa file: /r5n/liquid-cell-atlas/reference/GRCh38-DAC-U2AF1.fna
#   0%|          | 0/24 [00:00<?, ?it/s]
# 	Skipping chromosome chrM
# 	Skipping chromosome chr1_KI270706v1_random
# 	Skipping chromosome chr1_KI270707v1_random
# 	Skipping chromosome chr1_KI270708v1_random
# 	Skipping chromosome chr1_KI270709v1_random
# 	Skipping chromosome chr1_KI270710v1_random
# 	Skipping chromosome chr1_KI270711v1_random
# 	Skipping chromosome chr1_KI270712v1_random
# 	Skipping chromosome chr1_KI270713v1_random
# 	Skipping chromosome chr1_KI270714v1_random
# 	Skipping chromosome chr2_KI270715v1_random
# 	Skipping chromosome chr2_KI270716v1_random
# 	Skipping chromosome chr3_GL000221v1_random
# 	Skipping chromosome chr4_GL000008v2_random
# 	Skipping chromosome chr5_GL000208v1_random
# 	Skipping chromosome chr9_KI270717v1_random
# 	Skipping chromosome chr9_KI270718v1_random
# 	Skipping chromosome chr9_KI270719v1_random
# 	Skipping chromosome chr9_KI270720v1_random
# 	Skipping chromosome chr11_KI270721v1_random
# 	Skipping chromosome chr14_GL000009v2_random
# 	Skipping chromosome chr14_GL000225v1_random
# 	Skipping chromosome chr14_KI270722v1_random
# 	Skipping chromosome chr14_GL000194v1_random
# 	Skipping chromosome chr14_KI270723v1_random
# 	Skipping chromosome chr14_KI270724v1_random
# 	Skipping chromosome chr14_KI270725v1_random
# 	Skipping chromosome chr14_KI270726v1_random
# 	Skipping chromosome chr15_KI270727v1_random
# 	Skipping chromosome chr16_KI270728v1_random
# 	Skipping chromosome chr17_GL000205v2_random
# 	Skipping chromosome chr17_KI270729v1_random
# 	Skipping chromosome chr17_KI270730v1_random
# 	Skipping chromosome chr22_KI270731v1_random
# 	Skipping chromosome chr22_KI270732v1_random
# 	Skipping chromosome chr22_KI270733v1_random
# 	Skipping chromosome chr22_KI270734v1_random
# 	Skipping chromosome chr22_KI270735v1_random
# 	Skipping chromosome chr22_KI270736v1_random
# 	Skipping chromosome chr22_KI270737v1_random
# 	Skipping chromosome chr22_KI270738v1_random
# 	Skipping chromosome chr22_KI270739v1_random
# 	Skipping chromosome chrY_KI270740v1_random
# 	Skipping chromosome chrUn_KI270302v1
# 	Skipping chromosome chrUn_KI270304v1
# 	Skipping chromosome chrUn_KI270303v1
# 	Skipping chromosome chrUn_KI270305v1
# 	Skipping chromosome chrUn_KI270322v1
# 	Skipping chromosome chrUn_KI270320v1
# 	Skipping chromosome chrUn_KI270310v1
# 	Skipping chromosome chrUn_KI270316v1
# 	Skipping chromosome chrUn_KI270315v1
# 	Skipping chromosome chrUn_KI270312v1
# 	Skipping chromosome chrUn_KI270311v1
# 	Skipping chromosome chrUn_KI270317v1
# 	Skipping chromosome chrUn_KI270412v1
# 	Skipping chromosome chrUn_KI270411v1
# 	Skipping chromosome chrUn_KI270414v1
# 	Skipping chromosome chrUn_KI270419v1
# 	Skipping chromosome chrUn_KI270418v1
# 	Skipping chromosome chrUn_KI270420v1
# 	Skipping chromosome chrUn_KI270424v1
# 	Skipping chromosome chrUn_KI270417v1
# 	Skipping chromosome chrUn_KI270422v1
# 	Skipping chromosome chrUn_KI270423v1
# 	Skipping chromosome chrUn_KI270425v1
# 	Skipping chromosome chrUn_KI270429v1
# 	Skipping chromosome chrUn_KI270442v1
# 	Skipping chromosome chrUn_KI270466v1
# 	Skipping chromosome chrUn_KI270465v1
# 	Skipping chromosome chrUn_KI270467v1
# 	Skipping chromosome chrUn_KI270435v1
# 	Skipping chromosome chrUn_KI270438v1
# 	Skipping chromosome chrUn_KI270468v1
# 	Skipping chromosome chrUn_KI270510v1
# 	Skipping chromosome chrUn_KI270509v1
# 	Skipping chromosome chrUn_KI270518v1
# 	Skipping chromosome chrUn_KI270508v1
# 	Skipping chromosome chrUn_KI270516v1
# 	Skipping chromosome chrUn_KI270512v1
# 	Skipping chromosome chrUn_KI270519v1
# 	Skipping chromosome chrUn_KI270522v1
# 	Skipping chromosome chrUn_KI270511v1
# 	Skipping chromosome chrUn_KI270515v1
# 	Skipping chromosome chrUn_KI270507v1
# 	Skipping chromosome chrUn_KI270517v1
# 	Skipping chromosome chrUn_KI270529v1
# 	Skipping chromosome chrUn_KI270528v1
# 	Skipping chromosome chrUn_KI270530v1
# 	Skipping chromosome chrUn_KI270539v1
# 	Skipping chromosome chrUn_KI270538v1
# 	Skipping chromosome chrUn_KI270544v1
# 	Skipping chromosome chrUn_KI270548v1
# 	Skipping chromosome chrUn_KI270583v1
# 	Skipping chromosome chrUn_KI270587v1
# 	Skipping chromosome chrUn_KI270580v1
# 	Skipping chromosome chrUn_KI270581v1
# 	Skipping chromosome chrUn_KI270579v1
# 	Skipping chromosome chrUn_KI270589v1
# 	Skipping chromosome chrUn_KI270590v1
# 	Skipping chromosome chrUn_KI270584v1
# 	Skipping chromosome chrUn_KI270582v1
# 	Skipping chromosome chrUn_KI270588v1
# 	Skipping chromosome chrUn_KI270593v1
# 	Skipping chromosome chrUn_KI270591v1
# 	Skipping chromosome chrUn_KI270330v1
# 	Skipping chromosome chrUn_KI270329v1
# 	Skipping chromosome chrUn_KI270334v1
# 	Skipping chromosome chrUn_KI270333v1
# 	Skipping chromosome chrUn_KI270335v1
# 	Skipping chromosome chrUn_KI270338v1
# 	Skipping chromosome chrUn_KI270340v1
# 	Skipping chromosome chrUn_KI270336v1
# 	Skipping chromosome chrUn_KI270337v1
# 	Skipping chromosome chrUn_KI270363v1
# 	Skipping chromosome chrUn_KI270364v1
# 	Skipping chromosome chrUn_KI270362v1
# 	Skipping chromosome chrUn_KI270366v1
# 	Skipping chromosome chrUn_KI270378v1
# 	Skipping chromosome chrUn_KI270379v1
# 	Skipping chromosome chrUn_KI270389v1
# 	Skipping chromosome chrUn_KI270390v1
# 	Skipping chromosome chrUn_KI270387v1
# 	Skipping chromosome chrUn_KI270395v1
# 	Skipping chromosome chrUn_KI270396v1
# 	Skipping chromosome chrUn_KI270388v1
# 	Skipping chromosome chrUn_KI270394v1
# 	Skipping chromosome chrUn_KI270386v1
# 	Skipping chromosome chrUn_KI270391v1
# 	Skipping chromosome chrUn_KI270383v1
# 	Skipping chromosome chrUn_KI270393v1
# 	Skipping chromosome chrUn_KI270384v1
# 	Skipping chromosome chrUn_KI270392v1
# 	Skipping chromosome chrUn_KI270381v1
# 	Skipping chromosome chrUn_KI270385v1
# 	Skipping chromosome chrUn_KI270382v1
# 	Skipping chromosome chrUn_KI270376v1
# 	Skipping chromosome chrUn_KI270374v1
# 	Skipping chromosome chrUn_KI270372v1
# 	Skipping chromosome chrUn_KI270373v1
# 	Skipping chromosome chrUn_KI270375v1
# 	Skipping chromosome chrUn_KI270371v1
# 	Skipping chromosome chrUn_KI270448v1
# 	Skipping chromosome chrUn_KI270521v1
# 	Skipping chromosome chrUn_GL000195v1
# 	Skipping chromosome chrUn_GL000219v1
# 	Skipping chromosome chrUn_GL000220v1
# 	Skipping chromosome chrUn_GL000224v1
# 	Skipping chromosome chrUn_KI270741v1
# 	Skipping chromosome chrUn_GL000226v1
# 	Skipping chromosome chrUn_GL000213v1
# 	Skipping chromosome chrUn_KI270743v1
# 	Skipping chromosome chrUn_KI270744v1
# 	Skipping chromosome chrUn_KI270745v1
# 	Skipping chromosome chrUn_KI270746v1
# 	Skipping chromosome chrUn_KI270747v1
# 	Skipping chromosome chrUn_KI270748v1
# 	Skipping chromosome chrUn_KI270749v1
# 	Skipping chromosome chrUn_KI270750v1
# 	Skipping chromosome chrUn_KI270751v1
# 	Skipping chromosome chrUn_KI270752v1
# 	Skipping chromosome chrUn_KI270753v1
# 	Skipping chromosome chrUn_KI270754v1
# 	Skipping chromosome chrUn_KI270755v1
# 	Skipping chromosome chrUn_KI270756v1
# 	Skipping chromosome chrUn_KI270757v1
# 	Skipping chromosome chrUn_GL000214v1
# 	Skipping chromosome chrUn_KI270742v1
# 	Skipping chromosome chrUn_GL000216v2
# 	Skipping chromosome chrUn_GL000218v1
# 	Skipping chromosome chrEBV
# 	Skipping chromosome chrUn_KN707606v1_decoy
# 	Skipping chromosome chrUn_KN707607v1_decoy
# 	Skipping chromosome chrUn_KN707608v1_decoy
# 	Skipping chromosome chrUn_KN707609v1_decoy
# 	Skipping chromosome chrUn_KN707610v1_decoy
# 	Skipping chromosome chrUn_KN707611v1_decoy
# 	Skipping chromosome chrUn_KN707612v1_decoy
# 	Skipping chromosome chrUn_KN707613v1_decoy
# 	Skipping chromosome chrUn_KN707614v1_decoy
# 	Skipping chromosome chrUn_KN707615v1_decoy
# 	Skipping chromosome chrUn_KN707616v1_decoy
# 	Skipping chromosome chrUn_KN707617v1_decoy
# 	Skipping chromosome chrUn_KN707618v1_decoy
# 	Skipping chromosome chrUn_KN707619v1_decoy
# 	Skipping chromosome chrUn_KN707620v1_decoy
# 	Skipping chromosome chrUn_KN707621v1_decoy
# 	Skipping chromosome chrUn_KN707622v1_decoy
# 	Skipping chromosome chrUn_KN707623v1_decoy
# 	Skipping chromosome chrUn_KN707624v1_decoy
# 	Skipping chromosome chrUn_KN707625v1_decoy
# 	Skipping chromosome chrUn_KN707626v1_decoy
# 	Skipping chromosome chrUn_KN707627v1_decoy
# 	Skipping chromosome chrUn_KN707628v1_decoy
# 	Skipping chromosome chrUn_KN707629v1_decoy
# 	Skipping chromosome chrUn_KN707630v1_decoy
# 	Skipping chromosome chrUn_KN707631v1_decoy
# 	Skipping chromosome chrUn_KN707632v1_decoy
# 	Skipping chromosome chrUn_KN707633v1_decoy
# 	Skipping chromosome chrUn_KN707634v1_decoy
# 	Skipping chromosome chrUn_KN707635v1_decoy
# 	Skipping chromosome chrUn_KN707636v1_decoy
# 	Skipping chromosome chrUn_KN707637v1_decoy
# 	Skipping chromosome chrUn_KN707638v1_decoy
# 	Skipping chromosome chrUn_KN707639v1_decoy
# 	Skipping chromosome chrUn_KN707640v1_decoy
# 	Skipping chromosome chrUn_KN707641v1_decoy
# 	Skipping chromosome chrUn_KN707642v1_decoy
# 	Skipping chromosome chrUn_KN707643v1_decoy
# 	Skipping chromosome chrUn_KN707644v1_decoy
# 	Skipping chromosome chrUn_KN707645v1_decoy
# 	Skipping chromosome chrUn_KN707646v1_decoy
# 	Skipping chromosome chrUn_KN707647v1_decoy
# 	Skipping chromosome chrUn_KN707648v1_decoy
# 	Skipping chromosome chrUn_KN707649v1_decoy
# 	Skipping chromosome chrUn_KN707650v1_decoy
# 	Skipping chromosome chrUn_KN707651v1_decoy
# 	Skipping chromosome chrUn_KN707652v1_decoy
# 	Skipping chromosome chrUn_KN707653v1_decoy
# 	Skipping chromosome chrUn_KN707654v1_decoy
# 	Skipping chromosome chrUn_KN707655v1_decoy
# 	Skipping chromosome chrUn_KN707656v1_decoy
# 	Skipping chromosome chrUn_KN707657v1_decoy
# 	Skipping chromosome chrUn_KN707658v1_decoy
# 	Skipping chromosome chrUn_KN707659v1_decoy
# 	Skipping chromosome chrUn_KN707660v1_decoy
# 	Skipping chromosome chrUn_KN707661v1_decoy
# 	Skipping chromosome chrUn_KN707662v1_decoy
# 	Skipping chromosome chrUn_KN707663v1_decoy
# 	Skipping chromosome chrUn_KN707664v1_decoy
# 	Skipping chromosome chrUn_KN707665v1_decoy
# 	Skipping chromosome chrUn_KN707666v1_decoy
# 	Skipping chromosome chrUn_KN707667v1_decoy
# 	Skipping chromosome chrUn_KN707668v1_decoy
# 	Skipping chromosome chrUn_KN707669v1_decoy
# 	Skipping chromosome chrUn_KN707670v1_decoy
# 	Skipping chromosome chrUn_KN707671v1_decoy
# 	Skipping chromosome chrUn_KN707672v1_decoy
# 	Skipping chromosome chrUn_KN707673v1_decoy
# 	Skipping chromosome chrUn_KN707674v1_decoy
# 	Skipping chromosome chrUn_KN707675v1_decoy
# 	Skipping chromosome chrUn_KN707676v1_decoy
# 	Skipping chromosome chrUn_KN707677v1_decoy
# 	Skipping chromosome chrUn_KN707678v1_decoy
# 	Skipping chromosome chrUn_KN707679v1_decoy
# 	Skipping chromosome chrUn_KN707680v1_decoy
# 	Skipping chromosome chrUn_KN707681v1_decoy
# 	Skipping chromosome chrUn_KN707682v1_decoy
# 	Skipping chromosome chrUn_KN707683v1_decoy
# 	Skipping chromosome chrUn_KN707684v1_decoy
# 	Skipping chromosome chrUn_KN707685v1_decoy
# 	Skipping chromosome chrUn_KN707686v1_decoy
# 	Skipping chromosome chrUn_KN707687v1_decoy
# 	Skipping chromosome chrUn_KN707688v1_decoy
# 	Skipping chromosome chrUn_KN707689v1_decoy
# 	Skipping chromosome chrUn_KN707690v1_decoy
# 	Skipping chromosome chrUn_KN707691v1_decoy
# 	Skipping chromosome chrUn_KN707692v1_decoy
# 	Skipping chromosome chrUn_KN707693v1_decoy
# 	Skipping chromosome chrUn_KN707694v1_decoy
# 	Skipping chromosome chrUn_KN707695v1_decoy
# 	Skipping chromosome chrUn_KN707696v1_decoy
# 	Skipping chromosome chrUn_KN707697v1_decoy
# 	Skipping chromosome chrUn_KN707698v1_decoy
# 	Skipping chromosome chrUn_KN707699v1_decoy
# 	Skipping chromosome chrUn_KN707700v1_decoy
# 	Skipping chromosome chrUn_KN707701v1_decoy
# 	Skipping chromosome chrUn_KN707702v1_decoy
# 	Skipping chromosome chrUn_KN707703v1_decoy
# 	Skipping chromosome chrUn_KN707704v1_decoy
# 	Skipping chromosome chrUn_KN707705v1_decoy
# 	Skipping chromosome chrUn_KN707706v1_decoy
# 	Skipping chromosome chrUn_KN707707v1_decoy
# 	Skipping chromosome chrUn_KN707708v1_decoy
# 	Skipping chromosome chrUn_KN707709v1_decoy
# 	Skipping chromosome chrUn_KN707710v1_decoy
# 	Skipping chromosome chrUn_KN707711v1_decoy
# 	Skipping chromosome chrUn_KN707712v1_decoy
# 	Skipping chromosome chrUn_KN707713v1_decoy
# 	Skipping chromosome chrUn_KN707714v1_decoy
# 	Skipping chromosome chrUn_KN707715v1_decoy
# 	Skipping chromosome chrUn_KN707716v1_decoy
# 	Skipping chromosome chrUn_KN707717v1_decoy
# 	Skipping chromosome chrUn_KN707718v1_decoy
# 	Skipping chromosome chrUn_KN707719v1_decoy
# 	Skipping chromosome chrUn_KN707720v1_decoy
# 	Skipping chromosome chrUn_KN707721v1_decoy
# 	Skipping chromosome chrUn_KN707722v1_decoy
# 	Skipping chromosome chrUn_KN707723v1_decoy
# 	Skipping chromosome chrUn_KN707724v1_decoy
# 	Skipping chromosome chrUn_KN707725v1_decoy
# 	Skipping chromosome chrUn_KN707726v1_decoy
# 	Skipping chromosome chrUn_KN707727v1_decoy
# 	Skipping chromosome chrUn_KN707728v1_decoy
# 	Skipping chromosome chrUn_KN707729v1_decoy
# 	Skipping chromosome chrUn_KN707730v1_decoy
# 	Skipping chromosome chrUn_KN707731v1_decoy
# 	Skipping chromosome chrUn_KN707732v1_decoy
# 	Skipping chromosome chrUn_KN707733v1_decoy
# 	Skipping chromosome chrUn_KN707734v1_decoy
# 	Skipping chromosome chrUn_KN707735v1_decoy
# 	Skipping chromosome chrUn_KN707736v1_decoy
# 	Skipping chromosome chrUn_KN707737v1_decoy
# 	Skipping chromosome chrUn_KN707738v1_decoy
# 	Skipping chromosome chrUn_KN707739v1_decoy
# 	Skipping chromosome chrUn_KN707740v1_decoy
# 	Skipping chromosome chrUn_KN707741v1_decoy
# 	Skipping chromosome chrUn_KN707742v1_decoy
# 	Skipping chromosome chrUn_KN707743v1_decoy
# 	Skipping chromosome chrUn_KN707744v1_decoy
# 	Skipping chromosome chrUn_KN707745v1_decoy
# 	Skipping chromosome chrUn_KN707746v1_decoy
# 	Skipping chromosome chrUn_KN707747v1_decoy
# 	Skipping chromosome chrUn_KN707748v1_decoy
# 	Skipping chromosome chrUn_KN707749v1_decoy
# 	Skipping chromosome chrUn_KN707750v1_decoy
# 	Skipping chromosome chrUn_KN707751v1_decoy
# 	Skipping chromosome chrUn_KN707752v1_decoy
# 	Skipping chromosome chrUn_KN707753v1_decoy
# 	Skipping chromosome chrUn_KN707754v1_decoy
# 	Skipping chromosome chrUn_KN707755v1_decoy
# 	Skipping chromosome chrUn_KN707756v1_decoy
# 	Skipping chromosome chrUn_KN707757v1_decoy
# 	Skipping chromosome chrUn_KN707758v1_decoy
# 	Skipping chromosome chrUn_KN707759v1_decoy
# 	Skipping chromosome chrUn_KN707760v1_decoy
# 	Skipping chromosome chrUn_KN707761v1_decoy
# 	Skipping chromosome chrUn_KN707762v1_decoy
# 	Skipping chromosome chrUn_KN707763v1_decoy
# 	Skipping chromosome chrUn_KN707764v1_decoy
# 	Skipping chromosome chrUn_KN707765v1_decoy
# 	Skipping chromosome chrUn_KN707766v1_decoy
# 	Skipping chromosome chrUn_KN707767v1_decoy
# 	Skipping chromosome chrUn_KN707768v1_decoy
# 	Skipping chromosome chrUn_KN707769v1_decoy
# 	Skipping chromosome chrUn_KN707770v1_decoy
# 	Skipping chromosome chrUn_KN707771v1_decoy
# 	Skipping chromosome chrUn_KN707772v1_decoy
# 	Skipping chromosome chrUn_KN707773v1_decoy
# 	Skipping chromosome chrUn_KN707774v1_decoy
# 	Skipping chromosome chrUn_KN707775v1_decoy
# 	Skipping chromosome chrUn_KN707776v1_decoy
# 	Skipping chromosome chrUn_KN707777v1_decoy
# 	Skipping chromosome chrUn_KN707778v1_decoy
# 	Skipping chromosome chrUn_KN707779v1_decoy
# 	Skipping chromosome chrUn_KN707780v1_decoy
# 	Skipping chromosome chrUn_KN707781v1_decoy
# 	Skipping chromosome chrUn_KN707782v1_decoy
# 	Skipping chromosome chrUn_KN707783v1_decoy
# 	Skipping chromosome chrUn_KN707784v1_decoy
# 	Skipping chromosome chrUn_KN707785v1_decoy
# 	Skipping chromosome chrUn_KN707786v1_decoy
# 	Skipping chromosome chrUn_KN707787v1_decoy
# 	Skipping chromosome chrUn_KN707788v1_decoy
# 	Skipping chromosome chrUn_KN707789v1_decoy
# 	Skipping chromosome chrUn_KN707790v1_decoy
# 	Skipping chromosome chrUn_KN707791v1_decoy
# 	Skipping chromosome chrUn_KN707792v1_decoy
# 	Skipping chromosome chrUn_KN707793v1_decoy
# 	Skipping chromosome chrUn_KN707794v1_decoy
# 	Skipping chromosome chrUn_KN707795v1_decoy
# 	Skipping chromosome chrUn_KN707796v1_decoy
# 	Skipping chromosome chrUn_KN707797v1_decoy
# 	Skipping chromosome chrUn_KN707798v1_decoy
# 	Skipping chromosome chrUn_KN707799v1_decoy
# 	Skipping chromosome chrUn_KN707800v1_decoy
# 	Skipping chromosome chrUn_KN707801v1_decoy
# 	Skipping chromosome chrUn_KN707802v1_decoy
# 	Skipping chromosome chrUn_KN707803v1_decoy
# 	Skipping chromosome chrUn_KN707804v1_decoy
# 	Skipping chromosome chrUn_KN707805v1_decoy
# 	Skipping chromosome chrUn_KN707806v1_decoy
# 	Skipping chromosome chrUn_KN707807v1_decoy
# 	Skipping chromosome chrUn_KN707808v1_decoy
# 	Skipping chromosome chrUn_KN707809v1_decoy
# 	Skipping chromosome chrUn_KN707810v1_decoy
# 	Skipping chromosome chrUn_KN707811v1_decoy
# 	Skipping chromosome chrUn_KN707812v1_decoy
# 	Skipping chromosome chrUn_KN707813v1_decoy
# 	Skipping chromosome chrUn_KN707814v1_decoy
# 	Skipping chromosome chrUn_KN707815v1_decoy
# 	Skipping chromosome chrUn_KN707816v1_decoy
# 	Skipping chromosome chrUn_KN707817v1_decoy
# 	Skipping chromosome chrUn_KN707818v1_decoy
# 	Skipping chromosome chrUn_KN707819v1_decoy
# 	Skipping chromosome chrUn_KN707820v1_decoy
# 	Skipping chromosome chrUn_KN707821v1_decoy
# 	Skipping chromosome chrUn_KN707822v1_decoy
# 	Skipping chromosome chrUn_KN707823v1_decoy
# 	Skipping chromosome chrUn_KN707824v1_decoy
# 	Skipping chromosome chrUn_KN707825v1_decoy
# 	Skipping chromosome chrUn_KN707826v1_decoy
# 	Skipping chromosome chrUn_KN707827v1_decoy
# 	Skipping chromosome chrUn_KN707828v1_decoy
# 	Skipping chromosome chrUn_KN707829v1_decoy
# 	Skipping chromosome chrUn_KN707830v1_decoy
# 	Skipping chromosome chrUn_KN707831v1_decoy
# 	Skipping chromosome chrUn_KN707832v1_decoy
# 	Skipping chromosome chrUn_KN707833v1_decoy
# 	Skipping chromosome chrUn_KN707834v1_decoy
# 	Skipping chromosome chrUn_KN707835v1_decoy
# 	Skipping chromosome chrUn_KN707836v1_decoy
# 	Skipping chromosome chrUn_KN707837v1_decoy
# 	Skipping chromosome chrUn_KN707838v1_decoy
# 	Skipping chromosome chrUn_KN707839v1_decoy
# 	Skipping chromosome chrUn_KN707840v1_decoy
# 	Skipping chromosome chrUn_KN707841v1_decoy
# 	Skipping chromosome chrUn_KN707842v1_decoy
# 	Skipping chromosome chrUn_KN707843v1_decoy
# 	Skipping chromosome chrUn_KN707844v1_decoy
# 	Skipping chromosome chrUn_KN707845v1_decoy
# 	Skipping chromosome chrUn_KN707846v1_decoy
# 	Skipping chromosome chrUn_KN707847v1_decoy
# 	Skipping chromosome chrUn_KN707848v1_decoy
# 	Skipping chromosome chrUn_KN707849v1_decoy
# 	Skipping chromosome chrUn_KN707850v1_decoy
# 	Skipping chromosome chrUn_KN707851v1_decoy
# 	Skipping chromosome chrUn_KN707852v1_decoy
# 	Skipping chromosome chrUn_KN707853v1_decoy
# 	Skipping chromosome chrUn_KN707854v1_decoy
# 	Skipping chromosome chrUn_KN707855v1_decoy
# 	Skipping chromosome chrUn_KN707856v1_decoy
# 	Skipping chromosome chrUn_KN707857v1_decoy
# 	Skipping chromosome chrUn_KN707858v1_decoy
# 	Skipping chromosome chrUn_KN707859v1_decoy
# 	Skipping chromosome chrUn_KN707860v1_decoy
# 	Skipping chromosome chrUn_KN707861v1_decoy
# 	Skipping chromosome chrUn_KN707862v1_decoy
# 	Skipping chromosome chrUn_KN707863v1_decoy
# 	Skipping chromosome chrUn_KN707864v1_decoy
# 	Skipping chromosome chrUn_KN707865v1_decoy
# 	Skipping chromosome chrUn_KN707866v1_decoy
# 	Skipping chromosome chrUn_KN707867v1_decoy
# 	Skipping chromosome chrUn_KN707868v1_decoy
# 	Skipping chromosome chrUn_KN707869v1_decoy
# 	Skipping chromosome chrUn_KN707870v1_decoy
# 	Skipping chromosome chrUn_KN707871v1_decoy
# 	Skipping chromosome chrUn_KN707872v1_decoy
# 	Skipping chromosome chrUn_KN707873v1_decoy
# 	Skipping chromosome chrUn_KN707874v1_decoy
# 	Skipping chromosome chrUn_KN707875v1_decoy
# 	Skipping chromosome chrUn_KN707876v1_decoy
# 	Skipping chromosome chrUn_KN707877v1_decoy
# 	Skipping chromosome chrUn_KN707878v1_decoy
# 	Skipping chromosome chrUn_KN707879v1_decoy
# 	Skipping chromosome chrUn_KN707880v1_decoy
# 	Skipping chromosome chrUn_KN707881v1_decoy
# 	Skipping chromosome chrUn_KN707882v1_decoy
# 	Skipping chromosome chrUn_KN707883v1_decoy
# 	Skipping chromosome chrUn_KN707884v1_decoy
# 	Skipping chromosome chrUn_KN707885v1_decoy
# 	Skipping chromosome chrUn_KN707886v1_decoy
# 	Skipping chromosome chrUn_KN707887v1_decoy
# 	Skipping chromosome chrUn_KN707888v1_decoy
# 	Skipping chromosome chrUn_KN707889v1_decoy
# 	Skipping chromosome chrUn_KN707890v1_decoy
# 	Skipping chromosome chrUn_KN707891v1_decoy
# 	Skipping chromosome chrUn_KN707892v1_decoy
# 	Skipping chromosome chrUn_KN707893v1_decoy
# 	Skipping chromosome chrUn_KN707894v1_decoy
# 	Skipping chromosome chrUn_KN707895v1_decoy
# 	Skipping chromosome chrUn_KN707896v1_decoy
# 	Skipping chromosome chrUn_KN707897v1_decoy
# 	Skipping chromosome chrUn_KN707898v1_decoy
# 	Skipping chromosome chrUn_KN707899v1_decoy
# 	Skipping chromosome chrUn_KN707900v1_decoy
# 	Skipping chromosome chrUn_KN707901v1_decoy
# 	Skipping chromosome chrUn_KN707902v1_decoy
# 	Skipping chromosome chrUn_KN707903v1_decoy
# 	Skipping chromosome chrUn_KN707904v1_decoy
# 	Skipping chromosome chrUn_KN707905v1_decoy
# 	Skipping chromosome chrUn_KN707906v1_decoy
# 	Skipping chromosome chrUn_KN707907v1_decoy
# 	Skipping chromosome chrUn_KN707908v1_decoy
# 	Skipping chromosome chrUn_KN707909v1_decoy
# 	Skipping chromosome chrUn_KN707910v1_decoy
# 	Skipping chromosome chrUn_KN707911v1_decoy
# 	Skipping chromosome chrUn_KN707912v1_decoy
# 	Skipping chromosome chrUn_KN707913v1_decoy
# 	Skipping chromosome chrUn_KN707914v1_decoy
# 	Skipping chromosome chrUn_KN707915v1_decoy
# 	Skipping chromosome chrUn_KN707916v1_decoy
# 	Skipping chromosome chrUn_KN707917v1_decoy
# 	Skipping chromosome chrUn_KN707918v1_decoy
# 	Skipping chromosome chrUn_KN707919v1_decoy
# 	Skipping chromosome chrUn_KN707920v1_decoy
# 	Skipping chromosome chrUn_KN707921v1_decoy
# 	Skipping chromosome chrUn_KN707922v1_decoy
# 	Skipping chromosome chrUn_KN707923v1_decoy
# 	Skipping chromosome chrUn_KN707924v1_decoy
# 	Skipping chromosome chrUn_KN707925v1_decoy
# 	Skipping chromosome chrUn_KN707926v1_decoy
# 	Skipping chromosome chrUn_KN707927v1_decoy
# 	Skipping chromosome chrUn_KN707928v1_decoy
# 	Skipping chromosome chrUn_KN707929v1_decoy
# 	Skipping chromosome chrUn_KN707930v1_decoy
# 	Skipping chromosome chrUn_KN707931v1_decoy
# 	Skipping chromosome chrUn_KN707932v1_decoy
# 	Skipping chromosome chrUn_KN707933v1_decoy
# 	Skipping chromosome chrUn_KN707934v1_decoy
# 	Skipping chromosome chrUn_KN707935v1_decoy
# 	Skipping chromosome chrUn_KN707936v1_decoy
# 	Skipping chromosome chrUn_KN707937v1_decoy
# 	Skipping chromosome chrUn_KN707938v1_decoy
# 	Skipping chromosome chrUn_KN707939v1_decoy
# 	Skipping chromosome chrUn_KN707940v1_decoy
# 	Skipping chromosome chrUn_KN707941v1_decoy
# 	Skipping chromosome chrUn_KN707942v1_decoy
# 	Skipping chromosome chrUn_KN707943v1_decoy
# 	Skipping chromosome chrUn_KN707944v1_decoy
# 	Skipping chromosome chrUn_KN707945v1_decoy
# 	Skipping chromosome chrUn_KN707946v1_decoy
# 	Skipping chromosome chrUn_KN707947v1_decoy
# 	Skipping chromosome chrUn_KN707948v1_decoy
# 	Skipping chromosome chrUn_KN707949v1_decoy
# 	Skipping chromosome chrUn_KN707950v1_decoy
# 	Skipping chromosome chrUn_KN707951v1_decoy
# 	Skipping chromosome chrUn_KN707952v1_decoy
# 	Skipping chromosome chrUn_KN707953v1_decoy
# 	Skipping chromosome chrUn_KN707954v1_decoy
# 	Skipping chromosome chrUn_KN707955v1_decoy
# 	Skipping chromosome chrUn_KN707956v1_decoy
# 	Skipping chromosome chrUn_KN707957v1_decoy
# 	Skipping chromosome chrUn_KN707958v1_decoy
# 	Skipping chromosome chrUn_KN707959v1_decoy
# 	Skipping chromosome chrUn_KN707960v1_decoy
# 	Skipping chromosome chrUn_KN707961v1_decoy
# 	Skipping chromosome chrUn_KN707962v1_decoy
# 	Skipping chromosome chrUn_KN707963v1_decoy
# 	Skipping chromosome chrUn_KN707964v1_decoy
# 	Skipping chromosome chrUn_KN707965v1_decoy
# 	Skipping chromosome chrUn_KN707966v1_decoy
# 	Skipping chromosome chrUn_KN707967v1_decoy
# 	Skipping chromosome chrUn_KN707968v1_decoy
# 	Skipping chromosome chrUn_KN707969v1_decoy
# 	Skipping chromosome chrUn_KN707970v1_decoy
# 	Skipping chromosome chrUn_KN707971v1_decoy
# 	Skipping chromosome chrUn_KN707972v1_decoy
# 	Skipping chromosome chrUn_KN707973v1_decoy
# 	Skipping chromosome chrUn_KN707974v1_decoy
# 	Skipping chromosome chrUn_KN707975v1_decoy
# 	Skipping chromosome chrUn_KN707976v1_decoy
# 	Skipping chromosome chrUn_KN707977v1_decoy
# 	Skipping chromosome chrUn_KN707978v1_decoy
# 	Skipping chromosome chrUn_KN707979v1_decoy
# 	Skipping chromosome chrUn_KN707980v1_decoy
# 	Skipping chromosome chrUn_KN707981v1_decoy
# 	Skipping chromosome chrUn_KN707982v1_decoy
# 	Skipping chromosome chrUn_KN707983v1_decoy
# 	Skipping chromosome chrUn_KN707984v1_decoy
# 	Skipping chromosome chrUn_KN707985v1_decoy
# 	Skipping chromosome chrUn_KN707986v1_decoy
# 	Skipping chromosome chrUn_KN707987v1_decoy
# 	Skipping chromosome chrUn_KN707988v1_decoy
# 	Skipping chromosome chrUn_KN707989v1_decoy
# 	Skipping chromosome chrUn_KN707990v1_decoy
# 	Skipping chromosome chrUn_KN707991v1_decoy
# 	Skipping chromosome chrUn_KN707992v1_decoy
# 	Skipping chromosome chrUn_JTFH01000001v1_decoy
# 	Skipping chromosome chrUn_JTFH01000002v1_decoy
# 	Skipping chromosome chrUn_JTFH01000003v1_decoy
# 	Skipping chromosome chrUn_JTFH01000004v1_decoy
# 	Skipping chromosome chrUn_JTFH01000005v1_decoy
# 	Skipping chromosome chrUn_JTFH01000006v1_decoy
# 	Skipping chromosome chrUn_JTFH01000007v1_decoy
# 	Skipping chromosome chrUn_JTFH01000008v1_decoy
# 	Skipping chromosome chrUn_JTFH01000009v1_decoy
# 	Skipping chromosome chrUn_JTFH01000010v1_decoy
# 	Skipping chromosome chrUn_JTFH01000011v1_decoy
# 	Skipping chromosome chrUn_JTFH01000012v1_decoy
# 	Skipping chromosome chrUn_JTFH01000013v1_decoy
# 	Skipping chromosome chrUn_JTFH01000014v1_decoy
# 	Skipping chromosome chrUn_JTFH01000015v1_decoy
# 	Skipping chromosome chrUn_JTFH01000016v1_decoy
# 	Skipping chromosome chrUn_JTFH01000017v1_decoy
# 	Skipping chromosome chrUn_JTFH01000018v1_decoy
# 	Skipping chromosome chrUn_JTFH01000019v1_decoy
# 	Skipping chromosome chrUn_JTFH01000020v1_decoy
# 	Skipping chromosome chrUn_JTFH01000021v1_decoy
# 	Skipping chromosome chrUn_JTFH01000022v1_decoy
# 	Skipping chromosome chrUn_JTFH01000023v1_decoy
# 	Skipping chromosome chrUn_JTFH01000024v1_decoy
# 	Skipping chromosome chrUn_JTFH01000025v1_decoy
# 	Skipping chromosome chrUn_JTFH01000026v1_decoy
# 	Skipping chromosome chrUn_JTFH01000027v1_decoy
# 	Skipping chromosome chrUn_JTFH01000028v1_decoy
# 	Skipping chromosome chrUn_JTFH01000029v1_decoy
# 	Skipping chromosome chrUn_JTFH01000030v1_decoy
# 	Skipping chromosome chrUn_JTFH01000031v1_decoy
# 	Skipping chromosome chrUn_JTFH01000032v1_decoy
# 	Skipping chromosome chrUn_JTFH01000033v1_decoy
# 	Skipping chromosome chrUn_JTFH01000034v1_decoy
# 	Skipping chromosome chrUn_JTFH01000035v1_decoy
# 	Skipping chromosome chrUn_JTFH01000036v1_decoy
# 	Skipping chromosome chrUn_JTFH01000037v1_decoy
# 	Skipping chromosome chrUn_JTFH01000038v1_decoy
# 	Skipping chromosome chrUn_JTFH01000039v1_decoy
# 	Skipping chromosome chrUn_JTFH01000040v1_decoy
# 	Skipping chromosome chrUn_JTFH01000041v1_decoy
# 	Skipping chromosome chrUn_JTFH01000042v1_decoy
# 	Skipping chromosome chrUn_JTFH01000043v1_decoy
# 	Skipping chromosome chrUn_JTFH01000044v1_decoy
# 	Skipping chromosome chrUn_JTFH01000045v1_decoy
# 	Skipping chromosome chrUn_JTFH01000046v1_decoy
# 	Skipping chromosome chrUn_JTFH01000047v1_decoy
# 	Skipping chromosome chrUn_JTFH01000048v1_decoy
# 	Skipping chromosome chrUn_JTFH01000049v1_decoy
# 	Skipping chromosome chrUn_JTFH01000050v1_decoy
# 	Skipping chromosome chrUn_JTFH01000051v1_decoy
# 	Skipping chromosome chrUn_JTFH01000052v1_decoy
# 	Skipping chromosome chrUn_JTFH01000053v1_decoy
# 	Skipping chromosome chrUn_JTFH01000054v1_decoy
# 	Skipping chromosome chrUn_JTFH01000055v1_decoy
# 	Skipping chromosome chrUn_JTFH01000056v1_decoy
# 	Skipping chromosome chrUn_JTFH01000057v1_decoy
# 	Skipping chromosome chrUn_JTFH01000058v1_decoy
# 	Skipping chromosome chrUn_JTFH01000059v1_decoy
# 	Skipping chromosome chrUn_JTFH01000060v1_decoy
# 	Skipping chromosome chrUn_JTFH01000061v1_decoy
# 	Skipping chromosome chrUn_JTFH01000062v1_decoy
# 	Skipping chromosome chrUn_JTFH01000063v1_decoy
# 	Skipping chromosome chrUn_JTFH01000064v1_decoy
# 	Skipping chromosome chrUn_JTFH01000065v1_decoy
# 	Skipping chromosome chrUn_JTFH01000066v1_decoy
# 	Skipping chromosome chrUn_JTFH01000067v1_decoy
# 	Skipping chromosome chrUn_JTFH01000068v1_decoy
# 	Skipping chromosome chrUn_JTFH01000069v1_decoy
# 	Skipping chromosome chrUn_JTFH01000070v1_decoy
# 	Skipping chromosome chrUn_JTFH01000071v1_decoy
# 	Skipping chromosome chrUn_JTFH01000072v1_decoy
# 	Skipping chromosome chrUn_JTFH01000073v1_decoy
# 	Skipping chromosome chrUn_JTFH01000074v1_decoy
# 	Skipping chromosome chrUn_JTFH01000075v1_decoy
# 	Skipping chromosome chrUn_JTFH01000076v1_decoy
# 	Skipping chromosome chrUn_JTFH01000077v1_decoy
# 	Skipping chromosome chrUn_JTFH01000078v1_decoy
# 	Skipping chromosome chrUn_JTFH01000079v1_decoy
# 	Skipping chromosome chrUn_JTFH01000080v1_decoy
# 	Skipping chromosome chrUn_JTFH01000081v1_decoy
# 	Skipping chromosome chrUn_JTFH01000082v1_decoy
# 	Skipping chromosome chrUn_JTFH01000083v1_decoy
# 	Skipping chromosome chrUn_JTFH01000084v1_decoy
# 	Skipping chromosome chrUn_JTFH01000085v1_decoy
# 	Skipping chromosome chrUn_JTFH01000086v1_decoy
# 	Skipping chromosome chrUn_JTFH01000087v1_decoy
# 	Skipping chromosome chrUn_JTFH01000088v1_decoy
# 	Skipping chromosome chrUn_JTFH01000089v1_decoy
# 	Skipping chromosome chrUn_JTFH01000090v1_decoy
# 	Skipping chromosome chrUn_JTFH01000091v1_decoy
# 	Skipping chromosome chrUn_JTFH01000092v1_decoy
# 	Skipping chromosome chrUn_JTFH01000093v1_decoy
# 	Skipping chromosome chrUn_JTFH01000094v1_decoy
# 	Skipping chromosome chrUn_JTFH01000095v1_decoy
# 	Skipping chromosome chrUn_JTFH01000096v1_decoy
# 	Skipping chromosome chrUn_JTFH01000097v1_decoy
# 	Skipping chromosome chrUn_JTFH01000098v1_decoy
# 	Skipping chromosome chrUn_JTFH01000099v1_decoy
# 	Skipping chromosome chrUn_JTFH01000100v1_decoy
# 	Skipping chromosome chrUn_JTFH01000101v1_decoy
# 	Skipping chromosome chrUn_JTFH01000102v1_decoy
# 	Skipping chromosome chrUn_JTFH01000103v1_decoy
# 	Skipping chromosome chrUn_JTFH01000104v1_decoy
# 	Skipping chromosome chrUn_JTFH01000105v1_decoy
# 	Skipping chromosome chrUn_JTFH01000106v1_decoy
# 	Skipping chromosome chrUn_JTFH01000107v1_decoy
# 	Skipping chromosome chrUn_JTFH01000108v1_decoy
# 	Skipping chromosome chrUn_JTFH01000109v1_decoy
# 	Skipping chromosome chrUn_JTFH01000110v1_decoy
# 	Skipping chromosome chrUn_JTFH01000111v1_decoy
# 	Skipping chromosome chrUn_JTFH01000112v1_decoy
# 	Skipping chromosome chrUn_JTFH01000113v1_decoy
# 	Skipping chromosome chrUn_JTFH01000114v1_decoy
# 	Skipping chromosome chrUn_JTFH01000115v1_decoy
# 	Skipping chromosome chrUn_JTFH01000116v1_decoy
# 	Skipping chromosome chrUn_JTFH01000117v1_decoy
# 	Skipping chromosome chrUn_JTFH01000118v1_decoy
# 	Skipping chromosome chrUn_JTFH01000119v1_decoy
# 	Skipping chromosome chrUn_JTFH01000120v1_decoy
# 	Skipping chromosome chrUn_JTFH01000121v1_decoy
# 	Skipping chromosome chrUn_JTFH01000122v1_decoy
# 	Skipping chromosome chrUn_JTFH01000123v1_decoy
# 	Skipping chromosome chrUn_JTFH01000124v1_decoy
# 	Skipping chromosome chrUn_JTFH01000125v1_decoy
# 	Skipping chromosome chrUn_JTFH01000126v1_decoy
# 	Skipping chromosome chrUn_JTFH01000127v1_decoy
# 	Skipping chromosome chrUn_JTFH01000128v1_decoy
# 	Skipping chromosome chrUn_JTFH01000129v1_decoy
# 	Skipping chromosome chrUn_JTFH01000130v1_decoy
# 	Skipping chromosome chrUn_JTFH01000131v1_decoy
# 	Skipping chromosome chrUn_JTFH01000132v1_decoy
# 	Skipping chromosome chrUn_JTFH01000133v1_decoy
# 	Skipping chromosome chrUn_JTFH01000134v1_decoy
# 	Skipping chromosome chrUn_JTFH01000135v1_decoy
# 	Skipping chromosome chrUn_JTFH01000136v1_decoy
# 	Skipping chromosome chrUn_JTFH01000137v1_decoy
# 	Skipping chromosome chrUn_JTFH01000138v1_decoy
# 	Skipping chromosome chrUn_JTFH01000139v1_decoy
# 	Skipping chromosome chrUn_JTFH01000140v1_decoy
# 	Skipping chromosome chrUn_JTFH01000141v1_decoy
# 	Skipping chromosome chrUn_JTFH01000142v1_decoy
# 	Skipping chromosome chrUn_JTFH01000143v1_decoy
# 	Skipping chromosome chrUn_JTFH01000144v1_decoy
# 	Skipping chromosome chrUn_JTFH01000145v1_decoy
# 	Skipping chromosome chrUn_JTFH01000146v1_decoy
# 	Skipping chromosome chrUn_JTFH01000147v1_decoy
# 	Skipping chromosome chrUn_JTFH01000148v1_decoy
# 	Skipping chromosome chrUn_JTFH01000149v1_decoy
# 	Skipping chromosome chrUn_JTFH01000150v1_decoy
# 	Skipping chromosome chrUn_JTFH01000151v1_decoy
# 	Skipping chromosome chrUn_JTFH01000152v1_decoy
# 	Skipping chromosome chrUn_JTFH01000153v1_decoy
# 	Skipping chromosome chrUn_JTFH01000154v1_decoy
# 	Skipping chromosome chrUn_JTFH01000155v1_decoy
# 	Skipping chromosome chrUn_JTFH01000156v1_decoy
# 	Skipping chromosome chrUn_JTFH01000157v1_decoy
# 	Skipping chromosome chrUn_JTFH01000158v1_decoy
# 	Skipping chromosome chrUn_JTFH01000159v1_decoy
# 	Skipping chromosome chrUn_JTFH01000160v1_decoy
# 	Skipping chromosome chrUn_JTFH01000161v1_decoy
# 	Skipping chromosome chrUn_JTFH01000162v1_decoy
# 	Skipping chromosome chrUn_JTFH01000163v1_decoy
# 	Skipping chromosome chrUn_JTFH01000164v1_decoy
# 	Skipping chromosome chrUn_JTFH01000165v1_decoy
# 	Skipping chromosome chrUn_JTFH01000166v1_decoy
# 	Skipping chromosome chrUn_JTFH01000167v1_decoy
# 	Skipping chromosome chrUn_JTFH01000168v1_decoy
# 	Skipping chromosome chrUn_JTFH01000169v1_decoy
# 	Skipping chromosome chrUn_JTFH01000170v1_decoy
# 	Skipping chromosome chrUn_JTFH01000171v1_decoy
# 	Skipping chromosome chrUn_JTFH01000172v1_decoy
# 	Skipping chromosome chrUn_JTFH01000173v1_decoy
# 	Skipping chromosome chrUn_JTFH01000174v1_decoy
# 	Skipping chromosome chrUn_JTFH01000175v1_decoy
# 	Skipping chromosome chrUn_JTFH01000176v1_decoy
# 	Skipping chromosome chrUn_JTFH01000177v1_decoy
# 	Skipping chromosome chrUn_JTFH01000178v1_decoy
# 	Skipping chromosome chrUn_JTFH01000179v1_decoy
# 	Skipping chromosome chrUn_JTFH01000180v1_decoy
# 	Skipping chromosome chrUn_JTFH01000181v1_decoy
# 	Skipping chromosome chrUn_JTFH01000182v1_decoy
# 	Skipping chromosome chrUn_JTFH01000183v1_decoy
# 	Skipping chromosome chrUn_JTFH01000184v1_decoy
# 	Skipping chromosome chrUn_JTFH01000185v1_decoy
# 	Skipping chromosome chrUn_JTFH01000186v1_decoy
# 	Skipping chromosome chrUn_JTFH01000187v1_decoy
# 	Skipping chromosome chrUn_JTFH01000188v1_decoy
# 	Skipping chromosome chrUn_JTFH01000189v1_decoy
# 	Skipping chromosome chrUn_JTFH01000190v1_decoy
# 	Skipping chromosome chrUn_JTFH01000191v1_decoy
# 	Skipping chromosome chrUn_JTFH01000192v1_decoy
# 	Skipping chromosome chrUn_JTFH01000193v1_decoy
# 	Skipping chromosome chrUn_JTFH01000194v1_decoy
# 	Skipping chromosome chrUn_JTFH01000195v1_decoy
# 	Skipping chromosome chrUn_JTFH01000196v1_decoy
# 	Skipping chromosome chrUn_JTFH01000197v1_decoy
# 	Skipping chromosome chrUn_JTFH01000198v1_decoy
# 	Skipping chromosome chrUn_JTFH01000199v1_decoy
# 	Skipping chromosome chrUn_JTFH01000200v1_decoy
# 	Skipping chromosome chrUn_JTFH01000201v1_decoy
# 	Skipping chromosome chrUn_JTFH01000202v1_decoy
# 	Skipping chromosome chrUn_JTFH01000203v1_decoy
# 	Skipping chromosome chrUn_JTFH01000204v1_decoy
# 	Skipping chromosome chrUn_JTFH01000205v1_decoy
# 	Skipping chromosome chrUn_JTFH01000206v1_decoy
# 	Skipping chromosome chrUn_JTFH01000207v1_decoy
# 	Skipping chromosome chrUn_JTFH01000208v1_decoy
# 	Skipping chromosome chrUn_JTFH01000209v1_decoy
# 	Skipping chromosome chrUn_JTFH01000210v1_decoy
# 	Skipping chromosome chrUn_JTFH01000211v1_decoy
# 	Skipping chromosome chrUn_JTFH01000212v1_decoy
# 	Skipping chromosome chrUn_JTFH01000213v1_decoy
# 	Skipping chromosome chrUn_JTFH01000214v1_decoy
# 	Skipping chromosome chrUn_JTFH01000215v1_decoy
# 	Skipping chromosome chrUn_JTFH01000216v1_decoy
# 	Skipping chromosome chrUn_JTFH01000217v1_decoy
# 	Skipping chromosome chrUn_JTFH01000218v1_decoy
# 	Skipping chromosome chrUn_JTFH01000219v1_decoy
# 	Skipping chromosome chrUn_JTFH01000220v1_decoy
# 	Skipping chromosome chrUn_JTFH01000221v1_decoy
# 	Skipping chromosome chrUn_JTFH01000222v1_decoy
# 	Skipping chromosome chrUn_JTFH01000223v1_decoy
# 	Skipping chromosome chrUn_JTFH01000224v1_decoy
# 	Skipping chromosome chrUn_JTFH01000225v1_decoy
# 	Skipping chromosome chrUn_JTFH01000226v1_decoy
# 	Skipping chromosome chrUn_JTFH01000227v1_decoy
# 	Skipping chromosome chrUn_JTFH01000228v1_decoy
# 	Skipping chromosome chrUn_JTFH01000229v1_decoy
# 	Skipping chromosome chrUn_JTFH01000230v1_decoy
# 	Skipping chromosome chrUn_JTFH01000231v1_decoy
# 	Skipping chromosome chrUn_JTFH01000232v1_decoy
# 	Skipping chromosome chrUn_JTFH01000233v1_decoy
# 	Skipping chromosome chrUn_JTFH01000234v1_decoy
# 	Skipping chromosome chrUn_JTFH01000235v1_decoy
# 	Skipping chromosome chrUn_JTFH01000236v1_decoy
# 	Skipping chromosome chrUn_JTFH01000237v1_decoy
# 	Skipping chromosome chrUn_JTFH01000238v1_decoy
# 	Skipping chromosome chrUn_JTFH01000239v1_decoy
# 	Skipping chromosome chrUn_JTFH01000240v1_decoy
# 	Skipping chromosome chrUn_JTFH01000241v1_decoy
# 	Skipping chromosome chrUn_JTFH01000242v1_decoy
# 	Skipping chromosome chrUn_JTFH01000243v1_decoy
# 	Skipping chromosome chrUn_JTFH01000244v1_decoy
# 	Skipping chromosome chrUn_JTFH01000245v1_decoy
# 	Skipping chromosome chrUn_JTFH01000246v1_decoy
# 	Skipping chromosome chrUn_JTFH01000247v1_decoy
# 	Skipping chromosome chrUn_JTFH01000248v1_decoy
# 	Skipping chromosome chrUn_JTFH01000249v1_decoy
# 	Skipping chromosome chrUn_JTFH01000250v1_decoy
# 	Skipping chromosome chrUn_JTFH01000251v1_decoy
# 	Skipping chromosome chrUn_JTFH01000252v1_decoy
# 	Skipping chromosome chrUn_JTFH01000253v1_decoy
# 	Skipping chromosome chrUn_JTFH01000254v1_decoy
# 	Skipping chromosome chrUn_JTFH01000255v1_decoy
# 	Skipping chromosome chrUn_JTFH01000256v1_decoy
# 	Skipping chromosome chrUn_JTFH01000257v1_decoy
# 	Skipping chromosome chrUn_JTFH01000258v1_decoy
# 	Skipping chromosome chrUn_JTFH01000259v1_decoy
# 	Skipping chromosome chrUn_JTFH01000260v1_decoy
# 	Skipping chromosome chrUn_JTFH01000261v1_decoy
# 	Skipping chromosome chrUn_JTFH01000262v1_decoy
# 	Skipping chromosome chrUn_JTFH01000263v1_decoy
# 	Skipping chromosome chrUn_JTFH01000264v1_decoy
# 	Skipping chromosome chrUn_JTFH01000265v1_decoy
# 	Skipping chromosome chrUn_JTFH01000266v1_decoy
# 	Skipping chromosome chrUn_JTFH01000267v1_decoy
# 	Skipping chromosome chrUn_JTFH01000268v1_decoy
# 	Skipping chromosome chrUn_JTFH01000269v1_decoy
# 	Skipping chromosome chrUn_JTFH01000270v1_decoy
# 	Skipping chromosome chrUn_JTFH01000271v1_decoy
# 	Skipping chromosome chrUn_JTFH01000272v1_decoy
# 	Skipping chromosome chrUn_JTFH01000273v1_decoy
# 	Skipping chromosome chrUn_JTFH01000274v1_decoy
# 	Skipping chromosome chrUn_JTFH01000275v1_decoy
# 	Skipping chromosome chrUn_JTFH01000276v1_decoy
# 	Skipping chromosome chrUn_JTFH01000277v1_decoy
# 	Skipping chromosome chrUn_JTFH01000278v1_decoy
# 	Skipping chromosome chrUn_JTFH01000279v1_decoy
# 	Skipping chromosome chrUn_JTFH01000280v1_decoy
# 	Skipping chromosome chrUn_JTFH01000281v1_decoy
# 	Skipping chromosome chrUn_JTFH01000282v1_decoy
# 	Skipping chromosome chrUn_JTFH01000283v1_decoy
# 	Skipping chromosome chrUn_JTFH01000284v1_decoy
# 	Skipping chromosome chrUn_JTFH01000285v1_decoy
# 	Skipping chromosome chrUn_JTFH01000286v1_decoy
# 	Skipping chromosome chrUn_JTFH01000287v1_decoy
# 	Skipping chromosome chrUn_JTFH01000288v1_decoy
# 	Skipping chromosome chrUn_JTFH01000289v1_decoy
# 	Skipping chromosome chrUn_JTFH01000290v1_decoy
# 	Skipping chromosome chrUn_JTFH01000291v1_decoy
# 	Skipping chromosome chrUn_JTFH01000292v1_decoy
# 	Skipping chromosome chrUn_JTFH01000293v1_decoy
# 	Skipping chromosome chrUn_JTFH01000294v1_decoy
# 	Skipping chromosome chrUn_JTFH01000295v1_decoy
# 	Skipping chromosome chrUn_JTFH01000296v1_decoy
# 	Skipping chromosome chrUn_JTFH01000297v1_decoy
# 	Skipping chromosome chrUn_JTFH01000298v1_decoy
# 	Skipping chromosome chrUn_JTFH01000299v1_decoy
# 	Skipping chromosome chrUn_JTFH01000300v1_decoy
# 	Skipping chromosome chrUn_JTFH01000301v1_decoy
# 	Skipping chromosome chrUn_JTFH01000302v1_decoy
# 	Skipping chromosome chrUn_JTFH01000303v1_decoy
# 	Skipping chromosome chrUn_JTFH01000304v1_decoy
# 	Skipping chromosome chrUn_JTFH01000305v1_decoy
# 	Skipping chromosome chrUn_JTFH01000306v1_decoy
# 	Skipping chromosome chrUn_JTFH01000307v1_decoy
# 	Skipping chromosome chrUn_JTFH01000308v1_decoy
# 	Skipping chromosome chrUn_JTFH01000309v1_decoy
# 	Skipping chromosome chrUn_JTFH01000310v1_decoy
# 	Skipping chromosome chrUn_JTFH01000311v1_decoy
# 	Skipping chromosome chrUn_JTFH01000312v1_decoy
# 	Skipping chromosome chrUn_JTFH01000313v1_decoy
# 	Skipping chromosome chrUn_JTFH01000314v1_decoy
# 	Skipping chromosome chrUn_JTFH01000315v1_decoy
# 	Skipping chromosome chrUn_JTFH01000316v1_decoy
# 	Skipping chromosome chrUn_JTFH01000317v1_decoy
# 	Skipping chromosome chrUn_JTFH01000318v1_decoy
# 	Skipping chromosome chrUn_JTFH01000319v1_decoy
# 	Skipping chromosome chrUn_JTFH01000320v1_decoy
# 	Skipping chromosome chrUn_JTFH01000321v1_decoy
# 	Skipping chromosome chrUn_JTFH01000322v1_decoy
# 	Skipping chromosome chrUn_JTFH01000323v1_decoy
# 	Skipping chromosome chrUn_JTFH01000324v1_decoy
# 	Skipping chromosome chrUn_JTFH01000325v1_decoy
# 	Skipping chromosome chrUn_JTFH01000326v1_decoy
# 	Skipping chromosome chrUn_JTFH01000327v1_decoy
# 	Skipping chromosome chrUn_JTFH01000328v1_decoy
# 	Skipping chromosome chrUn_JTFH01000329v1_decoy
# 	Skipping chromosome chrUn_JTFH01000330v1_decoy
# 	Skipping chromosome chrUn_JTFH01000331v1_decoy
# 	Skipping chromosome chrUn_JTFH01000332v1_decoy
# 	Skipping chromosome chrUn_JTFH01000333v1_decoy
# 	Skipping chromosome chrUn_JTFH01000334v1_decoy
# 	Skipping chromosome chrUn_JTFH01000335v1_decoy
# 	Skipping chromosome chrUn_JTFH01000336v1_decoy
# 	Skipping chromosome chrUn_JTFH01000337v1_decoy
# 	Skipping chromosome chrUn_JTFH01000338v1_decoy
# 	Skipping chromosome chrUn_JTFH01000339v1_decoy
# 	Skipping chromosome chrUn_JTFH01000340v1_decoy
# 	Skipping chromosome chrUn_JTFH01000341v1_decoy
# 	Skipping chromosome chrUn_JTFH01000342v1_decoy
# 	Skipping chromosome chrUn_JTFH01000343v1_decoy
# 	Skipping chromosome chrUn_JTFH01000344v1_decoy
# 	Skipping chromosome chrUn_JTFH01000345v1_decoy
# 	Skipping chromosome chrUn_JTFH01000346v1_decoy
# 	Skipping chromosome chrUn_JTFH01000347v1_decoy
# 	Skipping chromosome chrUn_JTFH01000348v1_decoy
# 	Skipping chromosome chrUn_JTFH01000349v1_decoy
# 	Skipping chromosome chrUn_JTFH01000350v1_decoy
# 	Skipping chromosome chrUn_JTFH01000351v1_decoy
# 	Skipping chromosome chrUn_JTFH01000352v1_decoy
# 	Skipping chromosome chrUn_JTFH01000353v1_decoy
# 	Skipping chromosome chrUn_JTFH01000354v1_decoy
# 	Skipping chromosome chrUn_JTFH01000355v1_decoy
# 	Skipping chromosome chrUn_JTFH01000356v1_decoy
# 	Skipping chromosome chrUn_JTFH01000357v1_decoy
# 	Skipping chromosome chrUn_JTFH01000358v1_decoy
# 	Skipping chromosome chrUn_JTFH01000359v1_decoy
# 	Skipping chromosome chrUn_JTFH01000360v1_decoy
# 	Skipping chromosome chrUn_JTFH01000361v1_decoy
# 	Skipping chromosome chrUn_JTFH01000362v1_decoy
# 	Skipping chromosome chrUn_JTFH01000363v1_decoy
# 	Skipping chromosome chrUn_JTFH01000364v1_decoy
# 	Skipping chromosome chrUn_JTFH01000365v1_decoy
# 	Skipping chromosome chrUn_JTFH01000366v1_decoy
# 	Skipping chromosome chrUn_JTFH01000367v1_decoy
# 	Skipping chromosome chrUn_JTFH01000368v1_decoy
# 	Skipping chromosome chrUn_JTFH01000369v1_decoy
# 	Skipping chromosome chrUn_JTFH01000370v1_decoy
# 	Skipping chromosome chrUn_JTFH01000371v1_decoy
# 	Skipping chromosome chrUn_JTFH01000372v1_decoy
# 	Skipping chromosome chrUn_JTFH01000373v1_decoy
# 	Skipping chromosome chrUn_JTFH01000374v1_decoy
# 	Skipping chromosome chrUn_JTFH01000375v1_decoy
# 	Skipping chromosome chrUn_JTFH01000376v1_decoy
# 	Skipping chromosome chrUn_JTFH01000377v1_decoy
# 	Skipping chromosome chrUn_JTFH01000378v1_decoy
# 	Skipping chromosome chrUn_JTFH01000379v1_decoy
# 	Skipping chromosome chrUn_JTFH01000380v1_decoy
# 	Skipping chromosome chrUn_JTFH01000381v1_decoy
# 	Skipping chromosome chrUn_JTFH01000382v1_decoy
# 	Skipping chromosome chrUn_JTFH01000383v1_decoy
# 	Skipping chromosome chrUn_JTFH01000384v1_decoy
# 	Skipping chromosome chrUn_JTFH01000385v1_decoy
# 	Skipping chromosome chrUn_JTFH01000386v1_decoy
# 	Skipping chromosome chrUn_JTFH01000387v1_decoy
# 	Skipping chromosome chrUn_JTFH01000388v1_decoy
# 	Skipping chromosome chrUn_JTFH01000389v1_decoy
# 	Skipping chromosome chrUn_JTFH01000390v1_decoy
# 	Skipping chromosome chrUn_JTFH01000391v1_decoy
# 	Skipping chromosome chrUn_JTFH01000392v1_decoy
# 	Skipping chromosome chrUn_JTFH01000393v1_decoy
# 	Skipping chromosome chrUn_JTFH01000394v1_decoy
# 	Skipping chromosome chrUn_JTFH01000395v1_decoy
# 	Skipping chromosome chrUn_JTFH01000396v1_decoy
# 	Skipping chromosome chrUn_JTFH01000397v1_decoy
# 	Skipping chromosome chrUn_JTFH01000398v1_decoy
# 	Skipping chromosome chrUn_JTFH01000399v1_decoy
# 	Skipping chromosome chrUn_JTFH01000400v1_decoy
# 	Skipping chromosome chrUn_JTFH01000401v1_decoy
# 	Skipping chromosome chrUn_JTFH01000402v1_decoy
# 	Skipping chromosome chrUn_JTFH01000403v1_decoy
# 	Skipping chromosome chrUn_JTFH01000404v1_decoy
# 	Skipping chromosome chrUn_JTFH01000405v1_decoy
# 	Skipping chromosome chrUn_JTFH01000406v1_decoy
# 	Skipping chromosome chrUn_JTFH01000407v1_decoy
# 	Skipping chromosome chrUn_JTFH01000408v1_decoy
# 	Skipping chromosome chrUn_JTFH01000409v1_decoy
# 	Skipping chromosome chrUn_JTFH01000410v1_decoy
# 	Skipping chromosome chrUn_JTFH01000411v1_decoy
# 	Skipping chromosome chrUn_JTFH01000412v1_decoy
# 	Skipping chromosome chrUn_JTFH01000413v1_decoy
# 	Skipping chromosome chrUn_JTFH01000414v1_decoy
# 	Skipping chromosome chrUn_JTFH01000415v1_decoy
# 	Skipping chromosome chrUn_JTFH01000416v1_decoy
# 	Skipping chromosome chrUn_JTFH01000417v1_decoy
# 	Skipping chromosome chrUn_JTFH01000418v1_decoy
# 	Skipping chromosome chrUn_JTFH01000419v1_decoy
# 	Skipping chromosome chrUn_JTFH01000420v1_decoy
# 	Skipping chromosome chrUn_JTFH01000421v1_decoy
# 	Skipping chromosome chrUn_JTFH01000422v1_decoy
# 	Skipping chromosome chrUn_JTFH01000423v1_decoy
# 	Skipping chromosome chrUn_JTFH01000424v1_decoy
# 	Skipping chromosome chrUn_JTFH01000425v1_decoy
# 	Skipping chromosome chrUn_JTFH01000426v1_decoy
# 	Skipping chromosome chrUn_JTFH01000427v1_decoy
# 	Skipping chromosome chrUn_JTFH01000428v1_decoy
# 	Skipping chromosome chrUn_JTFH01000429v1_decoy
# 	Skipping chromosome chrUn_JTFH01000430v1_decoy
# 	Skipping chromosome chrUn_JTFH01000431v1_decoy
# 	Skipping chromosome chrUn_JTFH01000432v1_decoy
# 	Skipping chromosome chrUn_JTFH01000433v1_decoy
# 	Skipping chromosome chrUn_JTFH01000434v1_decoy
# 	Skipping chromosome chrUn_JTFH01000435v1_decoy
# 	Skipping chromosome chrUn_JTFH01000436v1_decoy
# 	Skipping chromosome chrUn_JTFH01000437v1_decoy
# 	Skipping chromosome chrUn_JTFH01000438v1_decoy
# 	Skipping chromosome chrUn_JTFH01000439v1_decoy
# 	Skipping chromosome chrUn_JTFH01000440v1_decoy
# 	Skipping chromosome chrUn_JTFH01000441v1_decoy
# 	Skipping chromosome chrUn_JTFH01000442v1_decoy
# 	Skipping chromosome chrUn_JTFH01000443v1_decoy
# 	Skipping chromosome chrUn_JTFH01000444v1_decoy
# 	Skipping chromosome chrUn_JTFH01000445v1_decoy
# 	Skipping chromosome chrUn_JTFH01000446v1_decoy
# 	Skipping chromosome chrUn_JTFH01000447v1_decoy
# 	Skipping chromosome chrUn_JTFH01000448v1_decoy
# 	Skipping chromosome chrUn_JTFH01000449v1_decoy
# 	Skipping chromosome chrUn_JTFH01000450v1_decoy
# 	Skipping chromosome chrUn_JTFH01000451v1_decoy
# 	Skipping chromosome chrUn_JTFH01000452v1_decoy
# 	Skipping chromosome chrUn_JTFH01000453v1_decoy
# 	Skipping chromosome chrUn_JTFH01000454v1_decoy
# 	Skipping chromosome chrUn_JTFH01000455v1_decoy
# 	Skipping chromosome chrUn_JTFH01000456v1_decoy
# 	Skipping chromosome chrUn_JTFH01000457v1_decoy
# 	Skipping chromosome chrUn_JTFH01000458v1_decoy
# 	Skipping chromosome chrUn_JTFH01000459v1_decoy
# 	Skipping chromosome chrUn_JTFH01000460v1_decoy
# 	Skipping chromosome chrUn_JTFH01000461v1_decoy
# 	Skipping chromosome chrUn_JTFH01000462v1_decoy
# 	Skipping chromosome chrUn_JTFH01000463v1_decoy
# 	Skipping chromosome chrUn_JTFH01000464v1_decoy
# 	Skipping chromosome chrUn_JTFH01000465v1_decoy
# 	Skipping chromosome chrUn_JTFH01000466v1_decoy
# 	Skipping chromosome chrUn_JTFH01000467v1_decoy
# 	Skipping chromosome chrUn_JTFH01000468v1_decoy
# 	Skipping chromosome chrUn_JTFH01000469v1_decoy
# 	Skipping chromosome chrUn_JTFH01000470v1_decoy
# 	Skipping chromosome chrUn_JTFH01000471v1_decoy
# 	Skipping chromosome chrUn_JTFH01000472v1_decoy
# 	Skipping chromosome chrUn_JTFH01000473v1_decoy
# 	Skipping chromosome chrUn_JTFH01000474v1_decoy
# 	Skipping chromosome chrUn_JTFH01000475v1_decoy
# 	Skipping chromosome chrUn_JTFH01000476v1_decoy
# 	Skipping chromosome chrUn_JTFH01000477v1_decoy
# 	Skipping chromosome chrUn_JTFH01000478v1_decoy
# 	Skipping chromosome chrUn_JTFH01000479v1_decoy
# 	Skipping chromosome chrUn_JTFH01000480v1_decoy
# 	Skipping chromosome chrUn_JTFH01000481v1_decoy
# 	Skipping chromosome chrUn_JTFH01000482v1_decoy
# 	Skipping chromosome chrUn_JTFH01000483v1_decoy
# 	Skipping chromosome chrUn_JTFH01000484v1_decoy
# 	Skipping chromosome chrUn_JTFH01000485v1_decoy
# 	Skipping chromosome chrUn_JTFH01000486v1_decoy
# 	Skipping chromosome chrUn_JTFH01000487v1_decoy
# 	Skipping chromosome chrUn_JTFH01000488v1_decoy
# 	Skipping chromosome chrUn_JTFH01000489v1_decoy
# 	Skipping chromosome chrUn_JTFH01000490v1_decoy
# 	Skipping chromosome chrUn_JTFH01000491v1_decoy
# 	Skipping chromosome chrUn_JTFH01000492v1_decoy
# 	Skipping chromosome chrUn_JTFH01000493v1_decoy
# 	Skipping chromosome chrUn_JTFH01000494v1_decoy
# 	Skipping chromosome chrUn_JTFH01000495v1_decoy
# 	Skipping chromosome chrUn_JTFH01000496v1_decoy
# 	Skipping chromosome chrUn_JTFH01000497v1_decoy
# 	Skipping chromosome chrUn_JTFH01000498v1_decoy
# 	Skipping chromosome chrUn_JTFH01000499v1_decoy
# 	Skipping chromosome chrUn_JTFH01000500v1_decoy
# 	Skipping chromosome chrUn_JTFH01000501v1_decoy
# ...
# 	Skipping chromosome chrUn_JTFH01001667v1_decoy
# 	Skipping chromosome chrUn_JTFH01001668v1_decoy
# 	Skipping chromosome chrUn_JTFH01001669v1_decoy
# 	Skipping chromosome chrUn_JTFH01001670v1_decoy
# 	Skipping chromosome chrUn_JTFH01001671v1_decoy
# 	Skipping chromosome chrUn_JTFH01001672v1_decoy
# 	Skipping chromosome chrUn_JTFH01001673v1_decoy
# 	Skipping chromosome chrUn_JTFH01001674v1_decoy
# 	Skipping chromosome chrUn_JTFH01001675v1_decoy
# 	Skipping chromosome chrUn_JTFH01001676v1_decoy
# 	Skipping chromosome chrUn_JTFH01001677v1_decoy
# 	Skipping chromosome chrUn_JTFH01001678v1_decoy
# 	Skipping chromosome chrUn_JTFH01001679v1_decoy
# 	Skipping chromosome chrUn_JTFH01001680v1_decoy
# 	Skipping chromosome chrUn_JTFH01001681v1_decoy
# 	Skipping chromosome chrUn_JTFH01001682v1_decoy
# 	Skipping chromosome chrUn_JTFH01001683v1_decoy
# 	Skipping chromosome chrUn_JTFH01001684v1_decoy
# 	Skipping chromosome chrUn_JTFH01001685v1_decoy
# 	Skipping chromosome chrUn_JTFH01001686v1_decoy
# 	Skipping chromosome chrUn_JTFH01001687v1_decoy
# 	Skipping chromosome chrUn_JTFH01001688v1_decoy
# 	Skipping chromosome chrUn_JTFH01001689v1_decoy
# 	Skipping chromosome chrUn_JTFH01001690v1_decoy
# 	Skipping chromosome chrUn_JTFH01001691v1_decoy
# 	Skipping chromosome chrUn_JTFH01001692v1_decoy
# 	Skipping chromosome chrUn_JTFH01001693v1_decoy
# 	Skipping chromosome chrUn_JTFH01001694v1_decoy
# 	Skipping chromosome chrUn_JTFH01001695v1_decoy
# 	Skipping chromosome chrUn_JTFH01001696v1_decoy
# 	Skipping chromosome chrUn_JTFH01001697v1_decoy
# 	Skipping chromosome chrUn_JTFH01001698v1_decoy
# 	Skipping chromosome chrUn_JTFH01001699v1_decoy
# 	Skipping chromosome chrUn_JTFH01001700v1_decoy
# 	Skipping chromosome chrUn_JTFH01001701v1_decoy
# 	Skipping chromosome chrUn_JTFH01001702v1_decoy
# 	Skipping chromosome chrUn_JTFH01001703v1_decoy
# 	Skipping chromosome chrUn_JTFH01001704v1_decoy
# 	Skipping chromosome chrUn_JTFH01001705v1_decoy
# 	Skipping chromosome chrUn_JTFH01001706v1_decoy
# 	Skipping chromosome chrUn_JTFH01001707v1_decoy
# 	Skipping chromosome chrUn_JTFH01001708v1_decoy
# 	Skipping chromosome chrUn_JTFH01001709v1_decoy
# 	Skipping chromosome chrUn_JTFH01001710v1_decoy
# 	Skipping chromosome chrUn_JTFH01001711v1_decoy
# 	Skipping chromosome chrUn_JTFH01001712v1_decoy
# 	Skipping chromosome chrUn_JTFH01001713v1_decoy
# 	Skipping chromosome chrUn_JTFH01001714v1_decoy
# 	Skipping chromosome chrUn_JTFH01001715v1_decoy
# 	Skipping chromosome chrUn_JTFH01001716v1_decoy
# 	Skipping chromosome chrUn_JTFH01001717v1_decoy
# 	Skipping chromosome chrUn_JTFH01001718v1_decoy
# 	Skipping chromosome chrUn_JTFH01001719v1_decoy
# 	Skipping chromosome chrUn_JTFH01001720v1_decoy
# 	Skipping chromosome chrUn_JTFH01001721v1_decoy
# 	Skipping chromosome chrUn_JTFH01001722v1_decoy
# 	Skipping chromosome chrUn_JTFH01001723v1_decoy
# 	Skipping chromosome chrUn_JTFH01001724v1_decoy
# 	Skipping chromosome chrUn_JTFH01001725v1_decoy
# 	Skipping chromosome chrUn_JTFH01001726v1_decoy
# 	Skipping chromosome chrUn_JTFH01001727v1_decoy
# 	Skipping chromosome chrUn_JTFH01001728v1_decoy
# 	Skipping chromosome chrUn_JTFH01001729v1_decoy
# 	Skipping chromosome chrUn_JTFH01001730v1_decoy
# 	Skipping chromosome chrUn_JTFH01001731v1_decoy
# 	Skipping chromosome chrUn_JTFH01001732v1_decoy
# 	Skipping chromosome chrUn_JTFH01001733v1_decoy
# 	Skipping chromosome chrUn_JTFH01001734v1_decoy
# 	Skipping chromosome chrUn_JTFH01001735v1_decoy
# 	Skipping chromosome chrUn_JTFH01001736v1_decoy
# 	Skipping chromosome chrUn_JTFH01001737v1_decoy
# 	Skipping chromosome chrUn_JTFH01001738v1_decoy
# 	Skipping chromosome chrUn_JTFH01001739v1_decoy
# 	Skipping chromosome chrUn_JTFH01001740v1_decoy
# 	Skipping chromosome chrUn_JTFH01001741v1_decoy
# 	Skipping chromosome chrUn_JTFH01001742v1_decoy
# 	Skipping chromosome chrUn_JTFH01001743v1_decoy
# 	Skipping chromosome chrUn_JTFH01001744v1_decoy
# 	Skipping chromosome chrUn_JTFH01001745v1_decoy
# 	Skipping chromosome chrUn_JTFH01001746v1_decoy
# 	Skipping chromosome chrUn_JTFH01001747v1_decoy
# 	Skipping chromosome chrUn_JTFH01001748v1_decoy
# 	Skipping chromosome chrUn_JTFH01001749v1_decoy
# 	Skipping chromosome chrUn_JTFH01001750v1_decoy
# 	Skipping chromosome chrUn_JTFH01001751v1_decoy
# 	Skipping chromosome chrUn_JTFH01001752v1_decoy
# 	Skipping chromosome chrUn_JTFH01001753v1_decoy
# 	Skipping chromosome chrUn_JTFH01001754v1_decoy
# 	Skipping chromosome chrUn_JTFH01001755v1_decoy
# 	Skipping chromosome chrUn_JTFH01001756v1_decoy
# 	Skipping chromosome chrUn_JTFH01001757v1_decoy
# 	Skipping chromosome chrUn_JTFH01001758v1_decoy
# 	Skipping chromosome chrUn_JTFH01001759v1_decoy
# 	Skipping chromosome chrUn_JTFH01001760v1_decoy
# 	Skipping chromosome chrUn_JTFH01001761v1_decoy
# 	Skipping chromosome chrUn_JTFH01001762v1_decoy
# 	Skipping chromosome chrUn_JTFH01001763v1_decoy
# 	Skipping chromosome chrUn_JTFH01001764v1_decoy
# 	Skipping chromosome chrUn_JTFH01001765v1_decoy
# 	Skipping chromosome chrUn_JTFH01001766v1_decoy
# 	Skipping chromosome chrUn_JTFH01001767v1_decoy
# 	Skipping chromosome chrUn_JTFH01001768v1_decoy
# 	Skipping chromosome chrUn_JTFH01001769v1_decoy
# 	Skipping chromosome chrUn_JTFH01001770v1_decoy
# 	Skipping chromosome chrUn_JTFH01001771v1_decoy
# 	Skipping chromosome chrUn_JTFH01001772v1_decoy
# 	Skipping chromosome chrUn_JTFH01001773v1_decoy
# 	Skipping chromosome chrUn_JTFH01001774v1_decoy
# 	Skipping chromosome chrUn_JTFH01001775v1_decoy
# 	Skipping chromosome chrUn_JTFH01001776v1_decoy
# 	Skipping chromosome chrUn_JTFH01001777v1_decoy
# 	Skipping chromosome chrUn_JTFH01001778v1_decoy
# 	Skipping chromosome chrUn_JTFH01001779v1_decoy
# 	Skipping chromosome chrUn_JTFH01001780v1_decoy
# 	Skipping chromosome chrUn_JTFH01001781v1_decoy
# 	Skipping chromosome chrUn_JTFH01001782v1_decoy
# 	Skipping chromosome chrUn_JTFH01001783v1_decoy
# 	Skipping chromosome chrUn_JTFH01001784v1_decoy
# 	Skipping chromosome chrUn_JTFH01001785v1_decoy
# 	Skipping chromosome chrUn_JTFH01001786v1_decoy
# 	Skipping chromosome chrUn_JTFH01001787v1_decoy
# 	Skipping chromosome chrUn_JTFH01001788v1_decoy
# 	Skipping chromosome chrUn_JTFH01001789v1_decoy
# 	Skipping chromosome chrUn_JTFH01001790v1_decoy
# 	Skipping chromosome chrUn_JTFH01001791v1_decoy
# 	Skipping chromosome chrUn_JTFH01001792v1_decoy
# 	Skipping chromosome chrUn_JTFH01001793v1_decoy
# 	Skipping chromosome chrUn_JTFH01001794v1_decoy
# 	Skipping chromosome chrUn_JTFH01001795v1_decoy
# 	Skipping chromosome chrUn_JTFH01001796v1_decoy
# 	Skipping chromosome chrUn_JTFH01001797v1_decoy
# 	Skipping chromosome chrUn_JTFH01001798v1_decoy
# 	Skipping chromosome chrUn_JTFH01001799v1_decoy
# 	Skipping chromosome chrUn_JTFH01001800v1_decoy
# 	Skipping chromosome chrUn_JTFH01001801v1_decoy
# 	Skipping chromosome chrUn_JTFH01001802v1_decoy
# 	Skipping chromosome chrUn_JTFH01001803v1_decoy
# 	Skipping chromosome chrUn_JTFH01001804v1_decoy
# 	Skipping chromosome chrUn_JTFH01001805v1_decoy
# 	Skipping chromosome chrUn_JTFH01001806v1_decoy
# 	Skipping chromosome chrUn_JTFH01001807v1_decoy
# 	Skipping chromosome chrUn_JTFH01001808v1_decoy
# 	Skipping chromosome chrUn_JTFH01001809v1_decoy
# 	Skipping chromosome chrUn_JTFH01001810v1_decoy
# 	Skipping chromosome chrUn_JTFH01001811v1_decoy
# 	Skipping chromosome chrUn_JTFH01001812v1_decoy
# 	Skipping chromosome chrUn_JTFH01001813v1_decoy
# 	Skipping chromosome chrUn_JTFH01001814v1_decoy
# 	Skipping chromosome chrUn_JTFH01001815v1_decoy
# 	Skipping chromosome chrUn_JTFH01001816v1_decoy
# 	Skipping chromosome chrUn_JTFH01001817v1_decoy
# 	Skipping chromosome chrUn_JTFH01001818v1_decoy
# 	Skipping chromosome chrUn_JTFH01001819v1_decoy
# 	Skipping chromosome chrUn_JTFH01001820v1_decoy
# 	Skipping chromosome chrUn_JTFH01001821v1_decoy
# 	Skipping chromosome chrUn_JTFH01001822v1_decoy
# 	Skipping chromosome chrUn_JTFH01001823v1_decoy
# 	Skipping chromosome chrUn_JTFH01001824v1_decoy
# 	Skipping chromosome chrUn_JTFH01001825v1_decoy
# 	Skipping chromosome chrUn_JTFH01001826v1_decoy
# 	Skipping chromosome chrUn_JTFH01001827v1_decoy
# 	Skipping chromosome chrUn_JTFH01001828v1_decoy
# 	Skipping chromosome chrUn_JTFH01001829v1_decoy
# 	Skipping chromosome chrUn_JTFH01001830v1_decoy
# 	Skipping chromosome chrUn_JTFH01001831v1_decoy
# 	Skipping chromosome chrUn_JTFH01001832v1_decoy
# 	Skipping chromosome chrUn_JTFH01001833v1_decoy
# 	Skipping chromosome chrUn_JTFH01001834v1_decoy
# 	Skipping chromosome chrUn_JTFH01001835v1_decoy
# 	Skipping chromosome chrUn_JTFH01001836v1_decoy
# 	Skipping chromosome chrUn_JTFH01001837v1_decoy
# 	Skipping chromosome chrUn_JTFH01001838v1_decoy
# 	Skipping chromosome chrUn_JTFH01001839v1_decoy
# 	Skipping chromosome chrUn_JTFH01001840v1_decoy
# 	Skipping chromosome chrUn_JTFH01001841v1_decoy
# 	Skipping chromosome chrUn_JTFH01001842v1_decoy
# 	Skipping chromosome chrUn_JTFH01001843v1_decoy
# 	Skipping chromosome chrUn_JTFH01001844v1_decoy
# 	Skipping chromosome chrUn_JTFH01001845v1_decoy
# 	Skipping chromosome chrUn_JTFH01001846v1_decoy
# 	Skipping chromosome chrUn_JTFH01001847v1_decoy
# 	Skipping chromosome chrUn_JTFH01001848v1_decoy
# 	Skipping chromosome chrUn_JTFH01001849v1_decoy
# 	Skipping chromosome chrUn_JTFH01001850v1_decoy
# 	Skipping chromosome chrUn_JTFH01001851v1_decoy
# 	Skipping chromosome chrUn_JTFH01001852v1_decoy
# 	Skipping chromosome chrUn_JTFH01001853v1_decoy
# 	Skipping chromosome chrUn_JTFH01001854v1_decoy
# 	Skipping chromosome chrUn_JTFH01001855v1_decoy
# 	Skipping chromosome chrUn_JTFH01001856v1_decoy
# 	Skipping chromosome chrUn_JTFH01001857v1_decoy
# 	Skipping chromosome chrUn_JTFH01001858v1_decoy
# 	Skipping chromosome chrUn_JTFH01001859v1_decoy
# 	Skipping chromosome chrUn_JTFH01001860v1_decoy
# 	Skipping chromosome chrUn_JTFH01001861v1_decoy
# 	Skipping chromosome chrUn_JTFH01001862v1_decoy
# 	Skipping chromosome chrUn_JTFH01001863v1_decoy
# 	Skipping chromosome chrUn_JTFH01001864v1_decoy
# 	Skipping chromosome chrUn_JTFH01001865v1_decoy
# 	Skipping chromosome chrUn_JTFH01001866v1_decoy
# 	Skipping chromosome chrUn_JTFH01001867v1_decoy
# 	Skipping chromosome chrUn_JTFH01001868v1_decoy
# 	Skipping chromosome chrUn_JTFH01001869v1_decoy
# 	Skipping chromosome chrUn_JTFH01001870v1_decoy
# 	Skipping chromosome chrUn_JTFH01001871v1_decoy
# 	Skipping chromosome chrUn_JTFH01001872v1_decoy
# 	Skipping chromosome chrUn_JTFH01001873v1_decoy
# 	Skipping chromosome chrUn_JTFH01001874v1_decoy
# 	Skipping chromosome chrUn_JTFH01001875v1_decoy
# 	Skipping chromosome chrUn_JTFH01001876v1_decoy
# 	Skipping chromosome chrUn_JTFH01001877v1_decoy
# 	Skipping chromosome chrUn_JTFH01001878v1_decoy
# 	Skipping chromosome chrUn_JTFH01001879v1_decoy
# 	Skipping chromosome chrUn_JTFH01001880v1_decoy
# 	Skipping chromosome chrUn_JTFH01001881v1_decoy
# 	Skipping chromosome chrUn_JTFH01001882v1_decoy
# 	Skipping chromosome chrUn_JTFH01001883v1_decoy
# 	Skipping chromosome chrUn_JTFH01001884v1_decoy
# 	Skipping chromosome chrUn_JTFH01001885v1_decoy
# 	Skipping chromosome chrUn_JTFH01001886v1_decoy
# 	Skipping chromosome chrUn_JTFH01001887v1_decoy
# 	Skipping chromosome chrUn_JTFH01001888v1_decoy
# 	Skipping chromosome chrUn_JTFH01001889v1_decoy
# 	Skipping chromosome chrUn_JTFH01001890v1_decoy
# 	Skipping chromosome chrUn_JTFH01001891v1_decoy
# 	Skipping chromosome chrUn_JTFH01001892v1_decoy
# 	Skipping chromosome chrUn_JTFH01001893v1_decoy
# 	Skipping chromosome chrUn_JTFH01001894v1_decoy
# 	Skipping chromosome chrUn_JTFH01001895v1_decoy
# 	Skipping chromosome chrUn_JTFH01001896v1_decoy
# 	Skipping chromosome chrUn_JTFH01001897v1_decoy
# 	Skipping chromosome chrUn_JTFH01001898v1_decoy
# 	Skipping chromosome chrUn_JTFH01001899v1_decoy
# 	Skipping chromosome chrUn_JTFH01001900v1_decoy
# 	Skipping chromosome chrUn_JTFH01001901v1_decoy
# 	Skipping chromosome chrUn_JTFH01001902v1_decoy
# 	Skipping chromosome chrUn_JTFH01001903v1_decoy
# 	Skipping chromosome chrUn_JTFH01001904v1_decoy
# 	Skipping chromosome chrUn_JTFH01001905v1_decoy
# 	Skipping chromosome chrUn_JTFH01001906v1_decoy
# 	Skipping chromosome chrUn_JTFH01001907v1_decoy
# 	Skipping chromosome chrUn_JTFH01001908v1_decoy
# 	Skipping chromosome chrUn_JTFH01001909v1_decoy
# 	Skipping chromosome chrUn_JTFH01001910v1_decoy
# 	Skipping chromosome chrUn_JTFH01001911v1_decoy
# 	Skipping chromosome chrUn_JTFH01001912v1_decoy
# 	Skipping chromosome chrUn_JTFH01001913v1_decoy
# 	Skipping chromosome chrUn_JTFH01001914v1_decoy
# 	Skipping chromosome chrUn_JTFH01001915v1_decoy
# 	Skipping chromosome chrUn_JTFH01001916v1_decoy
# 	Skipping chromosome chrUn_JTFH01001917v1_decoy
# 	Skipping chromosome chrUn_JTFH01001918v1_decoy
# 	Skipping chromosome chrUn_JTFH01001919v1_decoy
# 	Skipping chromosome chrUn_JTFH01001920v1_decoy
# 	Skipping chromosome chrUn_JTFH01001921v1_decoy
# 	Skipping chromosome chrUn_JTFH01001922v1_decoy
# 	Skipping chromosome chrUn_JTFH01001923v1_decoy
# 	Skipping chromosome chrUn_JTFH01001924v1_decoy
# 	Skipping chromosome chrUn_JTFH01001925v1_decoy
# 	Skipping chromosome chrUn_JTFH01001926v1_decoy
# 	Skipping chromosome chrUn_JTFH01001927v1_decoy
# 	Skipping chromosome chrUn_JTFH01001928v1_decoy
# 	Skipping chromosome chrUn_JTFH01001929v1_decoy
# 	Skipping chromosome chrUn_JTFH01001930v1_decoy
# 	Skipping chromosome chrUn_JTFH01001931v1_decoy
# 	Skipping chromosome chrUn_JTFH01001932v1_decoy
# 	Skipping chromosome chrUn_JTFH01001933v1_decoy
# 	Skipping chromosome chrUn_JTFH01001934v1_decoy
# 	Skipping chromosome chrUn_JTFH01001935v1_decoy
# 	Skipping chromosome chrUn_JTFH01001936v1_decoy
# 	Skipping chromosome chrUn_JTFH01001937v1_decoy
# 	Skipping chromosome chrUn_JTFH01001938v1_decoy
# 	Skipping chromosome chrUn_JTFH01001939v1_decoy
# 	Skipping chromosome chrUn_JTFH01001940v1_decoy
# 	Skipping chromosome chrUn_JTFH01001941v1_decoy
# 	Skipping chromosome chrUn_JTFH01001942v1_decoy
# 	Skipping chromosome chrUn_JTFH01001943v1_decoy
# 	Skipping chromosome chrUn_JTFH01001944v1_decoy
# 	Skipping chromosome chrUn_JTFH01001945v1_decoy
# 	Skipping chromosome chrUn_JTFH01001946v1_decoy
# 	Skipping chromosome chrUn_JTFH01001947v1_decoy
# 	Skipping chromosome chrUn_JTFH01001948v1_decoy
# 	Skipping chromosome chrUn_JTFH01001949v1_decoy
# 	Skipping chromosome chrUn_JTFH01001950v1_decoy
# 	Skipping chromosome chrUn_JTFH01001951v1_decoy
# 	Skipping chromosome chrUn_JTFH01001952v1_decoy
# 	Skipping chromosome chrUn_JTFH01001953v1_decoy
# 	Skipping chromosome chrUn_JTFH01001954v1_decoy
# 	Skipping chromosome chrUn_JTFH01001955v1_decoy
# 	Skipping chromosome chrUn_JTFH01001956v1_decoy
# 	Skipping chromosome chrUn_JTFH01001957v1_decoy
# 	Skipping chromosome chrUn_JTFH01001958v1_decoy
# 	Skipping chromosome chrUn_JTFH01001959v1_decoy
# 	Skipping chromosome chrUn_JTFH01001960v1_decoy
# 	Skipping chromosome chrUn_JTFH01001961v1_decoy
# 	Skipping chromosome chrUn_JTFH01001962v1_decoy
# 	Skipping chromosome chrUn_JTFH01001963v1_decoy
# 	Skipping chromosome chrUn_JTFH01001964v1_decoy
# 	Skipping chromosome chrUn_JTFH01001965v1_decoy
# 	Skipping chromosome chrUn_JTFH01001966v1_decoy
# 	Skipping chromosome chrUn_JTFH01001967v1_decoy
# 	Skipping chromosome chrUn_JTFH01001968v1_decoy
# 	Skipping chromosome chrUn_JTFH01001969v1_decoy
# 	Skipping chromosome chrUn_JTFH01001970v1_decoy
# 	Skipping chromosome chrUn_JTFH01001971v1_decoy
# 	Skipping chromosome chrUn_JTFH01001972v1_decoy
# 	Skipping chromosome chrUn_JTFH01001973v1_decoy
# 	Skipping chromosome chrUn_JTFH01001974v1_decoy
# 	Skipping chromosome chrUn_JTFH01001975v1_decoy
# 	Skipping chromosome chrUn_JTFH01001976v1_decoy
# 	Skipping chromosome chrUn_JTFH01001977v1_decoy
# 	Skipping chromosome chrUn_JTFH01001978v1_decoy
# 	Skipping chromosome chrUn_JTFH01001979v1_decoy
# 	Skipping chromosome chrUn_JTFH01001980v1_decoy
# 	Skipping chromosome chrUn_JTFH01001981v1_decoy
# 	Skipping chromosome chrUn_JTFH01001982v1_decoy
# 	Skipping chromosome chrUn_JTFH01001983v1_decoy
# 	Skipping chromosome chrUn_JTFH01001984v1_decoy
# 	Skipping chromosome chrUn_JTFH01001985v1_decoy
# 	Skipping chromosome chrUn_JTFH01001986v1_decoy
# 	Skipping chromosome chrUn_JTFH01001987v1_decoy
# 	Skipping chromosome chrUn_JTFH01001988v1_decoy
# 	Skipping chromosome chrUn_JTFH01001989v1_decoy
# 	Skipping chromosome chrUn_JTFH01001990v1_decoy
# 	Skipping chromosome chrUn_JTFH01001991v1_decoy
# 	Skipping chromosome chrUn_JTFH01001992v1_decoy
# 	Skipping chromosome chrUn_JTFH01001993v1_decoy
# 	Skipping chromosome chrUn_JTFH01001994v1_decoy
# 	Skipping chromosome chrUn_JTFH01001995v1_decoy
# 	Skipping chromosome chrUn_JTFH01001996v1_decoy
# 	Skipping chromosome chrUn_JTFH01001997v1_decoy
# 	Skipping chromosome chrUn_JTFH01001998v1_decoy
# Saving cpg_sites_dict and chr_lengths to disk as json

# %%
cpg_sites_dict["chr1"][:10]
# Out:
# [10469, 10471, 10484, 10489, 10493, 10497, 10525, 10542, 10563, 10571]

# %%
# Write our cpg sites to a .bed
if not os.path.exists("cpg_sites.bed") and not IGNORE_CACHE:
    with open("cpg_sites.bed", "w") as f:
        for chrom in CHROMOSOMES:
            for pos in cpg_sites_dict[chrom]:
                # TODO: Double-check the zero-open half closed bed format
                f.write(f"{chrom}\t{pos}\t{pos+1}\n")

# %%
# Now that we parsed our CpG sites, let's print some statistics
# How many CpG sites are there?
total_cpg_sites = sum([len(v) for v in cpg_sites_dict.values()])
print(f"Total CpG sites: {total_cpg_sites:,}")

# Validity check for hg38
assert(total_cpg_sites>28_000_000)
# Out:
# Total CpG sites: 28,254,596

# %%
# Count the number of CpGs per chromosome
cpgs_per_chr = {k: len(v) for k, v in cpg_sites_dict.items()}

# Altair chart but don't sort the chromosomes
alt.Chart(pd.DataFrame({"chr": list(cpgs_per_chr.keys()), "cpgs": list(cpgs_per_chr.values())})).mark_bar().encode(
    x=alt.X("chr", sort=None),
    y="cpgs",
)
# Out:
# alt.Chart(...)

# %%
# Add up the number of CpGs per chromosome, e.g. chr1, then chr1+chr2, then chr1+chr2+chr3, etc
cpgs_per_chr_cumsum = np.cumsum([cpgs_per_chr[k] for k in CHROMOSOMES])

def embedding_to_genomic_position(embedding_pos):
    """
    Given an embedding position, return the chromosome and position.

    Parameters
    ----------
    embedding_pos : int
        The embedding position.

    Returns
    -------
    chr : str
        The chromosome.
    pos : int
        The position.
    """
    assert embedding_pos >= 0 and embedding_pos < total_cpg_sites

    # Find the index of the first element in cpgs_per_chr_cumsum that is greater than or equal to the embedding position
    chr_index = np.searchsorted(cpgs_per_chr_cumsum, embedding_pos+1, side="left")

    # Now we know the chromosome, but we need to find the position within the chromosome
    # If this is the first chromosome, the position is just the embedding position
    if chr_index == 0:
        return CHROMOSOMES[chr_index], cpg_sites_dict[CHROMOSOMES[chr_index]][embedding_pos]
    # Otherwise, subtract the length of the previous chromosomes from the embedding position
    embedding_pos -= cpgs_per_chr_cumsum[chr_index-1]
    return CHROMOSOMES[chr_index], cpg_sites_dict[CHROMOSOMES[chr_index]][embedding_pos]

# Tests
assert cpgs_per_chr_cumsum[-1] == total_cpg_sites
assert embedding_to_genomic_position(0) == ("chr1", cpg_sites_dict["chr1"][0])
assert embedding_to_genomic_position(1) == ("chr1", cpg_sites_dict["chr1"][1])
# Edges
assert embedding_to_genomic_position(cpgs_per_chr_cumsum[0]) == ("chr2", cpg_sites_dict["chr2"][0])
assert embedding_to_genomic_position(cpgs_per_chr_cumsum[-1]-1) == ("chrY", cpg_sites_dict["chrY"][-1])

# %%
def genomic_position_to_embedding(chrom, pos):
    """
    Given a genomic position, return the embedding position.

    Parameters
    ----------
    chrom : str
        The chromosome.
    pos : int
        The position.

    Returns
    -------
    embedding_pos : int
        The embedding position.
    """
    assert chrom in CHROMOSOMES
    
    # Find the index of the chromosome
    chr_index = CHROMOSOMES.index(chrom)
    # Find the index of the CpG site in the chromosome
    cpg_index = cpg_sites_dict[chrom].index(pos)
    # If this is the first chromosome, the embedding position is just the CpG index
    if chr_index == 0:
        return cpg_index
    # Otherwise, add the length of the previous chromosomes to the CpG index
    return cpg_index + cpgs_per_chr_cumsum[chr_index-1]
    
# Tests
assert genomic_position_to_embedding("chr1", cpg_sites_dict["chr1"][0]) == 0
assert genomic_position_to_embedding("chr1", cpg_sites_dict["chr1"][1]) == 1
# Edges
assert genomic_position_to_embedding("chr2", cpg_sites_dict["chr2"][0]) == cpgs_per_chr_cumsum[0]
assert genomic_position_to_embedding("chrY", cpg_sites_dict["chrY"][-1]) == cpgs_per_chr_cumsum[-1]-1

# %%
# Let's generate ranges (windows) of all CpGs within READ_SIZE of each other
# This is to subsequently query our .bam/.sam files for reads containing CpGs

# This is a dict of lists, where but each list contains a tuple of CpG ranges witin a window
# The key is the chromosome: e.g. "chr1"
# The value is a list of tuples: e.g. [(0,35), (190,212), (1055,)]
windowed_cpg_sites_dict = {}

# And a reverse dict of dicts where chrom->window_start->[cpgs]
windowed_cpg_sites_dict_reverse = {}

# Loop over all chromosomes
for chrom, cpg_sites in tqdm(cpg_sites_dict.items()):

    windowed_cpg_sites_dict[chrom] = []
    windowed_cpg_sites_dict_reverse[chrom] = {}
    window_start = None
    window_end = None

    # Loop over all CpG sites
    cpg_sites_len = len(cpg_sites)
    temp_per_window_cpg_sites = []
    for i in range(cpg_sites_len):
        temp_per_window_cpg_sites.append(cpg_sites[i])

        if window_start is None:
            window_start = cpg_sites[i]

        # If we're at the end of the chromosome or the next CpG site is too far away
        if i+1 == cpg_sites_len or (cpg_sites[i+1] - cpg_sites[i]) > READ_SIZE:
            # We have a complete window
            window_end = cpg_sites[i]
            windowed_cpg_sites_dict[chrom].append((window_start, window_end))
            windowed_cpg_sites_dict_reverse[chrom][window_start] = temp_per_window_cpg_sites
            temp_per_window_cpg_sites = []
            window_start = None
            window_end = None
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]

# %%
# Write windowed_cpg_sites_dict to a .bed file, which is just a tsv
with open("windowed_cpg_sites_dict.bed", "w") as f:
    for chrom, cpg_sites in windowed_cpg_sites_dict.items():
        for window_start, window_end in cpg_sites:
            f.write(f"{chrom}\t{window_start}\t{window_end}\n")

# %%
# Now we'll parse the aligned .bam files and export per-read methylation profiles

# TODO: Break this out into its own script, with arguments:
# - Input bam file
# - Reference genome
# - Window size

# PySam shifts most of the hard work to the C bindings, so it's not too bad.
# I tried a few other options to pre-process data but realistically they're all slow-ish:
#  - Biscuit's epibed/epiread format -- this works OK, but parsing the RLE-encoded string is tricky and not flexible with non-biscuit data (I suspect)
#  - samtools mpileup -- this can't exclude indels, which also makes for annoying parsing

QUALITY_THRESHOLD=20

# One sample bam file for PoC
# HEALTHY_BAM = "/r5n/liquid-cell-atlas/healthy/Healthy_B12_Nu-13_PBMC_emseq/Healthy_B12_Nu-13_PBMC_emseq.bam"
HEALTHY_BAM = "/home/semenko/sorted.tinysam.bam"
print(f"Loading: {os.path.basename(HEALTHY_BAM)}")

# We require an index for performance
input_bam = pysam.AlignmentFile(HEALTHY_BAM, "rb", require_index=True, threads=1)
print(f"Total reads: {input_bam.mapped}")


# Temporary storage for loading into a COO matrix
# For a COO, we want three lists:
# row: the read number (we'll store a read name -> ID dict perhaps?)
# column: cpg #
# data: methylation state (1 [methylated], -1 [unmethylated], and 0 [no data])

next_coo_row_number = 0
read_name_to_row_number = {}

coo_row = []
coo_col = []
coo_data = []


DEBUG = False
PARANOID = False
# DEBUG = False
start_time = time.time()
# This is slow, but we only run it once and store the results for later
for chrom, windowed_cpgs in tqdm(windowed_cpg_sites_dict.items()):
    for start_pos, stop_pos in windowed_cpgs:
        cpgs_within_window = windowed_cpg_sites_dict_reverse[chrom][start_pos]
        if DEBUG: print(f"\tPosition: {start_pos} - {stop_pos}")
        if DEBUG: print(f"\tCovered CpGs: {cpgs_within_window}")
        # cpgs_within_window = [10469]
        # This returns an AlignmentSegment object from PySam
        for aligned_segment in input_bam.fetch(contig=chrom, start=start_pos, end=stop_pos):
            if aligned_segment.mapping_quality < QUALITY_THRESHOLD:
                # if DEBUG: print(f"Skipping read {aligned_segment.query_name} with MAPQ {aligned_segment.mapping_quality} < {QUALITY_THRESHOLD}")
                continue

            if aligned_segment.is_duplicate:
                continue
            if aligned_segment.is_qcfail:
                continue
            if aligned_segment.is_secondary:
                continue

            if DEBUG: print(aligned_segment)

            if PARANOID:
                # Validity tests
                assert aligned_segment.is_mapped
                assert aligned_segment.is_supplementary is False
                assert aligned_segment.reference_start <= stop_pos
                assert aligned_segment.reference_end >= start_pos
                assert aligned_segment.query_alignment_sequence == aligned_segment.get_forward_sequence()

                # Ensure alignment methylation tags exist
                assert aligned_segment.has_tag("XB") # GEM3/Blueprint may add this (also in Biscuit, but different!)
                assert aligned_segment.has_tag("MD") # Location of mismatches (methylation)
                assert aligned_segment.has_tag("YD") # Bisulfite conversion strand label (f: OT/CTOT C->T or r: OB/CTOB G->A)

            # TODO: We ignore paired/unpaired read status for now, and treat them the same
            # Should we treat paired reads / overlapping reads differently?

            bisulfite_parent_strand_is_reverse = None
            if aligned_segment.has_tag("YD"): # Biscuit tag
                yd_tag = aligned_segment.get_tag("YD")
                if yd_tag == "f": # Forward = C→T
                    # This read derives from OT/CTOT strand: C->T substitutions matter (C = methylated, T = unmethylated),
                    bisulfite_parent_strand_is_reverse = False
                elif yd_tag == "r": # Reverse = G→A
                    # This read derives from the OB/CTOB strand: G->A substitutions matter (G = methylated, A = unmethylated)
                    bisulfite_parent_strand_is_reverse = True
            elif aligned_segment.has_tag("XB"): # gem3 / blueprint tag
                raise NotImplementedError("XB tag not validated yet")
                xb_tag = aligned_segment.get_tag("XB") # XB:C = Forward / Reference was CG
                # TODO: Double check one or two of these gem3 tags manually.
                if xb_tag == "C":
                    bisulfite_parent_strand_is_reverse = False
                elif xb_tag == "G": # XB:G = Reverse / Reference was GA
                    bisulfite_parent_strand_is_reverse = True

            # TODO: Think about this old note of mine -- is this correct?
            # We have paired-end reads; one half should (the "parent strand") has the methylation data.
            # The other half (the "daughter strand") was the complement created by PCR, which we don't care about.
            if bisulfite_parent_strand_is_reverse != aligned_segment.is_reverse:
                # Skip if we're not on the bisulfite-converted parent strand.
                if DEBUG: print(f"\t\t Not on methylated strand, skipping: {aligned_segment.query_name}")
                continue

            # get_aligned_pairs returns a list of tuples of (read_pos, ref_pos)
            # We filter this to only include the specific CpG sites from above
            this_segment_cpgs = [e for e in aligned_segment.get_aligned_pairs(matches_only=True) if e[1]+1 in cpgs_within_window]

            # Ok we're on the same strand as the methylation (right?)
            # Let's compare the possible CpGs in this interval to the reference and note status
            #   A methylated C will be *unchanged* and read as C (pair G)
            #   An unmethylated C will be *changed* and read as T (pair A)
            if DEBUG: print(f"bisulfite_parent_strand_is_reverse: {bisulfite_parent_strand_is_reverse}")
            for query_pos, ref_pos in this_segment_cpgs:
                query_base = aligned_segment.query_sequence[query_pos]
                query_base2 = aligned_segment.get_forward_sequence()[query_pos]
                query_base3 = aligned_segment.query_alignment_sequence[query_pos]
                assert query_base == query_base2
                assert query_base == query_base3
                #ref_base = aligned_segment.get_reference_sequence()[ref_pos - aligned_segment.reference_start]
                #assert ref_base.upper() == "C", f"Expected C at {ref_pos} but got {ref_base}"
                # print(f"\t{query_pos} {ref_pos} {query_base} {query_base2} {query_base3} {ref_base}")
                # print(f"\t{query_pos} {ref_pos} C->{query_base}")
                # If query == reference, we're methylated.
                # If query !== reference, we're unmethylated.
                # NOTE: there's an edge where if query != reference AND query == random base, we're an SNV

                # Store in our sparse array
                coo_row.append(next_coo_row_number)
                # instead of ref_pos, we want the index of the CpG in the list of CpGs
                # coo_col.append(ref_pos)
                coo_col.append(genomic_position_to_embedding(chrom, ref_pos+1))
                #coo_data.append(1 if query_base == "C" else 0)
                if query_base == "C":
                    # Methylated
                    coo_data.append(1)
                    if DEBUG: print(f"\t\tMethylated")
                elif query_base == "T":
                    coo_data.append(0)
                    # Unmethylated
                    if DEBUG: print(f"\t\tUnmethylated")
                else:
                    coo_data.append(-1) # or just 0?
                    if DEBUG: print(f"\t\tUnknown!")
                    # raise ValueError(f"Unexpected query base {query_base} at {query_pos} {ref_pos}")

            read_name_to_row_number[aligned_segment.query_name] = next_coo_row_number
            next_coo_row_number += 1

            if DEBUG: print("************************************************\n")

            #query_bp = aligned_segment.query_sequence[pileupread.query_position]
            #reference_bp = aligned_segment.get_reference_sequence()[aligned_segment.reference_start - pileupcolumn.reference_pos].upper()
 
        # break
    # break

print("Elapsed Time: %.2f seconds" % (time.time() - start_time))
# Out:
# Loading: sorted.tinysam.bam
# Total reads: 6
#   0%|          | 0/24 [00:00<?, ?it/s]
# Elapsed Time: 35.33 seconds

# %%
my_matrix = coo_matrix((coo_data, (coo_row, coo_col)), shape=(len(read_name_to_row_number), total_cpg_sites)).toarray()
assert(len(my_matrix[0]) == total_cpg_sites)

# %%
# Save the matrix, which is an ndarray of shape (n_reads, n_cpgs), to a file
np.save("my_matrix.npy", my_matrix, allow_pickle=True)

# %% [markdown]
# # STOP HERE

# %%
HEALTHY_BAM = "/r5n/liquid-cell-atlas/healthy/Healthy_B12_Nu-13_PBMC_emseq/Healthy_B12_Nu-13_PBMC_emseq.bam"

QUALITY_THRESHOLD=40

bam_filename_only = os.path.basename(HEALTHY_BAM)
print(f"Loading: {os.path.basename(bam_filename_only)}")


# Temporary storage for loading into a COO matrix
# For a COO, we want three lists:
# row: the read number (we'll store a read name -> ID dict perhaps?)
# column: cpg #
# data: methylation state (1 [methylated], -1 [unmethylated], and 0 [no data])

next_coo_row_number = 0
read_name_to_row_number = {}

coo_row = []
coo_col = []
coo_data = []


# We require an index for performance
input_bam = pysam.AlignmentFile(HEALTHY_BAM, "rb", require_index=True, threads=10)
DEBUG = True
DEBUG = False
# There are two approaches to getting CpGs from PySam -- one is pileup(), and the other is fetch().
# I already had validated pileup() code, so I take that approach here again. It's a little less performant I suspect
# than using fetch(), since we re-query the same reads multiple times, but it's easier to understand and debug.
# I wonder if this is much slower than fetch()?
for cpg_chrom, per_chr_cpg_list in cpg_sites_dict.items():
    print(f"Processing chromosome: {cpg_chrom}")
    for cpg_position in tqdm(per_chr_cpg_list):
        # For each site, grab the pileup (all reads overlapping that exact site)
        # NOTE: A read could be returned by multiple loop iterations (i.e. a ~100bp read could be overlapping multiple CpGs)
        # truncate = return only the *exact* position, not the surrounding overlaps
        # There will only be one turn through this loop; pileup should return only one entry.
        for pileupcolumn in input_bam.pileup(cpg_chrom, start=cpg_position, stop=cpg_position+1,
                                            truncate=True, max_depth=10000, min_mapping_quality=QUALITY_THRESHOLD):
            if DEBUG: print(f"Coverage at CpG: {cpg_position} = {pileupcolumn.nsegments} (unfitered) | {pileupcolumn.get_num_aligned()} (QC filtered)")
            # ?get_query_positions(self)
            # reference_pos = pileupcolumn.reference_pos
            # Loop over all the reads overlapping this exact CpG location
            for pileupread in pileupcolumn.pileups:
                # Skip reads that land on deletions/refskips
                # e.g. This would skip a read that encompasses a CpG, but at the BP of interest, there's a deletion
                if not pileupread.is_del and not pileupread.is_refskip:
                    if DEBUG: print(f"\t Raw read: {pileupread}")
                    
                    assert pileupread.alignment.is_paired is True
                    assert pileupread.alignment.is_proper_pair is True
                    assert pileupread.alignment.is_qcfail is False
                    assert pileupread.alignment.is_unmapped is False
                    assert pileupread.alignment.is_duplicate is False
                    assert pileupread.alignment.has_tag("XB") or pileupread.alignment.has_tag("YD")
                    # assert pileupread.alignment.query_alignment_sequence == pileupread.alignment.query_sequence

                    # We have paired-end reads; one half should (the "parent strand") has the methylation data.
                    # The other half (the "daughter strand") was the complement created by PCR, which we don't care about.
                    # TODO: Let's think about this -- is this correct? 

                    bisulfite_parent_strand_is_reverse = None
                    if pileupread.alignment.has_tag("YD"): # Biscuit tag
                        yd_tag = pileupread.alignment.get_tag("YD")
                        if yd_tag == "f": # Forward = C→T
                            bisulfite_parent_strand_is_reverse = False
                        elif yd_tag == "r": # Reverse = G→A
                            bisulfite_parent_strand_is_reverse = True
                    elif pileupread.alignment.has_tag("XB"): # gem3 / blueprint tag
                        raise NotImplementedError("XB tag not validated yet.")
                        xb_tag = pileupread.alignment.get_tag("XB") # XB:C = Forward / Reference was CG
                        # TODO: Double check one or two of these gem3 tags manually.
                        if xb_tag == "C":
                            bisulfite_parent_strand_is_reverse = False
                        elif xb_tag == "G": # XB:G = Reverse / Reference was GA
                            bisulfite_parent_strand_is_reverse = True

                    # Skip if we're not on the bisulfite-converted parent strand.
                    if bisulfite_parent_strand_is_reverse != pileupread.alignment.is_reverse:
                        if DEBUG: print(f"\t\t Not on methylated strand, skipping.")
                        continue

                    # Ok we're on the same strand as the methylation, let's compare this BP to reference.
                    # Let's refresh how bisulfite actually works:
                    #   A methylated C will be *unchanged* and read as C (pair G)
                    #   An unmethylated C will be *changed* and read as T (pair A)
                    query_bp = pileupread.alignment.query_sequence[pileupread.query_position]
                    # TODO: Shift this up to the level of the pileupcolum?
                    reference_bp = pileupread.alignment.get_reference_sequence()[pileupread.alignment.reference_start - pileupcolumn.reference_pos].upper()
                    
                    # Now we need to populate coo_row, coo_col, and coo_data

                    # coo_row is the read "number" -- since .bam reads aren't assigned a number, we'll assign them one.
                    # We then keep track of the read name to row number mapping in read_name_to_row_number.
                    if pileupread.alignment.query_name in read_name_to_row_number:
                        coo_row.append(read_name_to_row_number[pileupread.alignment.query_name])
                    else:
                        read_name_to_row_number[pileupread.alignment.query_name] = coo_row
                        coo_row.append(next_coo_row_number)
                        next_coo_row_number += 1
                    
                    # coo_col is the CpG site number.
                    coo_col.append(cpg_position)

                    # If query == reference, we're methylated.
                    # If query != reference, we're unmethylated.
                    if query_bp == reference_bp.upper():
                        # If the read is methylated, add the score to the read_score_dict
                        if DEBUG: print(f"\t\t Methylated.")
                        coo_data.append(1)
                    else:
                        # If the read is unmethylated, we don't need to do anything.
                        if DEBUG: print(f"\t\t Unmethylated.")
                        coo_data.append(-1)
                else:
                    if DEBUG: print(f"\t\t Read is a deletion/refskip, skipping.")
            # break
        # break
    break
print("DONE")
# Out:
# Loading: Healthy_B12_Nu-13_PBMC_emseq.bam
# Processing chromosome: chr1
#   0%|          | 0/2305751 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 38
#      32 print(f"Processing chromosome: {cpg_chrom}")
#      33 for cpg_position in tqdm(per_chr_cpg_list):
#      34     # For each site, grab the pileup (all reads overlapping that exact site)
#      35     # NOTE: A read could be returned by multiple loop iterations (i.e. a ~100bp read could be overlapping multiple CpGs)
#      36     # truncate = return only the *exact* position, not the surrounding overlaps
#      37     # There will only be one turn through this loop; pileup should return only one entry.
# ---> 38     for pileupcolumn in input_bam.pileup(cpg_chrom, start=cpg_position, stop=cpg_position+1,
#      39                                         truncate=True, max_depth=10000, min_mapping_quality=QUALITY_THRESHOLD):
#      40         if DEBUG: print(f"Coverage at CpG: {cpg_position} = {pileupcolumn.nsegments} (unfitered) | {pileupcolumn.get_num_aligned()} (QC filtered)")
#      41         # ?get_query_positions(self)
#      42         # reference_pos = pileupcolumn.reference_pos
#      43         # Loop over all the reads overlapping this exact CpG location
#
# KeyboardInterrupt:

# %%
samfile = pysam.AlignmentFile(HEALTHY_BAM, "rb")
# 10468 - 11479
# cpg in this region
cpgs_in_this_region_block = [10468, 10470] # , 10483, 10488, 10492, 10496, 10524, 10541, 10562, 10570]

for pileupcolumn in samfile.pileup("chr1", 10468, 11479, truncate=False, stepper="all", ignore_overlaps=False, max_depth=10000, min_mapping_quality=20, compute_baq=False):
    if pileupcolumn.pos in cpgs_in_this_region_block:
        print("\ncoverage at cpg %s = %s" % (pileupcolumn.pos, pileupcolumn.n))
        for pileupread in pileupcolumn.pileups:
            if not pileupread.is_del and not pileupread.is_refskip:
                print('\tbase in read %s = %s' % (pileupread.alignment.query_name, pileupread.alignment.query_sequence[pileupread.query_position]))

samfile.close()
# Out:
# coverage at cpg 10468 = 67
# 	base in read A00354:758:HVTT7DSX3:3:1329:15962:20275 = T
# 	base in read A00354:758:HVTT7DSX3:3:2429:23158:30044 = A
# 	base in read A00354:758:HVTT7DSX3:3:2322:2202:15107 = A
# 	base in read A00354:758:HVTT7DSX3:3:1355:4191:3552 = C
# 	base in read A00354:758:HVTT7DSX3:3:2656:3007:3255 = A
# 	base in read A00354:758:HVTT7DSX3:3:2408:4824:33708 = G
# 	base in read A00354:758:HVTT7DSX3:3:2138:14407:2331 = T
# 	base in read A00354:758:HVTT7DSX3:3:1249:9869:10003 = A
# 	base in read A00354:758:HVTT7DSX3:3:2361:1940:21637 = T
# 	base in read A00354:758:HVTT7DSX3:3:2126:16532:20603 = A
# 	base in read A00354:758:HVTT7DSX3:3:2148:8648:27931 = C
# 	base in read A00354:758:HVTT7DSX3:3:2355:16975:17300 = T
# 	base in read A00354:754:HCLY3DMXY:2:2347:25274:22842 = A
# 	base in read A00354:758:HVTT7DSX3:3:1567:7952:7059 = A
# 	base in read A00354:758:HVTT7DSX3:3:1448:13792:28635 = T
# 	base in read A00354:754:HCLY3DMXY:2:2271:18385:1892 = A
# 	base in read A00354:758:HVTT7DSX3:3:1255:11071:2973 = A
# 	base in read A00354:758:HVTT7DSX3:3:2641:18927:21089 = A
# 	base in read A00354:754:HCLY3DMXY:2:2103:17183:29371 = A
# 	base in read A00354:758:HVTT7DSX3:3:2507:31602:10410 = A
# 	base in read A00354:758:HVTT7DSX3:3:1329:15962:20275 = T
# 	base in read A00354:758:HVTT7DSX3:3:1405:18692:15702 = A
# 	base in read A00354:758:HVTT7DSX3:3:1315:21459:10254 = A
# 	base in read A00354:754:HCLY3DMXY:2:1412:23357:2926 = T
# 	base in read A00354:758:HVTT7DSX3:3:2624:21124:27586 = T
# 	base in read A00354:754:HCLY3DMXY:2:2174:3803:13432 = T
# 	base in read A00354:758:HVTT7DSX3:3:1401:30138:11005 = A
# 	base in read A00354:758:HVTT7DSX3:3:2238:2546:16329 = C
# 	base in read A00354:754:HCLY3DMXY:2:1482:14235:16783 = A
# 	base in read A00354:758:HVTT7DSX3:3:1502:14145:24580 = T
# 	base in read A00354:758:HVTT7DSX3:3:2661:32597:23844 = T
# 	base in read A00354:754:HCLY3DMXY:2:1412:19831:6339 = C
# 	base in read A00354:758:HVTT7DSX3:3:1615:26838:18568 = T
# 	base in read A00354:758:HVTT7DSX3:3:1530:20057:5321 = A
# 	base in read A00354:758:HVTT7DSX3:3:2244:11044:31704 = G
# 	base in read A00354:758:HVTT7DSX3:3:1169:19741:33301 = T
# 	base in read A00354:758:HVTT7DSX3:3:1635:16414:5650 = T
# 	base in read A00354:758:HVTT7DSX3:3:2238:2546:16329 = C
# 	base in read A00354:758:HVTT7DSX3:3:2640:14064:25191 = A
# 	base in read A00354:758:HVTT7DSX3:3:1403:4264:3333 = A
# 	base in read A00354:758:HVTT7DSX3:3:1169:19741:33301 = A
# 	base in read A00354:758:HVTT7DSX3:3:1615:26838:18568 = T
# 	base in read A00354:758:HVTT7DSX3:3:1155:6632:32769 = T
# 	base in read A00354:758:HVTT7DSX3:3:1118:13214:16360 = G
# 	base in read A00354:758:HVTT7DSX3:3:2533:3016:23813 = A
# 	base in read A00354:758:HVTT7DSX3:3:2624:21124:27586 = C
# 	base in read A00354:758:HVTT7DSX3:3:2255:30635:30029 = T
# 	base in read A00354:758:HVTT7DSX3:3:1448:13792:28635 = T
# 	base in read A00354:758:HVTT7DSX3:3:1120:19316:8077 = G
# 	base in read A00354:758:HVTT7DSX3:3:1134:7283:32111 = A
# 	base in read A00354:758:HVTT7DSX3:3:1359:31448:13651 = T
# 	base in read A00354:754:HCLY3DMXY:2:2112:18448:13213 = A
# 	base in read A00354:754:HCLY3DMXY:2:2384:30436:6574 = C
# 	base in read A00354:758:HVTT7DSX3:3:2323:8359:34444 = C
# 	base in read A00354:754:HCLY3DMXY:2:2175:12066:30311 = C
# 	base in read A00354:758:HVTT7DSX3:3:2176:16685:8469 = A
# 	base in read A00354:758:HVTT7DSX3:3:1105:11089:13683 = C
# 	base in read A00354:754:HCLY3DMXY:2:1122:20175:23844 = C
#
# coverage at cpg 10470 = 48
# 	base in read A00354:758:HVTT7DSX3:3:1329:15962:20275 = A
# 	base in read A00354:758:HVTT7DSX3:3:2322:2202:15107 = T
# 	base in read A00354:758:HVTT7DSX3:3:2361:1940:21637 = T
# 	base in read A00354:758:HVTT7DSX3:3:2126:16532:20603 = C
# 	base in read A00354:758:HVTT7DSX3:3:2148:8648:27931 = T
# 	base in read A00354:754:HCLY3DMXY:2:2347:25274:22842 = C
# 	base in read A00354:758:HVTT7DSX3:3:1567:7952:7059 = C
# 	base in read A00354:758:HVTT7DSX3:3:1448:13792:28635 = C
# 	base in read A00354:754:HCLY3DMXY:2:2271:18385:1892 = T
# 	base in read A00354:758:HVTT7DSX3:3:1255:11071:2973 = T
# 	base in read A00354:758:HVTT7DSX3:3:2641:18927:21089 = C
# 	base in read A00354:758:HVTT7DSX3:3:2507:31602:10410 = T
# 	base in read A00354:758:HVTT7DSX3:3:1329:15962:20275 = T
# 	base in read A00354:758:HVTT7DSX3:3:1405:18692:15702 = C
# 	base in read A00354:758:HVTT7DSX3:3:1315:21459:10254 = T
# 	base in read A00354:758:HVTT7DSX3:3:1401:30138:11005 = T
# 	base in read A00354:758:HVTT7DSX3:3:2238:2546:16329 = C
# 	base in read A00354:754:HCLY3DMXY:2:1482:14235:16783 = T
# 	base in read A00354:758:HVTT7DSX3:3:1530:20057:5321 = C
# 	base in read A00354:758:HVTT7DSX3:3:2244:11044:31704 = T
# 	base in read A00354:758:HVTT7DSX3:3:2238:2546:16329 = C
# 	base in read A00354:758:HVTT7DSX3:3:2640:14064:25191 = C
# 	base in read A00354:758:HVTT7DSX3:3:1403:4264:3333 = C
# 	base in read A00354:758:HVTT7DSX3:3:1169:19741:33301 = C
# 	base in read A00354:758:HVTT7DSX3:3:1118:13214:16360 = T
# 	base in read A00354:758:HVTT7DSX3:3:2624:21124:27586 = C
# 	base in read A00354:754:HCLY3DMXY:2:1212:2257:29888 = T
# 	base in read A00354:758:HVTT7DSX3:3:2255:30635:30029 = A
# 	base in read A00354:758:HVTT7DSX3:3:1448:13792:28635 = C
# 	base in read A00354:758:HVTT7DSX3:3:1134:7283:32111 = C
# 	base in read A00354:754:HCLY3DMXY:2:2112:18448:13213 = C
# 	base in read A00354:758:HVTT7DSX3:3:2472:8223:10316 = C
# 	base in read A00354:754:HCLY3DMXY:2:2384:30436:6574 = T
# 	base in read A00354:758:HVTT7DSX3:3:2323:8359:34444 = C
# 	base in read A00354:754:HCLY3DMXY:2:2175:12066:30311 = C
# 	base in read A00354:758:HVTT7DSX3:3:1105:11089:13683 = C
# 	base in read A00354:754:HCLY3DMXY:2:1122:20175:23844 = C

# %%
HEALTHY_BAM = "/r5n/liquid-cell-atlas/healthy/Healthy_B12_Nu-13_PBMC_emseq/Healthy_B12_Nu-13_PBMC_emseq.bam"

QUALITY_THRESHOLD=20

bam_filename_only = os.path.basename(HEALTHY_BAM)
print(f"Loading: {os.path.basename(bam_filename_only)}")

# Temporary storage for loading into a COO matrix
# For a COO, we want three lists:
# row: the read number (we'll store a read name -> ID dict perhaps?)
# column: cpg #
# data: methylation state (1 [methylated], -1 [unmethylated], and 0 [no data])

next_coo_row_number = 0
read_name_to_row_number = {}

coo_row = []
coo_col = []
coo_data = []


# We require an index for performance
input_bam = pysam.AlignmentFile(HEALTHY_BAM, "rb", require_index=True, threads=1)

DEBUG = True
DEBUG = False

for cpg_chrom, per_chr_windowed_cpg_list in windowed_cpg_sites_dict.items():
    print(f"Processing windows in chromosome: {cpg_chrom}")
    for start_pos, stop_pos in tqdm(per_chr_windowed_cpg_list):
        for pileupcolumn in input_bam.pileup(cpg_chrom, start=start_pos, stop=stop_pos,
                                            truncate=False, max_depth=10000, min_mapping_quality=QUALITY_THRESHOLD,
                                            stepper="all", ignore_overlaps=False, compute_baq=False):
            # Ignore positions that aren't CpGs
            if pileupcolumn.pos in windowed_cpg_sites_dict_reverse[cpg_chrom][start_pos]:
                if DEBUG: print(f"Coverage at CpG: {pileupcolumn.pos} = {pileupcolumn.nsegments} (unfitered) | {pileupcolumn.get_num_aligned()} (QC filtered)")
                # Loop over all the reads overlapping this single CpG
                for pileupread in pileupcolumn.pileups:
                    continue
                    # Skip reads that land on deletions/refskips
                    # e.g. This would skip a read that encompasses a CpG, but at the BP of interest, there's a deletion
                    if not pileupread.is_del and not pileupread.is_refskip:
                        # print('\tbase in read %s = %s' % (pileupread.alignment.query_name, pileupread.alignment.query_sequence[pileupread.query_position]))
                        # if DEBUG: print(f"\t Raw read: {pileupread}")
                        assert pileupread.alignment.is_paired is True

                        # We can match unpaired reads, it's cool bro
                        # assert pileupread.alignment.is_proper_pair is True

                        assert pileupread.alignment.is_qcfail is False
                        assert pileupread.alignment.is_unmapped is False
                        assert pileupread.alignment.is_duplicate is False
                        assert pileupread.alignment.has_tag("XB") or pileupread.alignment.has_tag("YD")
                        # assert pileupread.alignment.query_alignment_sequence == pileupread.alignment.query_sequence

                        # We have paired-end reads; one half should (the "parent strand") has the methylation data.
                        # The other half (the "daughter strand") was the complement created by PCR, which we don't care about.
                        # TODO: Let's think about this -- is this correct? 

                        bisulfite_parent_strand_is_reverse = None
                        if pileupread.alignment.has_tag("YD"): # Biscuit tag
                            yd_tag = pileupread.alignment.get_tag("YD")
                            if yd_tag == "f": # Forward = C→T
                                bisulfite_parent_strand_is_reverse = False
                            elif yd_tag == "r": # Reverse = G→A
                                bisulfite_parent_strand_is_reverse = True
                        elif pileupread.alignment.has_tag("XB"): # gem3 / blueprint tag
                            raise NotImplementedError("XB tag not validated yet.")
                            xb_tag = pileupread.alignment.get_tag("XB") # XB:C = Forward / Reference was CG
                            # TODO: Double check one or two of these gem3 tags manually.
                            if xb_tag == "C":
                                bisulfite_parent_strand_is_reverse = False
                            elif xb_tag == "G": # XB:G = Reverse / Reference was GA
                                bisulfite_parent_strand_is_reverse = True

                        # Skip if we're not on the bisulfite-converted parent strand.
                        if bisulfite_parent_strand_is_reverse != pileupread.alignment.is_reverse:
                            if DEBUG: print(f"\t\t Not on methylated strand, skipping.")
                            continue

                        # Ok we're on the same strand as the methylation, let's compare this BP to reference.
                        # Let's refresh how bisulfite actually works:
                        #   A methylated C will be *unchanged* and read as C (pair G)
                        #   An unmethylated C will be *changed* and read as T (pair A)
                        query_bp = pileupread.alignment.query_sequence[pileupread.query_position]
                        # TODO: Shift this up to the level of the pileupcolum?
                        reference_bp = pileupread.alignment.get_reference_sequence()[pileupread.alignment.reference_start - pileupcolumn.reference_pos].upper()
                        
                        # Now we need to populate coo_row, coo_col, and coo_data

                        # coo_row is the read "number" -- since .bam reads aren't assigned a number, we'll assign them one.
                        # We then keep track of the read name to row number mapping in read_name_to_row_number.
                        if pileupread.alignment.query_name in read_name_to_row_number:
                            coo_row.append(read_name_to_row_number[pileupread.alignment.query_name])
                        else:
                            read_name_to_row_number[pileupread.alignment.query_name] = coo_row
                            coo_row.append(next_coo_row_number)
                            next_coo_row_number += 1
                        
                        # coo_col is the CpG site number.
                        coo_col.append(cpg_position)

                        # If query == reference, we're methylated.
                        # If query != reference, we're unmethylated.
                        if query_bp == reference_bp.upper():
                            # If the read is methylated, add the score to the read_score_dict
                            if DEBUG: print(f"\t\t Methylated.")
                            coo_data.append(1)
                        else:
                            # If the read is unmethylated, we don't need to do anything.
                            if DEBUG: print(f"\t\t Unmethylated.")
                            coo_data.append(-1)
                    else:
                        if DEBUG: print(f"\t\t Read is a deletion/refskip, skipping.")
        # break
    break
print("DONE")
# Out:
# Loading: Healthy_B12_Nu-13_PBMC_emseq.bam
# Processing windows in chromosome: chr1
#   0%|          | 0/456706 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[147], line 31
#      29 print(f"Processing windows in chromosome: {cpg_chrom}")
#      30 for start_pos, stop_pos in tqdm(per_chr_windowed_cpg_list):
# ---> 31     for pileupcolumn in input_bam.pileup(cpg_chrom, start=start_pos, stop=stop_pos,
#      32                                         truncate=False, max_depth=10000, min_mapping_quality=QUALITY_THRESHOLD,
#      33                                         stepper="all", ignore_overlaps=False, compute_baq=False):
#      34         # Ignore positions that aren't CpGs
#      35         if pileupcolumn.pos in windowed_cpg_sites_dict_reverse[cpg_chrom][start_pos]:
#      36             if DEBUG: print(f"Coverage at CpG: {pileupcolumn.pos} = {pileupcolumn.nsegments} (unfitered) | {pileupcolumn.get_num_aligned()} (QC filtered)")
#
# KeyboardInterrupt:

# %%
print(f"{coo_row}")
print(f"{coo_col}")
print(f"{coo_data}")
# Out:
# [0, 1, 2]
# [10468, 10468, 10468]
# [-1, -1, 1]

# %%
pileupread.alignment.query_name
# Out:
# 'A00354:754:HCLY3DMXY:2:1482:14235:16783'
