# %% [markdown]
# <a href="https://colab.research.google.com/github/semenko/liquid-cell-atlas/blob/main/liquid_cell_atlas_shell.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Liquid Cell Atlas — Blueprint Preprocessed Data
# **By Nick Semenkovich \<semenko@alum.mit.edu\>**
#
# <br>
#
# A performant, documented approach to the Liquid Cell Atlas (LCA) project. At a high level, we want to develop a signature or "fingerprint" of individual Human cell types using methylation data, and then deconvolute bulk samples.
#
# For example, we can ingest raw (un-annotated) methylation data (e.g. from a peripheral blood draw) and then estimate percentages of cell types observed (e.g. 3% CD4+ T cells), with a focus on exhausted immune cells, TILs, and other rare cell types.
#
# <br>
#
# $f(MethylationData) = \begin{bmatrix}
# 0.439_{CD4+}\\
# 0.264_{CD8+}\\
# 0.170_{Tex}
# \end{bmatrix}$
#
# <br>
#
# ___
#
#
# **Training Data**: We train on what limited pure WGBS data exists, predominantly from Blueprint and Encode. We are exploring incorporating RRBS & array data.
#
# $Train = \begin{Bmatrix}
# \{WGBS_{ENCODE}, WGBS_{Blueprint}, Array_{Infinium, …} \}_{CD4+}\\
# \{WGBS_{ENCODE}, WGBS_{Blueprint}, Array_{Infinium, …} \}_{CD8+}\\
# …\\
# \end{Bmatrix}$
#
# <br>
#
# **Validation**: Beyond standard held-out data and permutation experiments (see our mansucript), we also validate our model with ground truth experiments of parallel bisulfite/EM-seq data combined with FACS and CyTOF cell-type confirmation.
#
# $Test = \begin{Bmatrix}
# \{WGBS, CyTOF, FACS \}_{CD4+}\\
# \{WGBS, CyTOF, FACS \}_{CD8+}\\
# …\\
# \end{Bmatrix}$
#
# <br>
#
# This model is trained only on human data (via Blueprint) but could be trained on mouse or other organisms of interest, if enough ground-truth data exist.

# %% [markdown]
# ## Setup / Imports & Helpers

# %%
# ! pip3 -q install plotly pyBigWig tensorflow_decision_forests # --upgrade

# %%
import csv
import datetime
import glob
import hashlib
import itertools
import json
import os
import random
import sys
import timeit
import urllib.request

# %%
import socket
print(f"Running on: {socket.gethostname()}")
print(f"Python version: {sys.version}")

# Require Python 3.11, welcome to the future! :P
if sys.version_info < (3, 11):
    raise RuntimeError("Python 3.11 or greater is required")

# Parallel multithreading limit
NUM_USABLE_CPUS = len(os.sched_getaffinity(0))
print(f"Usable CPUs: {NUM_USABLE_CPUS}")
# Out:
# Running on: acln3
# Python version: 3.11.0 | packaged by conda-forge | (main, Jan 14 2023, 12:27:40) [GCC 11.3.0]
# Usable CPUs: 40

# %%
# External libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.express as px
import pyBigWig
# import pybedtools # Blocking Py3.11, using Pandas instead (lol)
import sklearn.metrics
import sklearn.model_selection
#import tensorflow as tf
import torch
import torchmetrics
# import tensorflow_decision_forests as tfdf
import zarr

from tqdm.notebook import tqdm

import plotly.io as pio
import plotly.graph_objects as go
pio.renderers.default = 'colab'

if "google.colab" in sys.modules:
    from google.colab import data_table
    print("Loading pretty datatable formatter.")
    data_table.enable_dataframe_formatter()

# %%
# PyTorch version
print(f"PyTorch version: {torch.__version__}")

# Tensorflow Decision Forests version
# print(f"Tensorflow Decision Forests version: {tfdf.__version__}")

# Require PyTorch 2.0, welcome to the future! :P
#if torch.__version__ < "2.0":
#    raise RuntimeError("PyTorch 2.0 or greater is required")

# Set random seeds
RUN_SEED = 42
random.seed(RUN_SEED)
np.random.seed(RUN_SEED)
torch.manual_seed(RUN_SEED)
# Out:
# PyTorch version: 1.13.1

# %%
# Run Settings
CHROMOSOMES = ["chr" + str(i) for i in range(1, 23)] + ["chrX"]

# For development, forcably re-run parsing even if a cache exists
IGNORE_CACHE = False

# %% [markdown]
# ## Data Loading & Pre-processing
#
# The biggest challenge in this project is data pre-processing and feature engineering. Lots of normalization / scaling / imputation / etc. is required to get the data into a form that can be used by a neural network.
#
# I suspect we will need to impute values either manually, or using SMOTE, etc. to get a good training set.

# %% [markdown]
# ### Blueprint WGBS
#
# Load WGBS data from the Blueprint consortium. There are two file types provided: **cov** and **call**
#
# The **cov** files show any spot covered by our sequening run.
#
# The **call** files show actual CpG methylation calls.
#
# We process these by:
# 1. Aggregating all **cov** files to find the shared set of regions covered in all samples
# 2. Filtering these to loci with **>30** reads for extreme stringency early on -- this should likely be closer to 10?
#
# Note that we also have the Blueprint raw BAM files via a licensing agreement to perform read-level analyses, thought this is not implemented in the first pass here.

# %%
# TODO: Programmatically download these for new / other users? Or bulk store somewhere?
# This directory contains all the .bw coverage and call files from Blueprint
# Source: http://dcc.blueprint-epigenome.eu/#/files
# Files all end with:
#   .CPG_methylation_calls.bs_call.GRCh38.20160531.bw
#                            or
#   .CPG_methylation_calls.bs_cov.GRCh38.20160531.bw

# %%
# Note, files were all generated with bs_call, followed by some filtering, see: http://dcc.blueprint-epigenome.eu/#/md/bs_seq_grch38
# Filters include phred > 20
BLUEPRINT_DATA_PATH = "/r5n/wgbs-public-data/blueprint-wgbs-data/raw-methylation-signal/"

# Annotations & bs_cov / bs_call names
CELL_TYPE_TO_FILE_ID = {
    "T_CD4_naive": ["S009W451", "S008H151","S007DD51","P580","P582","P584","P586","S007G756"],
    "T_CD4_central_memory": ["S006YC51", "S014QS55"],
    "T_CD4_effector_memory": ["S001U352", "S014QS51"],

    "T_CD8_naive": ["C0066P51","C003VO55","C00256A1bs","S00C2F51"],
    "T_CD8_central_memory": ["C003VO56", "C005UI52"],
    "T_CD8_effector_memory": ["C00256A3bs", "S014WG51"],
    "T_CD8_effector_memory_terminal": ["S002ND51", "S0164R51"],

    "Treg": ["S00XTP51","S001U353"],

    "B_cell_naive": ["S01ECGA1","NBC_NC11_83","NBC_NC11_41","S001JP51","C003K951","S00DM851","C0068L51"],
    "B_cell_memory": ["S017RE51","C003N351"], # Excluding W653; few reads.

    "Plasma_cell": ["S00XCMA1","S00XDKU1","S00XEIU1","G204","G203"],

    "Monocyte": ["S01BHIA1","S01MAPA1","S01E03A1"],
    "Macrophage_M0": ["S001S751","S0039051","S0022I51","S00BHQ51","S00DVR51","C005VG51"],
    "Macrophage_M1": ["S0022I53","S001S753","S0018A52","S00H6O51","S007SK51","S001MJ51"],
    "Macrophage_M2": ["S00BS451","S0062252","S00FTN51","S00C1H51","S00E8W51","S006VI53"],

    "NK_cell": ["C0067N51","S01E8O51","C002CTA1bs","C006G551"],
    "Neutrophil": ["S00K5EA1","C00184A3bs","C001UYA1bs","C0010KA1bs","C004GD51","C0011IA3bs","C000S5A2bs","S00FWHA1","S00K7AA1"],
    "Eosinophil": ["S00V6553","S006XE53"],

    "Dendtritic_immature": ["S00TU2A1", "S00TV0A1"],
    "Dendtritic_mature": ["S00TXXA1", "S00TYVA1"],

    "Megakaryocyte": ["S004AV51", "S004BT51"],
    "Erythroblast": ["S002S351","S002R551"]
}

# Reverse mapping of file id -> cell type
# e.g.  'S01BHIA1': 'Monocyte'
# Sort this for stability
FILE_ID_TO_CELL_TYPE = {sample:cell_type for cell_type, sample_list in CELL_TYPE_TO_FILE_ID.items() for sample in sample_list}

# If the blueprint dict changes, we need to replace our cache files
# This is a tiny checksum of the dictionary state, which we incorporate into
# our cache filenames below.
CELL_TYPE_DICT_SIG = hashlib.sha1(json.dumps(FILE_ID_TO_CELL_TYPE, sort_keys=True).encode()).hexdigest()[2:10]
print(f"Dictionary signature for cache files: {CELL_TYPE_DICT_SIG}\n")

BLUEPRINT_FILEKEYS = list(itertools.chain.from_iterable(CELL_TYPE_TO_FILE_ID.values()))

# Validity testing
assert all(len(vals) > 1 for vals in CELL_TYPE_TO_FILE_ID.values()), "We need more than one example per cell type."
assert len(BLUEPRINT_FILEKEYS) == len(set(BLUEPRINT_FILEKEYS)), "One filename is duplicated in the cell types"

print(f"Number of Blueprint cell types: {len(CELL_TYPE_TO_FILE_ID.keys())}")
print(f"Number of Blueprint raw files: {len(BLUEPRINT_FILEKEYS)}")

# Check that all the files exist
for filekey in BLUEPRINT_FILEKEYS:
    assert os.path.exists(os.path.join(BLUEPRINT_DATA_PATH, filekey + ".CPG_methylation_calls.bs_call.GRCh38.20160531.bw")), f"File {filekey} not found."
    assert os.path.exists(os.path.join(BLUEPRINT_DATA_PATH, filekey + ".CPG_methylation_calls.bs_cov.GRCh38.20160531.bw")), f"File {filekey} not found."
# Out:
# Dictionary signature for cache files: 5882f660
#
# Number of Blueprint cell types: 22
# Number of Blueprint raw files: 82

# %% [markdown]
# #### Create shared **cov** map
#
# Load coverage (if >minimum below) across all files, then determine the set() shared across **all** samples.
#
# IF a locus (e.g. "chr1:123") is missing from **one** single sample, it will be **excluded** from our entire analysis.
#
# IF a locus has \<10 reads in **one** single sample, it will be **excluded** from our entire analysis.

# %%
# The Blueprint cov .bw files include CpGs with trivial coverage, e.g. 1 read.
# Require a minimum of 10 reads per-sample to be considered valid. 
BLUEPRINT_CPG_COV_MINIMUM = 10

RUN_SIGNATURE = f"{BLUEPRINT_CPG_COV_MINIMUM}_{CELL_TYPE_DICT_SIG}"

assert type(BLUEPRINT_CPG_COV_MINIMUM) is int
assert BLUEPRINT_CPG_COV_MINIMUM > 0

print(f"Minimum Blueprint coverage limit: {BLUEPRINT_CPG_COV_MINIMUM}")
print(f" (CpGs with fewer than {BLUEPRINT_CPG_COV_MINIMUM} reads in *any* sample will be ignored.)\n")

# Our output / save file
INTERSECTED_COVERAGE_BED = f"intersected_bs_cov_min_{RUN_SIGNATURE}.bed"

print(f"Coverage BED: {INTERSECTED_COVERAGE_BED}")

if os.path.exists(INTERSECTED_COVERAGE_BED) and not IGNORE_CACHE:
    print("\tPost-processed cov .bed already exists. (Skipping raw Blueprint bs_cov parsing.)")
else:
    print("\t.bed does not exist yet -- parsing bs_cov .bw files. (This will take roughly 30 minutes.)")
    start_time = timeit.default_timer()

    # Dict of CpGs seen across *all* samples in blueprint, at >= BLUEPRINT_CPG_COV_MINIMUM
    #   'chr1': [1234, 1247, ...]
    INTERSECTED_BS_COV_POSITIONS = {}

    ## We loop over all the bs_cov .bw files to build a shared CpG matrix
    for file_key in tqdm(BLUEPRINT_FILEKEYS):
        print(f"{file_key}", end=' ')
        with pyBigWig.open(BLUEPRINT_DATA_PATH + "/" + file_key + ".CPG_methylation_calls.bs_cov.GRCh38.20160531.bw") as bw_object:
            bw_header = bw_object.header()
            if bw_header['nBasesCovered'] < 1e7 or bw_header['sumData'] < 1e8:
                print('\t\t*** WARNING: Input .bw has few reads or low coverage. This may cause unexpected results, consider removing this file.')
                print(f"\t\tnBasesCovered: {bw_header['nBasesCovered']}, sumData: {bw_header['sumData']}")
            for chrom in CHROMOSOMES:
                # Get existing values, or set to the current ones

                # For ease, we require a CpG to be covered at least BLUEPRINT_CPG_COV_MINIMUM across all cell
                # types to be considered  for our fingerprints, though we could leave NaN values if needed,
                # as decision trees, etc. can handle those gracefully.
                current_loop_values = set([start for start, _, cov in bw_object.intervals(chrom) if cov >= BLUEPRINT_CPG_COV_MINIMUM])
                existing_values = INTERSECTED_BS_COV_POSITIONS.get(chrom, current_loop_values)

                # For the first time we see a chrom, we'll intersect ourselves
                INTERSECTED_BS_COV_POSITIONS[chrom] = existing_values.intersection(current_loop_values)


    # Save this hard work as a .bed for later recovery if needed
    with open(INTERSECTED_COVERAGE_BED, 'w') as outfile:
        # A .bed is just a .tsv with ['chrom', 'chromStart', 'chromEnd']
        bed_writer = csv.writer(outfile, delimiter='\t')
        for chr in CHROMOSOMES:
            for entry in INTERSECTED_BS_COV_POSITIONS[chr]:
                bed_writer.writerow([chr, entry, entry+1])

    # del INTERSECTED_BS_COV_POSITIONS
    print(f"\nWrote data to: {INTERSECTED_COVERAGE_BED}") # Unsorted
    print(f"Elapsed time: {datetime.timedelta(seconds=timeit.default_timer() - start_time)}")
# Out:
# Minimum Blueprint coverage limit: 10
#  (CpGs with fewer than 10 reads in *any* sample will be ignored.)
#
# Coverage BED: intersected_bs_cov_min_10_5882f660.bed
# 	.bed does not exist yet -- parsing bs_cov .bw files. (This will take roughly 30 minutes.)
#   0%|          | 0/82 [00:00<?, ?it/s]
# S009W451 S008H151 S007DD51 P580 P582 P584 P586 S007G756 S006YC51 S014QS55 S001U352 S014QS51 C0066P51 C003VO55 C00256A1bs S00C2F51 C003VO56 C005UI52 C00256A3bs S014WG51 S002ND51 S0164R51 S00XTP51 S001U353 S01ECGA1 NBC_NC11_83 NBC_NC11_41 S001JP51 C003K951 S00DM851 C0068L51 S017RE51 C003N351 S00XCMA1 S00XDKU1 S00XEIU1 G204 G203 S01BHIA1 S01MAPA1 S01E03A1 S001S751 S0039051 S0022I51 S00BHQ51 S00DVR51 C005VG51 S0022I53 S001S753 S0018A52 S00H6O51 S007SK51 S001MJ51 S00BS451 S0062252 S00FTN51 S00C1H51 S00E8W51 S006VI53 C0067N51 S01E8O51 C002CTA1bs C006G551 S00K5EA1 C00184A3bs C001UYA1bs C0010KA1bs C004GD51 C0011IA3bs C000S5A2bs S00FWHA1 S00K7AA1 S00V6553 S006XE53 S00TU2A1 S00TV0A1 S00TXXA1 S00TYVA1 S004AV51 S004BT51 S002S351 S002R551
# Wrote data to: intersected_bs_cov_min_10_5882f660.bed
# Elapsed time: 0:39:19.213718

# %% [markdown]
# #### Filter from Encode DAC Exclusion List
#
# Encode defines a standard list of "bad" regions -- very low complexity / information content, etc. that show up in some studies but are not informative. We remove them and do some other standard data cleaning.

# %%
# Load the .bed from above
# raw_bs_cov_bed = pybedtools.BedTool(INTERSECTED_COVERAGE_BED)
# Note that pybedtools isn't supported on Py3.11 yet, so instead we simply parse it as a tsv in pandas (lol)
raw_bs_cov_bed = pd.read_csv(INTERSECTED_COVERAGE_BED, sep='\t', header=None, names=['chrom', 'start', 'end'])
print(f"Number of entries in bs_cov (raw): {len(raw_bs_cov_bed):,}")

# Remove the ENCODE DAC Exclusion List Regions
# Via https://www.encodeproject.org/annotations/ENCSR636HFF/
# Specifically: https://www.encodeproject.org/files/ENCFF356LFX/

if not os.path.exists("ENCFF356LFX.bed.gz"):
    print("Downloading ENCODE DAC Exclusion List")
    urllib.request.urlretrieve("https://www.encodeproject.org/files/ENCFF356LFX/@@download/ENCFF356LFX.bed.gz", "ENCFF356LFX.bed.gz")

excluded_regions = pd.read_csv("ENCFF356LFX.bed.gz", sep='\t', header=None, names=['chrom', 'start', 'end'])
# excluded_regions = pybedtools.BedTool("ENCFF356LFX.bed.gz")
print(f"Number of entries in excluded_regions: {len(excluded_regions):,}")
assert len(excluded_regions) == 910 # as of 3/2023

# .saveas forces this to render, otherwise may be a generator
# TODO: Fix path to be more specific
# cleaned_sorted_bs_cov = raw_bs_cov_bed.subtract(excluded_regions).sort().saveas('bs_cov_cleaned_sorted.bed')
cleaned_sorted_bs_cov = raw_bs_cov_bed[~raw_bs_cov_bed.isin(excluded_regions)].dropna().sort_values(['chrom', 'start'])
print(f"Number of remaining bs_cov entries: {len(cleaned_sorted_bs_cov):,}")
assert len(cleaned_sorted_bs_cov) > 90000 # We expect about 90k entries


# Convert `bs_cov_cleaned_sorted` to a dict too:
#  key: chr
#  val: [sorted list of bs_cov positions]
# NOTE: This works because dicts are insertion ordered as of Python>3.7
BS_COV_POSITIONS = {}

for bed_entry in cleaned_sorted_bs_cov.itertuples():
    BS_COV_POSITIONS.setdefault(bed_entry.chrom, []).append(bed_entry.start)

#for bed_entry in cleaned_sorted_bs_cov:
#    BS_COV_POSITIONS.setdefault(bed_entry.chrom, []).append(bed_entry.start)
# Out:
# Number of entries in bs_cov (raw): 93,284
# Number of entries in excluded_regions: 910
# Number of remaining bs_cov entries: 93,230

# %% [markdown]
# #### Load bs_call data
#
# Now switch to methylation **calls** -- we only load calls that are within the shared coverage CpGs defined above.
#
# The Blueprint project generated these calls using https://github.com/heathsc/bs_call, see details: http://dcc.blueprint-epigenome.eu/#/md/bs_seq_grch38

# %%
# NOTE: Blueprint also has some high/low methylation calls, aggregated into clusters, e.g.:
#       `P579.hyper_meth.bs_call.GRCh38.20150707.bed.gz`
#       Those files contain nearest gene annotations, region-wide scores, etc.
#       We don't use them here and prefer raw individual CpGs.

# Store cpg_call values for all files in a dict of dicts:
# Dict of:
#  key: file_id (e.g. "S009W451")
#  val: dict of chr->list of bs_call ints
#     e.g. "chr1": [1, 4, 1, 0, 12 …]
FILE_ID_TO_CPG_CALLS = { }

# cache_file = "bs_call_min_" + str(BLUEPRINT_CPG_COV_MINIMUM) + ".json"
print("Parsing bs_call files. [This should take ~10 minutes.]")
for file_key in tqdm(BLUEPRINT_FILEKEYS):
    print(f"{file_key}", end=" ")
    FILE_ID_TO_CPG_CALLS[file_key] = {}
    with pyBigWig.open(BLUEPRINT_DATA_PATH + "/" + file_key + ".CPG_methylation_calls.bs_call.GRCh38.20160531.bw") as bw_object:
        for chrom in CHROMOSOMES:
            # This is more nuanced than the bs_cov data, since we only want to look at the 
            # CpGs that were covered across all samples. (The intervals now in BS_COV_POSITIONS).

            # Grabbing the entire chr interval is super slow
            # FILE_ID_TO_CPG_CALLS[file_key][chrom] = [i for pos, _, i in bw_object.intervals(chrom) if pos in shared_pos_for_this_chromosome]
            
            # Each .bw interval is a nested tuple of: ((start, end, value))
            # We extract all the values that overlap our bs_cov set.
            FILE_ID_TO_CPG_CALLS[file_key][chrom] = [bw_object.intervals(chrom, pos, pos+1)[0][2] for pos in BS_COV_POSITIONS[chrom]]
# Out:
# Parsing bs_call files. [This should take ~10 minutes.]
#   0%|          | 0/82 [00:00<?, ?it/s]
# S009W451 S008H151 S007DD51 P580 P582 P584 P586 S007G756 S006YC51 S014QS55 S001U352 S014QS51 C0066P51 C003VO55 C00256A1bs S00C2F51 C003VO56 C005UI52 C00256A3bs S014WG51 S002ND51 S0164R51 S00XTP51 S001U353 S01ECGA1 NBC_NC11_83 NBC_NC11_41 S001JP51 C003K951 S00DM851 C0068L51 S017RE51 C003N351 S00XCMA1 S00XDKU1 S00XEIU1 G204 G203 S01BHIA1 S01MAPA1 S01E03A1 S001S751 S0039051 S0022I51 S00BHQ51 S00DVR51 C005VG51 S0022I53 S001S753 S0018A52 S00H6O51 S007SK51 S001MJ51 S00BS451 S0062252 S00FTN51 S00C1H51 S00E8W51 S006VI53 C0067N51 S01E8O51 C002CTA1bs C006G551 S00K5EA1 C00184A3bs C001UYA1bs C0010KA1bs C004GD51 C0011IA3bs C000S5A2bs S00FWHA1 S00K7AA1 S00V6553 S006XE53 S00TU2A1 S00TV0A1 S00TXXA1 S00TYVA1 S004AV51 S004BT51 S002S351 S002R551

# %% [markdown]
# ## Export Data as a .tsv
#
# For reproducibility, we store our data as a jumbo .tsv. This allows us to move the model around, re-load at this stage, etc.
#
# We export a **ludicrous** tsv like:
#
# ```
# sampleid    celltype    chr1:123    chr1:234    ...
# S00K5EA1    Neutrophil  4   0   ...
# ```
#
# The dimensions here will be roughly 90,000 x 83. [CPGs x Samples]
#
# (Note that this would be better stored as a .zarr or .h5 file in the future.)

# %%
BLUEPRINT_TSV_EXPORT_FILE = f"blueprint_condensed_data_{RUN_SIGNATURE}.tsv"

if not os.path.isfile(BLUEPRINT_TSV_EXPORT_FILE):
    print(f"Writing Blueprint data to a .tsv for portability: {BLUEPRINT_TSV_EXPORT_FILE}")
    with open(BLUEPRINT_TSV_EXPORT_FILE, 'w', newline='') as tsvfile:
        tsv_writer = csv.writer(tsvfile, delimiter='\t', quoting=csv.QUOTE_NONE)

        # Write an enormous header including all BS_COV_POSITIONS as "chr1:123"
        tsv_writer.writerow(['sample', 'celltype'] +
                               [f"{chrom}:{start_pos}" for chrom, chrom_pos_list in BS_COV_POSITIONS.items() for start_pos in chrom_pos_list])
        
        # Loop over all our file bs_call entries and write
        for file_id, file_cov_dict in tqdm(FILE_ID_TO_CPG_CALLS.items()):
            tsv_writer.writerow([file_id, FILE_ID_TO_CELL_TYPE[file_id]] + 
                                [start_pos for chrom, chrom_pos_list in file_cov_dict.items() for start_pos in chrom_pos_list])
else:
    print(f"Skipping writing Blueprint data: {BLUEPRINT_TSV_EXPORT_FILE} already exists.")

# TODO: Implement as non-directory store, compress, etc.
if not os.path.isfile(f"blueprint_condensed_data_{RUN_SIGNATURE}.zarr"):
    print(f"Writing Blueprint data to a .zarr for portability: blueprint_condensed_data_{RUN_SIGNATURE}.zarr")

    # Also write a .zarr file for easy loading in Python
    with zarr.open(f"blueprint_condensed_data_{RUN_SIGNATURE}.zarr", mode='w') as zarr_out:
        zarr_out['sample'] = np.array([file_id for file_id in FILE_ID_TO_CPG_CALLS.keys()])
        zarr_out['celltype'] = np.array([FILE_ID_TO_CELL_TYPE[file_id] for file_id in FILE_ID_TO_CPG_CALLS.keys()])
        zarr_out['data'] = np.array([[start_pos for chrom, chrom_pos_list in file_cov_dict.items() for start_pos in chrom_pos_list] for file_cov_dict in FILE_ID_TO_CPG_CALLS.values()])
else:
    print(f"Skipping writing Blueprint data: blueprint_condensed_data_{RUN_SIGNATURE}.zarr already exists.")
# Out:
# Skipping writing Blueprint data: blueprint_condensed_data_10_5882f660.tsv already exists.
# Writing Blueprint data to a .zarr for portability: blueprint_condensed_data_10_5882f660.zarr

# %% [markdown]
# # Trial of ML Models
#
# First, we try TFDF since it has a nice new visual exploration tool for model performance.

# %%
# Load the .zarr file
with zarr.open(f"blueprint_condensed_data_{RUN_SIGNATURE}.zarr", mode='r') as zarr_in:
    zarr_sample = zarr_in['sample'][:]
    zarr_celltype = zarr_in['celltype'][:]
    zarr_data = zarr_in['data'][:]

# Now we have a condensed data matrix of all the Blueprint samples, with the following dimensions:
#   1. Samples (rows)
#   2. CpGs (columns)
#   3. bs_call values (0-12)

# We can now use this data matrix to do some analysis.

# For example, we can calculate the correlation between all pairs of samples.
corr_matrix = np.corrcoef(zarr_data)
# Show this as a heatmap, with sample labels
plt.figure(figsize=(10,10))
plt.imshow(corr_matrix, cmap='hot', interpolation='nearest')
plt.xticks(range(len(zarr_sample)), zarr_sample, rotation=90)
plt.yticks(range(len(zarr_sample)), zarr_sample)

# update the axes to include cell type from FILE_ID_TO_CELL_TYPE
plt.gca().set_xticklabels([f"{sample} ({FILE_ID_TO_CELL_TYPE[sample]})" for sample in zarr_sample])
plt.gca().set_yticklabels([f"{sample} ({FILE_ID_TO_CELL_TYPE[sample]})" for sample in zarr_sample])
plt.colorbar()
plt.gca().tick_params(axis='both', which='major', labelsize=5)

plt.title("Correlation between Blueprint samples")
plt.gca().title.set_fontsize(10)
plt.show()

# %% [markdown]
# Let's try a simple model with 10% of the data, and see how it performs.
#
# ## TFDF
#
# ## PyTorch
#
# ## PyTorch with SMOTE
#
# ## PyTorch with SMOTE + PCA
#
# ## PyTorch with SMOTE + PCA + Feature Selection

# %%
# First, let's try TFDF with the default parameters.

# We'll use the same data matrix as above, but we'll convert it to a pandas DataFrame.
# This is just for convenience, since TFDF expects a pandas DataFrame.

# We'll also convert the cell type labels to integers, since TFDF expects a numeric label.

# We'll also convert the cell type labels to integers, since TFDF expects a numeric label.

BS_COV_POSITIONS_FLAT = [f"{chrom}:{start_pos}" for chrom, chrom_pos_list in BS_COV_POSITIONS.items() for start_pos in chrom_pos_list]
CELL_TYPE_TO_INT = {cell_type: i for i, cell_type in enumerate(set(FILE_ID_TO_CELL_TYPE.values()))}

data = pd.DataFrame(zarr_data, index=zarr_sample, columns=BS_COV_POSITIONS_FLAT)
# We'll also convert the cell type labels to integers, since TFDF expects a numeric label.
data['celltype'] = [CELL_TYPE_TO_INT[FILE_ID_TO_CELL_TYPE[sample]] for sample in zarr_sample]
data

# Load the data into a TFDF dataset
dataset = tfdf.keras.pd_dataframe_to_tf_dataset(data, label='celltype')
dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 19
#      16 data
#      18 # Load the data into a TFDF dataset
# ---> 19 dataset = tfdf.keras.pd_dataframe_to_tf_dataset(data, label='celltype')
#      20 dataset
#
# NameError: name 'tfdf' is not defined

# %%
# experiument with loading this

tfds = tf.data.experimental.make_csv_dataset(TF_CSV_EXPORT_FILE,
                                             batch_size=128,
                                             label_name="celltype",
                                             # Skip the first sampleid column
                                             select_columns=range(1,len(cleaned_sorted_bs_cov)+2))
# Out:
# 2022-04-12 14:28:30.966357: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
for data, labels in tfds:
    print("here!")
    print(labels)
    print(data.shape)
# Out:
# 2022-04-13 13:03:29.721943: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 1 of 10000
# 2022-04-13 13:03:29.806389: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 2 of 10000
# 2022-04-13 13:03:29.890336: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 3 of 10000
# 2022-04-13 13:03:29.970733: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 4 of 10000
# 2022-04-13 13:03:30.050091: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 5 of 10000
# 2022-04-13 13:03:30.131031: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 6 of 10000
# 2022-04-13 13:03:30.210359: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 7 of 10000
# 2022-04-13 13:03:30.297362: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 8 of 10000
# 2022-04-13 13:03:30.382760: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 9 of 10000
# 2022-04-13 13:03:30.472552: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 10 of 10000
# 2022-04-13 13:03:30.564275: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 11 of 10000
# 2022-04-13 13:03:30.658843: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 12 of 10000
# 2022-04-13 13:03:30.733616: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 13 of 10000
# 2022-04-13 13:03:30.820617: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 14 of 10000
# 2022-04-13 13:03:30.915672: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 15 of 10000
# 2022-04-13 13:03:30.991520: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 16 of 10000
# 2022-04-13 13:03:31.081872: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 17 of 10000
# 2022-04-13 13:03:31.170563: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 18 of 10000
# 2022-04-13 13:03:31.253681: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 19 of 10000
# 2022-04-13 13:03:31.343223: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 20 of 10000
# 2022-04-13 13:03:31.430753: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 21 of 10000
# 2022-04-13 13:03:31.516897: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 22 of 10000
# 2022-04-13 13:03:31.605558: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 23 of 10000
# 2022-04-13 13:03:31.691327: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 24 of 10000
# 2022-04-13 13:03:31.774514: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 25 of 10000
# 2022-04-13 13:03:31.861466: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 26 of 10000
# 2022-04-13 13:03:31.948394: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 27 of 10000
# 2022-04-13 13:03:32.035756: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 28 of 10000
# 2022-04-13 13:03:32.122077: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 29 of 10000
# 2022-04-13 13:03:32.203941: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 30 of 10000
# 2022-04-13 13:03:32.292378: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 31 of 10000
# 2022-04-13 13:03:32.377661: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 32 of 10000
# 2022-04-13 13:03:32.463894: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 33 of 10000
# 2022-04-13 13:03:32.553467: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 34 of 10000
# 2022-04-13 13:03:32.645544: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 35 of 10000
# 2022-04-13 13:03:32.727259: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 36 of 10000
# 2022-04-13 13:03:32.818016: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 37 of 10000
# 2022-04-13 13:03:32.909227: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 38 of 10000
# 2022-04-13 13:03:32.996364: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 39 of 10000
# 2022-04-13 13:03:33.081235: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 40 of 10000
# 2022-04-13 13:03:33.164664: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 41 of 10000
# 2022-04-13 13:03:33.250082: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 42 of 10000
# 2022-04-13 13:03:33.336157: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 43 of 10000
# 2022-04-13 13:03:33.422731: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 44 of 10000
# 2022-04-13 13:03:33.508805: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 45 of 10000
# 2022-04-13 13:03:33.593409: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 46 of 10000
# 2022-04-13 13:03:33.676118: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 47 of 10000
# 2022-04-13 13:03:33.763987: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 48 of 10000
# 2022-04-13 13:03:33.850200: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 49 of 10000
# 2022-04-13 13:03:33.936431: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 50 of 10000
# 2022-04-13 13:03:34.024785: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 51 of 10000
# 2022-04-13 13:03:38.009502: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 93 of 10000
# 2022-04-13 13:03:47.979927: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:380] Filling up shuffle buffer (this may take a while): 204 of 10000
# 2022-04-13 13:03:52.066540: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:405] Shuffle buffer filled.
# here!
# tf.Tensor(
# [b'T_CD4_effector_memory' b'Neutrophil' b'T_CD4_naive' b'Macrophage_M0'
#  b'Erythroblast' b'Macrophage_M2' b'Macrophage_M1' b'NK_cell'
#  b'B_cell_naive' b'T_CD4_central_memory' b'Macrophage_M0' b'B_cell_naive'
#  b'Dendtritic_immature' b'Treg' b'Macrophage_M0' b'Eosinophil'
#  b'T_CD8_central_memory' b'B_cell_memory' b'Neutrophil' b'Plasma_cell'
#  b'Monocyte' b'Macrophage_M2' b'T_CD4_central_memory' b'Macrophage_M2'
#  b'Neutrophil' b'T_CD4_naive' b'T_CD8_effector_memory' b'Neutrophil'
#  b'Plasma_cell' b'T_CD8_naive' b'T_CD8_effector_memory_terminal'
#  b'NK_cell' b'Neutrophil' b'Macrophage_M2' b'Macrophage_M1'
#  b'Macrophage_M2' b'Neutrophil' b'Neutrophil' b'B_cell_naive'
#  b'Neutrophil' b'T_CD4_naive' b'Dendtritic_immature' b'NK_cell'
#  b'B_cell_naive' b'Neutrophil' b'Treg' b'T_CD8_naive' b'B_cell_naive'
#  b'B_cell_naive' b'Erythroblast' b'Monocyte' b'T_CD4_naive'
#  b'B_cell_memory' b'Dendtritic_mature' b'Macrophage_M1' b'Plasma_cell'
#  b'Macrophage_M2' b'T_CD4_effector_memory' b'Eosinophil'
#  b'T_CD8_effector_memory' b'B_cell_naive' b'Plasma_cell' b'Megakaryocyte'
#  b'NK_cell' b'T_CD4_naive' b'Macrophage_M0' b'Macrophage_M0'
#  b'Dendtritic_mature' b'Monocyte' b'T_CD4_naive' b'T_CD8_naive'
#  b'T_CD4_naive' b'Plasma_cell' b'T_CD4_naive' b'T_CD8_naive'
#  b'Megakaryocyte' b'Macrophage_M1' b'Macrophage_M1' b'Macrophage_M1'
#  b'Macrophage_M0' b'T_CD8_effector_memory_terminal'
#  b'T_CD8_central_memory' b'Macrophage_M2' b'Plasma_cell' b'Macrophage_M2'
#  b'Macrophage_M0' b'T_CD4_effector_memory' b'T_CD4_central_memory'
#  b'T_CD8_central_memory' b'T_CD4_naive' b'Dendtritic_immature'
#  b'Megakaryocyte' b'B_cell_naive' b'Neutrophil' b'T_CD8_naive'
#  b'Plasma_cell' b'Macrophage_M2' b'T_CD8_effector_memory_terminal'
#  b'T_CD4_naive' b'Macrophage_M0' b'T_CD4_naive' b'T_CD8_naive' b'Monocyte'
#  b'Macrophage_M1' b'T_CD8_central_memory' b'Neutrophil' b'B_cell_memory'
#  b'Macrophage_M2' b'Dendtritic_mature' b'B_cell_naive' b'Neutrophil'
#  b'T_CD4_naive' b'B_cell_naive' b'Macrophage_M0' b'NK_cell'
#  b'Megakaryocyte' b'Plasma_cell' b'T_CD8_effector_memory_terminal'
#  b'Macrophage_M0' b'T_CD4_effector_memory' b'Treg' b'NK_cell'
#  b'T_CD8_effector_memory' b'T_CD4_naive' b'Neutrophil'
#  b'Dendtritic_mature' b'T_CD8_effector_memory' b'Macrophage_M1'], shape=(128,), dtype=string)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [100], in <cell line: 1>()
#       2 print("here!")
#       3 print(labels)
# ----> 4 print(data.shape)
#
# AttributeError: 'collections.OrderedDict' object has no attribute 'shape'

# %% [markdown]
# ### Encode Data
#
# Encode has tissue-level data, but less immune cell data. (e.g. it contains liver, thyroid, etc., but no CD4+ T cells).

# %%
# Encode 117 human WGBS samples, and more from RRBS -- however they are esentially all whole tissues (e.g. "liver")
# We can consider building a mixed model later; for now, we want only specific cells.

# %% [markdown]
# ### DEEP Data
#
# Part of a gGerman consortium: https://deep.dkfz.de/#/experiments
#
# This has a handful of immunologic lineages, along with mixed tissue similar to Encode.

# %%
# https://deep.dkfz.de/#/experiments

# %% [markdown]
# ### RNBeads
#
# A post-processing of multiple data sources, useful aggregation: https://rnbeads.org/methylomes.html

# %% [markdown]
# ### Array Data
#
# Infinium array methylation data

# %%
# Should we bulk download these?

# %% [markdown]
# ## Compute cell fingerprints -- Individual CpG approach
#
# At this point we have a ton of CpGs (~300,000) across our samples. From Blueprint, each has a value stored as a float, from 0.0-1.0 reflecting % methylation.
#
# This is now a multi-class classification problem (i.e. each cell belongs to **exactly** one of multiple classes) -- though we can implement it more flexibly as a multi-label classifier (i.e. each cell may belong to multiple classes, with different probability).
#
# For example, a true CD4+ T cell might get assigned `p(CD4) = 0.9` and `p(CD8) = 0.6`, and hopefully low probabilities for less related cell types, e.g. `p(Mφ) = 0.2`.
#
# We can try to model this with Tensorflow or scikit-learn, among other packages. Let's see how those perform.
#
# **Note**: These ignore methylation co-occurrence data -- i.e. two or more CpGs methylated on the same read --  which can't be obtained from the bs_call data, only raw .bam data.

# %% [markdown]
# ### Subset Blueprint Data
#
# We have a huge imbalance in our data; very few labels (cell types), but >300,000 CpGs. we can try to reduce our CpG list further to those likely to be the most informative.
#
# One option (not implemented here), is to limit CpGs based on genomic position -- exon / intron / within NN bp of start/stop, etc.
#
# We can also threshold the CpGs to require a minimum coverage.

# %% [markdown]
# ### Perform multi-label classification (individual CpG only)

# %% [markdown]
# #### WIP CODE Define a test/train split

# %%
# TODO: Remove / archive this code? Splitting separately in sckit-learn/TensorFlow, below.

### Establish a test/train split on these (limited) data.
# Below, we can also compare to Encode and internal data.
TEST_TRAIN_SPLIT = 0.25  # Hold out 25% of each cell type's files as a test set.

CELL_TYPE_TO_FILE_ID_TRAIN = {}
CELL_TYPE_TO_FILE_ID_TEST = {}

for cell_type, cell_files in CELL_TYPE_TO_FILE_ID.items():
    # Take a minimum of 1 item, regardless of % above.
    CELL_TYPE_TO_FILE_ID_TEST[cell_type] = random.sample(cell_files, max(1, round(len(cell_files) * TEST_TRAIN_SPLIT)))
    CELL_TYPE_TO_FILE_ID_TRAIN[cell_type] = [x for x in cell_files if x not in CELL_TYPE_TO_FILE_ID_TEST[cell_type]]

# %%
train_test_stats_df = pd.DataFrame(list(
    zip(
        CELL_TYPE_TO_FILE_ID.keys(),
        [len(e) for e in CELL_TYPE_TO_FILE_ID.values()], 
        [len(e) for e in CELL_TYPE_TO_FILE_ID_TRAIN.values()],
        [len(e) for e in CELL_TYPE_TO_FILE_ID_TEST.values()]
        )
    ),
    columns = ["Cell", "Total", "Train", "Test"])

train_test_stats_df
# Out:
#              Cell  Total  Train  Test
# 0             CD4      8      6     2
# 1             CD8      4      3     1
# 2            Treg      2      1     1
# 3    B_cell_naive      7      5     2
# 4   B_cell_memory      2      1     1
# 5     Plasma_cell      5      4     1
# 6        Monocyte      3      2     1
# 7   Macrophage_M0      6      4     2
# 8   Macrophage_M1      6      4     2
# 9   Macrophage_M2      6      4     2
# 10        NK_cell      4      3     1
# 11     Neutrophil      9      7     2
# 12     Eosinophil      2      1     1
# 13   Erythroblast      2      1     1

# %%
fig = px.bar(
        train_test_stats_df,
        x="Cell", y="Total", color="Test", text_auto=True,
        title="Amount of Blueprint WGBS Test/Train Data (# of BAM files) per Cell Type"
)
fig.update_layout(autosize=False, width=800)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.11.1.min.js"></script>                <div id="c18ee066-60e4-49b8-8b16-92fe8052b30d" class="plotly-graph-div" style="height:525px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c18ee066-60e4-49b8-8b16-92fe8052b30d")) {                    Plotly.newPlot(                        "c18ee066-60e4-49b8-8b16-92fe8052b30d",                        [{"alignmentgroup":"True","hovertemplate":"Cell=%{x}<br>Total=%{y}<br>Test=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[2,1,1,2,1,1,1,2,2,2,1,2,1,1],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["CD4","CD8","Treg","B_cell_naive","B_cell_memory","Plasma_cell","Monocyte","Macrophage_M0","Macrophage_M1","Macrophage_M2","NK_cell","Neutrophil","Eosinophil","Erythroblast"],"xaxis":"x","y":[8,4,2,7,2,5,3,6,6,6,4,9,2,2],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line ...

# %% [markdown]
# ##### Define a TensorFlow Decision Forests GBDT Mdel

# %%
## Establish our TensorFlow Model
# List available models
tfdf.keras.get_all_models()
# Out:
# [tensorflow_decision_forests.keras.RandomForestModel,
#  tensorflow_decision_forests.keras.GradientBoostedTreesModel,
#  tensorflow_decision_forests.keras.CartModel,
#  tensorflow_decision_forests.keras.DistributedGradientBoostedTreesModel]

# %%
# Existing hyperparameters for our chosen model
print(tfdf.keras.GradientBoostedTreesModel.predefined_hyperparameters())
# Out:
# [HyperParameterTemplate(name='better_default', version=1, parameters={'growing_strategy': 'BEST_FIRST_GLOBAL'}, description='A configuration that is generally better than the default parameters without being more expensive.'), HyperParameterTemplate(name='benchmark_rank1', version=1, parameters={'growing_strategy': 'BEST_FIRST_GLOBAL', 'categorical_algorithm': 'RANDOM', 'split_axis': 'SPARSE_OBLIQUE', 'sparse_oblique_normalization': 'MIN_MAX', 'sparse_oblique_num_projections_exponent': 1.0}, description='Top ranking hyper-parameters on our benchmark slightly modified to run in reasonable time.')]

# %%
## First let's format data for TensorFlow

# We can create a tensor directly, but it's more flexible to manipulate things in a Pandas dataframe.
temp_array_for_df = []

for k, v in CELL_TYPE_TO_FILE_ID.items():
    for file_id in v:
        working = [k]
        # TODO: Expand beyond Chr1
        # Expand this, which is a nest per-chromosome list
        working.extend(FILE_ID_TO_CPG_CALLS[file_id]['chr1']) # [val for chrom in FILE_ID_TO_CPG_CALLS[file_id] for val in chrom]
        temp_array_for_df.append(working)

per_cpg_df = pd.DataFrame(temp_array_for_df)

# TODO: Rename columns to actual cpg loci
per_cpg_df.rename(columns={0: 'CellType'}, inplace=True)
# A bit of a hack: int->string, as tfdf seems to require iterable column names (to check if they're valid, oddly). 
per_cpg_df.columns = [str(x) for x in per_cpg_df.columns]

# %%
# Let's train a classification model on this label:
CLASSIFICATION_LABEL = "CellType"

# NOTE: Classification labels must be integers.
classes = sorted(per_cpg_df[CLASSIFICATION_LABEL].unique().tolist())
print(f"Label classes for: {CLASSIFICATION_LABEL} = {classes}\n")

classification_model_data = per_cpg_df.copy()
classification_model_data[CLASSIFICATION_LABEL] = classification_model_data[CLASSIFICATION_LABEL].map(classes.index)
print(f"Input data shape: {classification_model_data.shape}")
# Out:
# Label classes for: CellType = ['B_cell_memory', 'B_cell_naive', 'CD4', 'CD8', 'Eosinophil', 'Erythroblast', 'Macrophage_M0', 'Macrophage_M1', 'Macrophage_M2', 'Monocyte', 'NK_cell', 'Neutrophil', 'Plasma_cell', 'Treg']
#
# Input data shape: (66, 7809)

# %%
# Split into test/train datasets and labels, with equal percentages of each cell type.
# Note: We join the labels back into the dataset below, as that works a little better with tfdf.
cpg_train_ds, cpg_test_ds, label_train_ds, label_test_ds = sklearn.model_selection.train_test_split(classification_model_data.drop(['CellType'], axis=1),
                                                                                        classification_model_data['CellType'],
                                                                                        test_size=0.2,
                                                                                        random_state=2022,
                                                                                        stratify=classification_model_data['CellType']) # Force equal % of class labels.

print(f"Training data shape: {cpg_train_ds.shape}")
print(f"Testing data shape: {cpg_test_ds.shape}")

# Add the labels back into the data; this works more cleanly with tfdf.
training_df = pd.concat([label_train_ds, cpg_train_ds], axis=1)
testing_df = pd.concat([label_test_ds, cpg_test_ds], axis=1)

assert not training_df.isnull().values.any()
assert not testing_df.isnull().values.any()

print("Converting Pandas data to TensorFlow dataset...")
training_classification_ds_tf = tfdf.keras.pd_dataframe_to_tf_dataset(training_df, label=CLASSIFICATION_LABEL,
                                                                      task=tfdf.keras.Task.CLASSIFICATION, fix_feature_names=False)

testing_classification_ds_tf = tfdf.keras.pd_dataframe_to_tf_dataset(testing_df, label=CLASSIFICATION_LABEL,
                                                                     task=tfdf.keras.Task.CLASSIFICATION, fix_feature_names=False)
# Out:
# Training data shape: (52, 7808)
# Testing data shape: (14, 7808)
# Converting Pandas data to TensorFlow dataset...
# /home/nsemenkovich/.local/miniconda3/envs/jupyter/lib/python3.9/site-packages/tensorflow_decision_forests/keras/core.py:2038: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#
# /home/nsemenkovich/.local/miniconda3/envs/jupyter/lib/python3.9/site-packages/tensorflow_decision_forests/keras/core.py:2038: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.

# %%
print(f"Training GradientBoostedTrees classification model on: {CLASSIFICATION_LABEL}")

gbt_classification_model = tfdf.keras.GradientBoostedTreesModel(
    num_threads=NUM_USABLE_CPUS,
    task=tfdf.keras.Task.CLASSIFICATION,
    hyperparameter_template="benchmark_rank1"
    )

gbt_classification_model.compile(metrics=["accuracy"])

gbt_classification_model.fit(training_classification_ds_tf, verbose=2)
# Out:
# Training GradientBoostedTrees classification model on: CellType
# Resolve hyper-parameter template "benchmark_rank1" to "benchmark_rank1@v1" -> {'growing_strategy': 'BEST_FIRST_GLOBAL', 'categorical_algorithm': 'RANDOM', 'split_axis': 'SPARSE_OBLIQUE', 'sparse_oblique_normalization': 'MIN_MAX', 'sparse_oblique_num_projections_exponent': 1.0}.
# Use /tmp/tmpfkylzgl2 as temporary training directory
# Starting reading the dataset
# Training tensor examples:
# Features: {'1': <tf.Tensor 'data:0' shape=(None,) dtype=float64>, '2': <tf.Tensor 'data_1111:0' shape=(None,) dtype=float64>, '3': <tf.Tensor 'data_2222:0' shape=(None,) dtype=float64>, '4': <tf.Tensor 'data_3333:0' shape=(None,) dtype=float64>, '5': <tf.Tensor 'data_4444:0' shape=(None,) dtype=float64>, '6': <tf.Tensor 'data_5555:0' shape=(None,) dtype=float64>, '7': <tf.Tensor 'data_6666:0' shape=(None,) dtype=float64>, '8': <tf.Tensor 'data_7586:0' shape=(None,) dtype=float64>, '9': <tf.Tensor 'data_7697:0' shape=(None,) dtype=float64>, '10': <tf.Tensor 'data_1:0' shape=(None,) dtype=float64>, '11': <tf.Tensor 'data_112:0' shape=(None,) dtype=float64>, '12': <tf.Tensor 'data_223:0' shape=(None,) dtype=float64>, '13': <tf.Tensor 'data_334:0' shape=(None,) dtype=float64>, '14': <tf.Tensor 'data_445:0' shape=(None,) dtype=float64>, '15': <tf.Tensor 'data_556:0' shape=(None,) dtype=float64>, '16': <tf.Tensor 'data_667:0' shape=(None,) dtype=float64>, '17': <tf.Tensor 'data_778:0' shape=(None,) dtype=float64>, '18': <tf.Tensor 'data_889:0' shape=(None,) dtype=float64>, '19': <tf.Tensor 'data_1000:0' shape=(None,) dtype=float64>, '20': <tf.Tensor 'data_1112:0' shape=(None,) dtype=float64>, '21': <tf.Tensor 'data_1223:0' shape=(None,) dtype=float64>, '22': <tf.Tensor 'data_1334:0' shape=(None,) dtype=float64>, '23': <tf.Tensor 'data_1445:0' shape=(None,) dtype=float64>, '24': <tf.Tensor 'data_1556:0' shape=(None,) dtype=float64>, '25': <tf.Tensor 'data_1667:0' shape=(None,) dtype=float64>, '26': <tf.Tensor 'data_1778:0' shape=(None,) dtype=float64>, '27': <tf.Tensor 'data_1889:0' shape=(None,) dtype=float64>, '28': <tf.Tensor 'data_2000:0' shape=(None,) dtype=float64>, '29': <tf.Tensor 'data_2111:0' shape=(None,) dtype=float64>, '30': <tf.Tensor 'data_2223:0' shape=(None,) dtype=float64>, '31': <tf.Tensor 'data_2334:0' shape=(None,) dtype=float64>, '32': <tf.Tensor 'data_2445:0' shape=(None,) dtype=float64>, '33': <tf.Tensor 'data_2556:0' shape=(None,) dtype=float64>, '34': <tf.Tensor 'data_2667:0' shape=(None,) dtype=float64>, '35': <tf.Tensor 'data_2778:0' shape=(None,) dtype=float64>, '36': <tf.Tensor 'data_2889:0' shape=(None,) dtype=float64>, '37': <tf.Tensor 'data_3000:0' shape=(None,) dtype=float64>, '38': <tf.Tensor 'data_3111:0' shape=(None,) dtype=float64>, '39': <tf.Tensor 'data_3222:0' shape=(None,) dtype=float64>, '40': <tf.Tensor 'data_3334:0' shape=(None,) dtype=float64>, '41': <tf.Tensor 'data_3445:0' shape=(None,) dtype=float64>, '42': <tf.Tensor 'data_3556:0' shape=(None,) dtype=float64>, '43': <tf.Tensor 'data_3667:0' shape=(None,) dtype=float64>, '44': <tf.Tensor 'data_3778:0' shape=(None,) dtype=float64>, '45': <tf.Tensor 'data_3889:0' shape=(None,) dtype=float64>, '46': <tf.Tensor 'data_4000:0' shape=(None,) dtype=float64>, '47': <tf.Tensor 'data_4111:0' shape=(None,) dtype=float64>, '48': <tf.Tensor 'data_4222:0' shape=(None,) dtype=float64>, '49': <tf.Tensor 'data_4333:0' shape=(None,) dtype=float64>, '50': <tf.Tensor 'data_4445:0' shape=(None,) dtype=float64>, '51': <tf.Tensor 'data_4556:0' shape=(None,) dtype=float64>, '52': <tf.Tensor 'data_4667:0' shape=(None,) dtype=float64>, '53': <tf.Tensor 'data_4778:0' shape=(None,) dtype=float64>, '54': <tf.Tensor 'data_4889:0' shape=(None,) dtype=float64>, '55': <tf.Tensor 'data_5000:0' shape=(None,) dtype=float64>, '56': <tf.Tensor 'data_5111:0' shape=(None,) dtype=float64>, '57': <tf.Tensor 'data_5222:0' shape=(None,) dtype=float64>, '58': <tf.Tensor 'data_5333:0' shape=(None,) dtype=float64>, '59': <tf.Tensor 'data_5444:0' shape=(None,) dtype=float64>, '60': <tf.Tensor 'data_5556:0' shape=(None,) dtype=float64>, '61': <tf.Tensor 'data_5667:0' shape=(None,) dtype=float64>, '62': <tf.Tensor 'data_5778:0' shape=(None,) dtype=float64>, '63': <tf.Tensor 'data_5889:0' shape=(None,) dtype=float64>, '64': <tf.Tensor 'data_6000:0' shape=(None,) dtype=float64>, '65': <tf.Tensor 'data_6111:0' shape=(None,) dtype=float64>, '66': <tf.Tensor 'data_6222:0' shape=(None,) dtyp ...
# Label: Tensor("data_7808:0", shape=(None,), dtype=int64)
# Weights: None
# Normalized tensor features:
#  {'1': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast:0' shape=(None,) dtype=float32>), '2': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_1:0' shape=(None,) dtype=float32>), '3': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_2:0' shape=(None,) dtype=float32>), '4': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_3:0' shape=(None,) dtype=float32>), '5': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_4:0' shape=(None,) dtype=float32>), '6': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_5:0' shape=(None,) dtype=float32>), '7': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_6:0' shape=(None,) dtype=float32>), '8': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_7:0' shape=(None,) dtype=float32>), '9': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_8:0' shape=(None,) dtype=float32>), '10': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_9:0' shape=(None,) dtype=float32>), '11': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_10:0' shape=(None,) dtype=float32>), '12': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_11:0' shape=(None,) dtype=float32>), '13': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_12:0' shape=(None,) dtype=float32>), '14': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_13:0' shape=(None,) dtype=float32>), '15': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_14:0' shape=(None,) dtype=float32>), '16': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_15:0' shape=(None,) dtype=float32>), '17': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_16:0' shape=(None,) dtype=float32>), '18': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_17:0' shape=(None,) dtype=float32>), '19': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_18:0' shape=(None,) dtype=float32>), '20': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_19:0' shape=(None,) dtype=float32>), '21': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_20:0' shape=(None,) dtype=float32>), '22': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_21:0' shape=(None,) dtype=float32>), '23': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_22:0' shape=(None,) dtype=float32>), '24': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_23:0' shape=(None,) dtype=float32>), '25': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_24:0' shape=(None,) dtype=float32>), '26': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_25:0' shape=(None,) dtype=float32>), '27': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_26:0' shape=(None,) dtype=float32>), '28': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_27:0' shape=(None,) dtype=float32>), '29': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_28:0' shape=(None,) dtype=float32>), '30': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_29:0' shape=(None,) dtype=float32>), '31': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_30:0' shape=(None,) dtype=float32>), '32': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_31:0' shape=(None,) dtype=float32>), '33': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_32:0' shape=(None,) dtype=float32>), '34': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'Cast_33:0' shape=(None,) dtype=float32>), '35': SemanticTensor(semantic=<Semantic.NUMERICAL: 1>, tensor=<tf.Tensor 'C ...
# Dataset read in 0:05:11.394758
# Training model
# Streaming output truncated to the last 5000 lines.
# features: "3593"
# features: "3594"
# features: "3595"
# features: "3596"
# features: "3597"
# features: "3598"
# features: "3599"
# features: "36"
# features: "360"
# features: "3600"
# features: "3601"
# features: "3602"
# features: "3603"
# features: "3604"
# features: "3605"
# features: "3606"
# features: "3607"
# features: "3608"
# features: "3609"
# features: "361"
# features: "3610"
# features: "3611"
# features: "3612"
# features: "3613"
# features: "3614"
# features: "3615"
# features: "3616"
# features: "3617"
# features: "3618"
# features: "3619"
# features: "362"
# features: "3620"
# features: "3621"
# features: "3622"
# features: "3623"
# features: "3624"
# features: "3625"
# features: "3626"
# features: "3627"
# features: "3628"
# features: "3629"
# features: "363"
# features: "3630"
# features: "3631"
# features: "3632"
# features: "3633"
# features: "3634"
# features: "3635"
# features: "3636"
# features: "3637"
# features: "3638"
# features: "3639"
# features: "364"
# features: "3640"
# features: "3641"
# features: "3642"
# features: "3643"
# features: "3644"
# features: "3645"
# features: "3646"
# features: "3647"
# features: "3648"
# features: "3649"
# features: "365"
# features: "3650"
# features: "3651"
# features: "3652"
# features: "3653"
# features: "3654"
# features: "3655"
# features: "3656"
# features: "3657"
# features: "3658"
# features: "3659"
# features: "366"
# features: "3660"
# features: "3661"
# features: "3662"
# features: "3663"
# features: "3664"
# features: "3665"
# features: "3666"
# features: "3667"
# features: "3668"
# features: "3669"
# features: "367"
# features: "3670"
# features: "3671"
# features: "3672"
# features: "3673"
# features: "3674"
# features: "3675"
# features: "3676"
# features: "3677"
# features: "3678"
# features: "3679"
# features: "368"
# features: "3680"
# features: "3681"
# features: "3682"
# features: "3683"
# features: "3684"
# features: "3685"
# features: "3686"
# features: "3687"
# features: "3688"
# features: "3689"
# features: "369"
# features: "3690"
# features: "3691"
# features: "3692"
# features: "3693"
# features: "3694"
# features: "3695"
# features: "3696"
# features: "3697"
# features: "3698"
# features: "3699"
# features: "37"
# features: "370"
# features: "3700"
# features: "3701"
# features: "3702"
# features: "3703"
# features: "3704"
# features: "3705"
# features: "3706"
# features: "3707"
# features: "3708"
# features: "3709"
# features: "371"
# features: "3710"
# features: "3711"
# features: "3712"
# features: "3713"
# features: "3714"
# features: "3715"
# features: "3716"
# features: "3717"
# features: "3718"
# features: "3719"
# features: "372"
# features: "3720"
# features: "3721"
# features: "3722"
# features: "3723"
# features: "3724"
# features: "3725"
# features: "3726"
# features: "3727"
# features: "3728"
# features: "3729"
# features: "373"
# features: "3730"
# features: "3731"
# features: "3732"
# features: "3733"
# features: "3734"
# features: "3735"
# features: "3736"
# features: "3737"
# features: "3738"
# features: "3739"
# features: "374"
# features: "3740"
# features: "3741"
# features: "3742"
# features: "3743"
# features: "3744"
# features: "3745"
# features: "3746"
# features: "3747"
# features: "3748"
# features: "3749"
# features: "375"
# features: "3750"
# features: "3751"
# features: "3752"
# features: "3753"
# features: "3754"
# features: "3755"
# features: "3756"
# features: "3757"
# features: "3758"
# features: "3759"
# features: "376"
# features: "3760"
# features: "3761"
# features: "3762"
# features: "3763"
# features: "3764"
# features: "3765"
# features: "3766"
# features: "3767"
# features: "3768"
# features: "3769"
# features: "377"
# features: "3770"
# features: "3771"
# features: "3772"
# features: "3773"
# features: "3774"
# features: "3775"
# features: "3776"
# features: "3777"
# features: "3778"
# features: "3779"
# features: "378"
# features: "3780"
# features: "3781"
# features: "3782"
# features: "3783"
# features: "3784"
# features: "3785"
# features: "3786"
# features: "3787"
# features: "3788"
# features: "3789"
# features: "379"
# features: "3790"
# features: "3791"
# features: "3792"
# features: "3793"
# features: "3794"
# features: "3795"
# features: "3796"
# features: "3797"
# features: "3798"
# features: "3799"
# features: "38"
# features: "380"
# features: "3800"
# features: "3801"
# features: "3802"
# features: "3803"
# features: "3804"
# features: "3805"
# features: "3806"
# features: "3807"
# features: "3808"
# features: "3809"
# features: "381"
# features: "3810"
# features: "3811"
# features: "3812"
# features: "3813"
# features: "3814"
# features: "3815"
# features: "3816"
# features: "3817"
# features: "3818"
# features: "3819"
# features: "382"
# features: "3820"
# features: "3821"
# features: "3822"
# features: "3823"
# features: "3824"
# features: "3825"
# features: "3826"
# features: "3827"
# features: "3828"
# features: "3829"
# features: "383"
# features: "3830"
# features: "3831"
# features: "3832"
# features: "3833"
# features: "3834"
# features: "3835"
# features: "3836"
# features: "3837"
# features: "3838"
# features: "3839"
# features: "384"
# features: "3840"
# features: "3841"
# features: "3842"
# features: "3843"
# features: "3844"
# features: "3845"
# features: "3846"
# features: "3847"
# features: "3848"
# features: "3849"
# features: "385"
# features: "3850"
# features: "3851"
# features: "3852"
# features: "3853"
# features: "3854"
# features: "3855"
# features: "3856"
# features: "3857"
# features: "3858"
# features: "3859"
# features: "386"
# features: "3860"
# features: "3861"
# features: "3862"
# features: "3863"
# features: "3864"
# features: "3865"
# features: "3866"
# features: "3867"
# features: "3868"
# features: "3869"
# features: "387"
# features: "3870"
# features: "3871"
# features: "3872"
# features: "3873"
# features: "3874"
# features: "3875"
# features: "3876"
# features: "3877"
# features: "3878"
# features: "3879"
# features: "388"
# features: "3880"
# features: "3881"
# features: "3882"
# features: "3883"
# features: "3884"
# features: "3885"
# features: "3886"
# features: "3887"
# features: "3888"
# features: "3889"
# features: "389"
# features: "3890"
# features: "3891"
# features: "3892"
# features: "3893"
# features: "3894"
# features: "3895"
# features: "3896"
# features: "3897"
# features: "3898"
# features: "3899"
# features: "39"
# features: "390"
# features: "3900"
# features: "3901"
# features: "3902"
# features: "3903"
# features: "3904"
# features: "3905"
# features: "3906"
# features: "3907"
# features: "3908"
# features: "3909"
# features: "391"
# features: "3910"
# features: "3911"
# features: "3912"
# features: "3913"
# features: "3914"
# features: "3915"
# features: "3916"
# features: "3917"
# features: "3918"
# features: "3919"
# features: "392"
# features: "3920"
# features: "3921"
# features: "3922"
# features: "3923"
# features: "3924"
# features: "3925"
# features: "3926"
# features: "3927"
# features: "3928"
# features: "3929"
# features: "393"
# features: "3930"
# features: "3931"
# features: "3932"
# features: "3933"
# features: "3934"
# features: "3935"
# features: "3936"
# features: "3937"
# features: "3938"
# features: "3939"
# features: "394"
# features: "3940"
# features: "3941"
# features: "3942"
# features: "3943"
# features: "3944"
# features: "3945"
# features: "3946"
# features: "3947"
# features: "3948"
# features: "3949"
# features: "395"
# features: "3950"
# features: "3951"
# features: "3952"
# features: "3953"
# features: "3954"
# features: "3955"
# features: "3956"
# features: "3957"
# features: "3958"
# features: "3959"
# features: "396"
# features: "3960"
# features: "3961"
# features: "3962"
# features: "3963"
# features: "3964"
# features: "3965"
# features: "3966"
# features: "3967"
# features: "3968"
# features: "3969"
# features: "397"
# features: "3970"
# features: "3971"
# features: "3972"
# features: "3973"
# features: "3974"
# features: "3975"
# features: "3976"
# features: "3977"
# features: "3978"
# features: "3979"
# features: "398"
# features: "3980"
# features: "3981"
# features: "3982"
# features: "3983"
# features: "3984"
# features: "3985"
# features: "3986"
# features: "3987"
# features: "3988"
# features: "3989"
# features: "399"
# features: "3990"
# features: "3991"
# features: "3992"
# features: "3993"
# features: "3994"
# features: "3995"
# features: "3996"
# features: "3997"
# features: "3998"
# features: "3999"
# features: "4"
# features: "40"
# features: "400"
# features: "4000"
# features: "4001"
# features: "4002"
# features: "4003"
# features: "4004"
# features: "4005"
# features: "4006"
# features: "4007"
# features: "4008"
# features: "4009"
# features: "401"
# features: "4010"
# features: "4011"
# features: "4012"
# features: "4013"
# features: "4014"
# features: "4015"
# features: "4016"
# features: "4017"
# features: "4018"
# features: "4019"
# features: "402"
# features: "4020"
# features: "4021"
# features: "4022"
# features: "4023"
# features: "4024"
# features: "4025"
# features: "4026"
# features: "4027"
# features: "4028"
# features: "4029"
# features: "403"
# features: "4030"
# features: "4031"
# features: "4032"
# features: "4033"
# features: "4034"
# features: "4035"
# features: "4036"
# features: "4037"
# features: "4038"
# features: "4039"
# features: "404"
# features: "4040"
# features: "4041"
# features: "4042"
# features: "4043"
# features: "4044"
# features: "4045"
# features: "4046"
# features: "4047"
# features: "4048"
# features: "4049"
# features: "405"
# features: "4050"
# features: "4051"
# features: "4052"
# features: "4053"
# features: "4054"
# features: "4055"
# features: "4056"
# features: "4057"
# features: "4058"
# features: "4059"
# features: "406"
# features: "4060"
# features: "4061"
# features: "4062"
# features: "4063"
# features: "4064"
# features: "4065"
# features: "4066"
# features: "4067"
# features: "4068"
# features: "4069"
# features: "407"
# features: "4070"
# features: "4071"
# features: "4072"
# features: "4073"
# features: "4074"
# features: "4075"
# features: "4076"
# features: "4077"
# features: "4078"
# features: "4079"
# features: "408"
# features: "4080"
# features: "4081"
# features: "4082"
# features: "4083"
# features: "4084"
# features: "4085"
# features: "4086"
# features: "4087"
# features: "4088"
# features: "4089"
# features: "409"
# features: "4090"
# features: "4091"
# features: "4092"
# features: "4093"
# features: "4094"
# features: "4095"
# features: "4096"
# features: "4097"
# features: "4098"
# features: "4099"
# features: "41"
# features: "410"
# features: "4100"
# features: "4101"
# features: "4102"
# features: "4103"
# features: "4104"
# features: "4105"
# features: "4106"
# features: "4107"
# features: "4108"
# features: "4109"
# features: "411"
# features: "4110"
# features: "4111"
# features: "4112"
# features: "4113"
# features: "4114"
# features: "4115"
# features: "4116"
# features: "4117"
# features: "4118"
# features: "4119"
# features: "412"
# features: "4120"
# features: "4121"
# features: "4122"
# features: "4123"
# features: "4124"
# features: "4125"
# features: "4126"
# features: "4127"
# features: "4128"
# features: "4129"
# features: "413"
# features: "4130"
# features: "4131"
# features: "4132"
# features: "4133"
# features: "4134"
# features: "4135"
# features: "4136"
# features: "4137"
# features: "4138"
# features: "4139"
# features: "414"
# features: "4140"
# features: "4141"
# features: "4142"
# features: "4143"
# features: "4144"
# features: "4145"
# features: "4146"
# features: "4147"
# features: "4148"
# features: "4149"
# features: "415"
# features: "4150"
# features: "4151"
# features: "4152"
# features: "4153"
# features: "4154"
# features: "4155"
# features: "4156"
# features: "4157"
# features: "4158"
# features: "4159"
# features: "416"
# features: "4160"
# features: "4161"
# features: "4162"
# features: "4163"
# features: "4164"
# features: "4165"
# features: "4166"
# features: "4167"
# features: "4168"
# features: "4169"
# features: "417"
# features: "4170"
# features: "4171"
# features: "4172"
# features: "4173"
# features: "4174"
# features: "4175"
# features: "4176"
# features: "4177"
# features: "4178"
# features: "4179"
# features: "418"
# features: "4180"
# features: "4181"
# features: "4182"
# features: "4183"
# features: "4184"
# features: "4185"
# features: "4186"
# features: "4187"
# features: "4188"
# features: "4189"
# features: "419"
# features: "4190"
# features: "4191"
# features: "4192"
# features: "4193"
# features: "4194"
# features: "4195"
# features: "4196"
# features: "4197"
# features: "4198"
# features: "4199"
# features: "42"
# features: "420"
# features: "4200"
# features: "4201"
# features: "4202"
# features: "4203"
# features: "4204"
# features: "4205"
# features: "4206"
# features: "4207"
# features: "4208"
# features: "4209"
# features: "421"
# features: "4210"
# features: "4211"
# features: "4212"
# features: "4213"
# features: "4214"
# features: "4215"
# features: "4216"
# features: "4217"
# features: "4218"
# features: "4219"
# features: "422"
# features: "4220"
# features: "4221"
# features: "4222"
# features: "4223"
# features: "4224"
# features: "4225"
# features: "4226"
# features: "4227"
# features: "4228"
# features: "4229"
# features: "423"
# features: "4230"
# features: "4231"
# features: "4232"
# features: "4233"
# features: "4234"
# features: "4235"
# features: "4236"
# features: "4237"
# features: "4238"
# features: "4239"
# features: "424"
# features: "4240"
# features: "4241"
# features: "4242"
# features: "4243"
# features: "4244"
# features: "4245"
# features: "4246"
# features: "4247"
# features: "4248"
# features: "4249"
# features: "425"
# features: "4250"
# features: "4251"
# features: "4252"
# features: "4253"
# features: "4254"
# features: "4255"
# features: "4256"
# features: "4257"
# features: "4258"
# features: "4259"
# features: "426"
# features: "4260"
# features: "4261"
# features: "4262"
# features: "4263"
# features: "4264"
# features: "4265"
# features: "4266"
# features: "4267"
# features: "4268"
# features: "4269"
# features: "427"
# features: "4270"
# features: "4271"
# features: "4272"
# features: "4273"
# features: "4274"
# features: "4275"
# features: "4276"
# features: "4277"
# features: "4278"
# features: "4279"
# features: "428"
# features: "4280"
# features: "4281"
# features: "4282"
# features: "4283"
# features: "4284"
# features: "4285"
# features: "4286"
# features: "4287"
# features: "4288"
# features: "4289"
# features: "429"
# features: "4290"
# features: "4291"
# features: "4292"
# features: "4293"
# features: "4294"
# features: "4295"
# features: "4296"
# features: "4297"
# features: "4298"
# features: "4299"
# features: "43"
# features: "430"
# features: "4300"
# features: "4301"
# features: "4302"
# features: "4303"
# features: "4304"
# features: "4305"
# features: "4306"
# features: "4307"
# features: "4308"
# features: "4309"
# features: "431"
# features: "4310"
# features: "4311"
# features: "4312"
# features: "4313"
# features: "4314"
# features: "4315"
# features: "4316"
# features: "4317"
# features: "4318"
# features: "4319"
# features: "432"
# features: "4320"
# features: "4321"
# features: "4322"
# features: "4323"
# features: "4324"
# features: "4325"
# features: "4326"
# features: "4327"
# features: "4328"
# features: "4329"
# features: "433"
# features: "4330"
# features: "4331"
# features: "4332"
# features: "4333"
# features: "4334"
# features: "4335"
# features: "4336"
# features: "4337"
# features: "4338"
# features: "4339"
# features: "434"
# features: "4340"
# features: "4341"
# features: "4342"
# features: "4343"
# features: "4344"
# features: "4345"
# features: "4346"
# features: "4347"
# features: "4348"
# features: "4349"
# features: "435"
# features: "4350"
# features: "4351"
# features: "4352"
# features: "4353"
# features: "4354"
# features: "4355"
# features: "4356"
# features: "4357"
# features: "4358"
# features: "4359"
# features: "436"
# features: "4360"
# features: "4361"
# features: "4362"
# features: "4363"
# features: "4364"
# features: "4365"
# features: "4366"
# features: "4367"
# features: "4368"
# features: "4369"
# features: "437"
# features: "4370"
# features: "4371"
# features: "4372"
# features: "4373"
# features: "4374"
# features: "4375"
# features: "4376"
# features: "4377"
# features: "4378"
# features: "4379"
# features: "438"
# features: "4380"
# features: "4381"
# features: "4382"
# features: "4383"
# features: "4384"
# features: "4385"
# features: "4386"
# features: "4387"
# features: "4388"
# features: "4389"
# features: "439"
# features: "4390"
# features: "4391"
# features: "4392"
# features: "4393"
# features: "4394"
# features: "4395"
# features: "4396"
# features: "4397"
# features: "4398"
# features: "4399"
# features: "44"
# features: "440"
# features: "4400"
# features: "4401"
# features: "4402"
# features: "4403"
# features: "4404"
# features: "4405"
# features: "4406"
# features: "4407"
# features: "4408"
# features: "4409"
# features: "441"
# features: "4410"
# features: "4411"
# features: "4412"
# features: "4413"
# features: "4414"
# features: "4415"
# features: "4416"
# features: "4417"
# features: "4418"
# features: "4419"
# features: "442"
# features: "4420"
# features: "4421"
# features: "4422"
# features: "4423"
# features: "4424"
# features: "4425"
# features: "4426"
# features: "4427"
# features: "4428"
# features: "4429"
# features: "443"
# features: "4430"
# features: "4431"
# features: "4432"
# features: "4433"
# features: "4434"
# features: "4435"
# features: "4436"
# features: "4437"
# features: "4438"
# features: "4439"
# features: "444"
# features: "4440"
# features: "4441"
# features: "4442"
# features: "4443"
# features: "4444"
# features: "4445"
# features: "4446"
# features: "4447"
# features: "4448"
# features: "4449"
# features: "445"
# features: "4450"
# features: "4451"
# features: "4452"
# features: "4453"
# features: "4454"
# features: "4455"
# features: "4456"
# features: "4457"
# features: "4458"
# features: "4459"
# features: "446"
# features: "4460"
# features: "4461"
# features: "4462"
# features: "4463"
# features: "4464"
# features: "4465"
# features: "4466"
# features: "4467"
# features: "4468"
# features: "4469"
# features: "447"
# features: "4470"
# features: "4471"
# features: "4472"
# features: "4473"
# features: "4474"
# features: "4475"
# features: "4476"
# features: "4477"
# features: "4478"
# features: "4479"
# features: "448"
# features: "4480"
# features: "4481"
# features: "4482"
# features: "4483"
# features: "4484"
# features: "4485"
# features: "4486"
# features: "4487"
# features: "4488"
# features: "4489"
# features: "449"
# features: "4490"
# features: "4491"
# features: "4492"
# features: "4493"
# features: "4494"
# features: "4495"
# features: "4496"
# features: "4497"
# features: "4498"
# features: "4499"
# features: "45"
# features: "450"
# features: "4500"
# features: "4501"
# features: "4502"
# features: "4503"
# features: "4504"
# features: "4505"
# features: "4506"
# features: "4507"
# features: "4508"
# features: "4509"
# features: "451"
# features: "4510"
# features: "4511"
# features: "4512"
# features: "4513"
# features: "4514"
# features: "4515"
# features: "4516"
# features: "4517"
# features: "4518"
# features: "4519"
# features: "452"
# features: "4520"
# features: "4521"
# features: "4522"
# features: "4523"
# features: "4524"
# features: "4525"
# features: "4526"
# features: "4527"
# features: "4528"
# features: "4529"
# features: "453"
# features: "4530"
# features: "4531"
# features: "4532"
# features: "4533"
# features: "4534"
# features: "4535"
# features: "4536"
# features: "4537"
# features: "4538"
# features: "4539"
# features: "454"
# features: "4540"
# features: "4541"
# features: "4542"
# features: "4543"
# features: "4544"
# features: "4545"
# features: "4546"
# features: "4547"
# features: "4548"
# features: "4549"
# features: "455"
# features: "4550"
# features: "4551"
# features: "4552"
# features: "4553"
# features: "4554"
# features: "4555"
# features: "4556"
# features: "4557"
# features: "4558"
# features: "4559"
# features: "456"
# features: "4560"
# features: "4561"
# features: "4562"
# features: "4563"
# features: "4564"
# features: "4565"
# features: "4566"
# features: "4567"
# features: "4568"
# features: "4569"
# features: "457"
# features: "4570"
# features: "4571"
# features: "4572"
# features: "4573"
# features: "4574"
# features: "4575"
# features: "4576"
# features: "4577"
# features: "4578"
# features: "4579"
# features: "458"
# features: "4580"
# features: "4581"
# features: "4582"
# features: "4583"
# features: "4584"
# features: "4585"
# features: "4586"
# features: "4587"
# features: "4588"
# features: "4589"
# features: "459"
# features: "4590"
# features: "4591"
# features: "4592"
# features: "4593"
# features: "4594"
# features: "4595"
# features: "4596"
# features: "4597"
# features: "4598"
# features: "4599"
# features: "46"
# features: "460"
# features: "4600"
# features: "4601"
# features: "4602"
# features: "4603"
# features: "4604"
# features: "4605"
# features: "4606"
# features: "4607"
# features: "4608"
# features: "4609"
# features: "461"
# features: "4610"
# features: "4611"
# features: "4612"
# features: "4613"
# features: "4614"
# features: "4615"
# features: "4616"
# features: "4617"
# features: "4618"
# features: "4619"
# features: "462"
# features: "4620"
# features: "4621"
# features: "4622"
# features: "4623"
# features: "4624"
# features: "4625"
# features: "4626"
# features: "4627"
# features: "4628"
# features: "4629"
# features: "463"
# features: "4630"
# features: "4631"
# features: "4632"
# features: "4633"
# features: "4634"
# features: "4635"
# features: "4636"
# features: "4637"
# features: "4638"
# features: "4639"
# features: "464"
# features: "4640"
# features: "4641"
# features: "4642"
# features: "4643"
# features: "4644"
# features: "4645"
# features: "4646"
# features: "4647"
# features: "4648"
# features: "4649"
# features: "465"
# features: "4650"
# features: "4651"
# features: "4652"
# features: "4653"
# features: "4654"
# features: "4655"
# features: "4656"
# features: "4657"
# features: "4658"
# features: "4659"
# features: "466"
# features: "4660"
# features: "4661"
# features: "4662"
# features: "4663"
# features: "4664"
# features: "4665"
# features: "4666"
# features: "4667"
# features: "4668"
# features: "4669"
# features: "467"
# features: "4670"
# features: "4671"
# features: "4672"
# features: "4673"
# features: "4674"
# features: "4675"
# features: "4676"
# features: "4677"
# features: "4678"
# features: "4679"
# features: "468"
# features: "4680"
# features: "4681"
# features: "4682"
# features: "4683"
# features: "4684"
# features: "4685"
# features: "4686"
# features: "4687"
# features: "4688"
# features: "4689"
# features: "469"
# features: "4690"
# features: "4691"
# features: "4692"
# features: "4693"
# features: "4694"
# features: "4695"
# features: "4696"
# features: "4697"
# features: "4698"
# features: "4699"
# features: "47"
# features: "470"
# features: "4700"
# features: "4701"
# features: "4702"
# features: "4703"
# features: "4704"
# features: "4705"
# features: "4706"
# features: "4707"
# features: "4708"
# features: "4709"
# features: "471"
# features: "4710"
# features: "4711"
# features: "4712"
# features: "4713"
# features: "4714"
# features: "4715"
# features: "4716"
# features: "4717"
# features: "4718"
# features: "4719"
# features: "472"
# features: "4720"
# features: "4721"
# features: "4722"
# features: "4723"
# features: "4724"
# features: "4725"
# features: "4726"
# features: "4727"
# features: "4728"
# features: "4729"
# features: "473"
# features: "4730"
# features: "4731"
# features: "4732"
# features: "4733"
# features: "4734"
# features: "4735"
# features: "4736"
# features: "4737"
# features: "4738"
# features: "4739"
# features: "474"
# features: "4740"
# features: "4741"
# features: "4742"
# features: "4743"
# features: "4744"
# features: "4745"
# features: "4746"
# features: "4747"
# features: "4748"
# features: "4749"
# features: "475"
# features: "4750"
# features: "4751"
# features: "4752"
# features: "4753"
# features: "4754"
# features: "4755"
# features: "4756"
# features: "4757"
# features: "4758"
# features: "4759"
# features: "476"
# features: "4760"
# features: "4761"
# features: "4762"
# features: "4763"
# features: "4764"
# features: "4765"
# features: "4766"
# features: "4767"
# features: "4768"
# features: "4769"
# features: "477"
# features: "4770"
# features: "4771"
# features: "4772"
# features: "4773"
# features: "4774"
# features: "4775"
# features: "4776"
# features: "4777"
# features: "4778"
# features: "4779"
# features: "478"
# features: "4780"
# features: "4781"
# features: "4782"
# features: "4783"
# features: "4784"
# features: "4785"
# features: "4786"
# features: "4787"
# features: "4788"
# features: "4789"
# features: "479"
# features: "4790"
# features: "4791"
# features: "4792"
# features: "4793"
# features: "4794"
# features: "4795"
# features: "4796"
# features: "4797"
# features: "4798"
# features: "4799"
# features: "48"
# features: "480"
# features: "4800"
# features: "4801"
# features: "4802"
# features: "4803"
# features: "4804"
# features: "4805"
# features: "4806"
# features: "4807"
# features: "4808"
# features: "4809"
# features: "481"
# features: "4810"
# features: "4811"
# features: "4812"
# features: "4813"
# features: "4814"
# features: "4815"
# features: "4816"
# features: "4817"
# features: "4818"
# features: "4819"
# features: "482"
# features: "4820"
# features: "4821"
# features: "4822"
# features: "4823"
# features: "4824"
# features: "4825"
# features: "4826"
# features: "4827"
# features: "4828"
# features: "4829"
# features: "483"
# features: "4830"
# features: "4831"
# features: "4832"
# features: "4833"
# features: "4834"
# features: "4835"
# features: "4836"
# features: "4837"
# features: "4838"
# features: "4839"
# features: "484"
# features: "4840"
# features: "4841"
# features: "4842"
# features: "4843"
# features: "4844"
# features: "4845"
# features: "4846"
# features: "4847"
# features: "4848"
# features: "4849"
# features: "485"
# features: "4850"
# features: "4851"
# features: "4852"
# features: "4853"
# features: "4854"
# features: "4855"
# features: "4856"
# features: "4857"
# features: "4858"
# features: "4859"
# features: "486"
# features: "4860"
# features: "4861"
# features: "4862"
# features: "4863"
# features: "4864"
# features: "4865"
# features: "4866"
# features: "4867"
# features: "4868"
# features: "4869"
# features: "487"
# features: "4870"
# features: "4871"
# features: "4872"
# features: "4873"
# features: "4874"
# features: "4875"
# features: "4876"
# features: "4877"
# features: "4878"
# features: "4879"
# features: "488"
# features: "4880"
# features: "4881"
# features: "4882"
# features: "4883"
# features: "4884"
# features: "4885"
# features: "4886"
# features: "4887"
# features: "4888"
# features: "4889"
# features: "489"
# features: "4890"
# features: "4891"
# features: "4892"
# features: "4893"
# features: "4894"
# features: "4895"
# features: "4896"
# features: "4897"
# features: "4898"
# features: "4899"
# features: "49"
# features: "490"
# features: "4900"
# features: "4901"
# features: "4902"
# features: "4903"
# features: "4904"
# features: "4905"
# features: "4906"
# features: "4907"
# features: "4908"
# features: "4909"
# features: "491"
# features: "4910"
# features: "4911"
# features: "4912"
# features: "4913"
# features: "4914"
# features: "4915"
# features: "4916"
# features: "4917"
# features: "4918"
# features: "4919"
# features: "492"
# features: "4920"
# features: "4921"
# features: "4922"
# features: "4923"
# features: "4924"
# features: "4925"
# features: "4926"
# features: "4927"
# features: "4928"
# features: "4929"
# features: "493"
# features: "4930"
# features: "4931"
# features: "4932"
# features: "4933"
# features: "4934"
# features: "4935"
# features: "4936"
# features: "4937"
# features: "4938"
# features: "4939"
# features: "494"
# features: "4940"
# features: "4941"
# features: "4942"
# features: "4943"
# features: "4944"
# features: "4945"
# features: "4946"
# features: "4947"
# features: "4948"
# features: "4949"
# features: "495"
# features: "4950"
# features: "4951"
# features: "4952"
# features: "4953"
# features: "4954"
# features: "4955"
# features: "4956"
# features: "4957"
# features: "4958"
# features: "4959"
# features: "496"
# features: "4960"
# features: "4961"
# features: "4962"
# features: "4963"
# features: "4964"
# features: "4965"
# features: "4966"
# features: "4967"
# features: "4968"
# features: "4969"
# features: "497"
# features: "4970"
# features: "4971"
# features: "4972"
# features: "4973"
# features: "4974"
# features: "4975"
# features: "4976"
# features: "4977"
# features: "4978"
# features: "4979"
# features: "498"
# features: "4980"
# features: "4981"
# features: "4982"
# features: "4983"
# features: "4984"
# features: "4985"
# features: "4986"
# features: "4987"
# features: "4988"
# features: "4989"
# features: "499"
# features: "4990"
# features: "4991"
# features: "4992"
# features: "4993"
# features: "4994"
# features: "4995"
# features: "4996"
# features: "4997"
# features: "4998"
# features: "4999"
# features: "5"
# features: "50"
# features: "500"
# features: "5000"
# features: "5001"
# features: "5002"
# features: "5003"
# features: "5004"
# features: "5005"
# features: "5006"
# features: "5007"
# features: "5008"
# features: "5009"
# features: "501"
# features: "5010"
# features: "5011"
# features: "5012"
# features: "5013"
# features: "5014"
# features: "5015"
# features: "5016"
# features: "5017"
# features: "5018"
# features: "5019"
# features: "502"
# features: "5020"
# features: "5021"
# features: "5022"
# features: "5023"
# features: "5024"
# features: "5025"
# features: "5026"
# features: "5027"
# features: "5028"
# features: "5029"
# features: "503"
# features: "5030"
# features: "5031"
# features: "5032"
# features: "5033"
# features: "5034"
# features: "5035"
# features: "5036"
# features: "5037"
# features: "5038"
# features: "5039"
# features: "504"
# features: "5040"
# features: "5041"
# features: "5042"
# features: "5043"
# features: "5044"
# features: "5045"
# features: "5046"
# features: "5047"
# features: "5048"
# features: "5049"
# features: "505"
# features: "5050"
# features: "5051"
# features: "5052"
# features: "5053"
# features: "5054"
# features: "5055"
# features: "5056"
# features: "5057"
# features: "5058"
# features: "5059"
# features: "506"
# features: "5060"
# features: "5061"
# features: "5062"
# features: "5063"
# features: "5064"
# features: "5065"
# features: "5066"
# features: "5067"
# features: "5068"
# features: "5069"
# features: "507"
# features: "5070"
# features: "5071"
# features: "5072"
# features: "5073"
# features: "5074"
# features: "5075"
# features: "5076"
# features: "5077"
# features: "5078"
# features: "5079"
# features: "508"
# features: "5080"
# features: "5081"
# features: "5082"
# features: "5083"
# features: "5084"
# features: "5085"
# features: "5086"
# features: "5087"
# features: "5088"
# features: "5089"
# features: "509"
# features: "5090"
# features: "5091"
# features: "5092"
# features: "5093"
# features: "5094"
# features: "5095"
# features: "5096"
# features: "5097"
# features: "5098"
# features: "5099"
# features: "51"
# features: "510"
# features: "5100"
# features: "5101"
# features: "5102"
# features: "5103"
# features: "5104"
# features: "5105"
# features: "5106"
# features: "5107"
# features: "5108"
# features: "5109"
# features: "511"
# features: "5110"
# features: "5111"
# features: "5112"
# features: "5113"
# features: "5114"
# features: "5115"
# features: "5116"
# features: "5117"
# features: "5118"
# features: "5119"
# features: "512"
# features: "5120"
# features: "5121"
# features: "5122"
# features: "5123"
# features: "5124"
# features: "5125"
# features: "5126"
# features: "5127"
# features: "5128"
# features: "5129"
# features: "513"
# features: "5130"
# features: "5131"
# features: "5132"
# features: "5133"
# features: "5134"
# features: "5135"
# features: "5136"
# features: "5137"
# features: "5138"
# features: "5139"
# features: "514"
# features: "5140"
# features: "5141"
# features: "5142"
# features: "5143"
# features: "5144"
# features: "5145"
# features: "5146"
# features: "5147"
# features: "5148"
# features: "5149"
# features: "515"
# features: "5150"
# features: "5151"
# features: "5152"
# features: "5153"
# features: "5154"
# features: "5155"
# features: "5156"
# features: "5157"
# features: "5158"
# features: "5159"
# features: "516"
# features: "5160"
# features: "5161"
# features: "5162"
# features: "5163"
# features: "5164"
# features: "5165"
# features: "5166"
# features: "5167"
# features: "5168"
# features: "5169"
# features: "517"
# features: "5170"
# features: "5171"
# features: "5172"
# features: "5173"
# features: "5174"
# features: "5175"
# features: "5176"
# features: "5177"
# features: "5178"
# features: "5179"
# features: "518"
# features: "5180"
# features: "5181"
# features: "5182"
# features: "5183"
# features: "5184"
# features: "5185"
# features: "5186"
# features: "5187"
# features: "5188"
# features: "5189"
# features: "519"
# features: "5190"
# features: "5191"
# features: "5192"
# features: "5193"
# features: "5194"
# features: "5195"
# features: "5196"
# features: "5197"
# features: "5198"
# features: "5199"
# features: "52"
# features: "520"
# features: "5200"
# features: "5201"
# features: "5202"
# features: "5203"
# features: "5204"
# features: "5205"
# features: "5206"
# features: "5207"
# features: "5208"
# features: "5209"
# features: "521"
# features: "5210"
# features: "5211"
# features: "5212"
# features: "5213"
# features: "5214"
# features: "5215"
# features: "5216"
# features: "5217"
# features: "5218"
# features: "5219"
# features: "522"
# features: "5220"
# features: "5221"
# features: "5222"
# features: "5223"
# features: "5224"
# features: "5225"
# features: "5226"
# features: "5227"
# features: "5228"
# features: "5229"
# features: "523"
# features: "5230"
# features: "5231"
# features: "5232"
# features: "5233"
# features: "5234"
# features: "5235"
# features: "5236"
# features: "5237"
# features: "5238"
# features: "5239"
# features: "524"
# features: "5240"
# features: "5241"
# features: "5242"
# features: "5243"
# features: "5244"
# features: "5245"
# features: "5246"
# features: "5247"
# features: "5248"
# features: "5249"
# features: "525"
# features: "5250"
# features: "5251"
# features: "5252"
# features: "5253"
# features: "5254"
# features: "5255"
# features: "5256"
# features: "5257"
# features: "5258"
# features: "5259"
# features: "526"
# features: "5260"
# features: "5261"
# features: "5262"
# features: "5263"
# features: "5264"
# features: "5265"
# features: "5266"
# features: "5267"
# features: "5268"
# features: "5269"
# features: "527"
# features: "5270"
# features: "5271"
# features: "5272"
# features: "5273"
# features: "5274"
# features: "5275"
# features: "5276"
# features: "5277"
# features: "5278"
# features: "5279"
# features: "528"
# features: "5280"
# features: "5281"
# features: "5282"
# features: "5283"
# features: "5284"
# features: "5285"
# features: "5286"
# features: "5287"
# features: "5288"
# features: "5289"
# features: "529"
# features: "5290"
# features: "5291"
# features: "5292"
# features: "5293"
# features: "5294"
# features: "5295"
# features: "5296"
# features: "5297"
# features: "5298"
# features: "5299"
# features: "53"
# features: "530"
# features: "5300"
# features: "5301"
# features: "5302"
# features: "5303"
# features: "5304"
# features: "5305"
# features: "5306"
# features: "5307"
# features: "5308"
# features: "5309"
# features: "531"
# features: "5310"
# features: "5311"
# features: "5312"
# features: "5313"
# features: "5314"
# features: "5315"
# features: "5316"
# features: "5317"
# features: "5318"
# features: "5319"
# features: "532"
# features: "5320"
# features: "5321"
# features: "5322"
# features: "5323"
# features: "5324"
# features: "5325"
# features: "5326"
# features: "5327"
# features: "5328"
# features: "5329"
# features: "533"
# features: "5330"
# features: "5331"
# features: "5332"
# features: "5333"
# features: "5334"
# features: "5335"
# features: "5336"
# features: "5337"
# features: "5338"
# features: "5339"
# features: "534"
# features: "5340"
# features: "5341"
# features: "5342"
# features: "5343"
# features: "5344"
# features: "5345"
# features: "5346"
# features: "5347"
# features: "5348"
# features: "5349"
# features: "535"
# features: "5350"
# features: "5351"
# features: "5352"
# features: "5353"
# features: "5354"
# features: "5355"
# features: "5356"
# features: "5357"
# features: "5358"
# features: "5359"
# features: "536"
# features: "5360"
# features: "5361"
# features: "5362"
# features: "5363"
# features: "5364"
# features: "5365"
# features: "5366"
# features: "5367"
# features: "5368"
# features: "5369"
# features: "537"
# features: "5370"
# features: "5371"
# features: "5372"
# features: "5373"
# features: "5374"
# features: "5375"
# features: "5376"
# features: "5377"
# features: "5378"
# features: "5379"
# features: "538"
# features: "5380"
# features: "5381"
# features: "5382"
# features: "5383"
# features: "5384"
# features: "5385"
# features: "5386"
# features: "5387"
# features: "5388"
# features: "5389"
# features: "539"
# features: "5390"
# features: "5391"
# features: "5392"
# features: "5393"
# features: "5394"
# features: "5395"
# features: "5396"
# features: "5397"
# features: "5398"
# features: "5399"
# features: "54"
# features: "540"
# features: "5400"
# features: "5401"
# features: "5402"
# features: "5403"
# features: "5404"
# features: "5405"
# features: "5406"
# features: "5407"
# features: "5408"
# features: "5409"
# features: "541"
# features: "5410"
# features: "5411"
# features: "5412"
# features: "5413"
# features: "5414"
# features: "5415"
# features: "5416"
# features: "5417"
# features: "5418"
# features: "5419"
# features: "542"
# features: "5420"
# features: "5421"
# features: "5422"
# features: "5423"
# features: "5424"
# features: "5425"
# features: "5426"
# features: "5427"
# features: "5428"
# features: "5429"
# features: "543"
# features: "5430"
# features: "5431"
# features: "5432"
# features: "5433"
# features: "5434"
# features: "5435"
# features: "5436"
# features: "5437"
# features: "5438"
# features: "5439"
# features: "544"
# features: "5440"
# features: "5441"
# features: "5442"
# features: "5443"
# features: "5444"
# features: "5445"
# features: "5446"
# features: "5447"
# features: "5448"
# features: "5449"
# features: "545"
# features: "5450"
# features: "5451"
# features: "5452"
# features: "5453"
# features: "5454"
# features: "5455"
# features: "5456"
# features: "5457"
# features: "5458"
# features: "5459"
# features: "546"
# features: "5460"
# features: "5461"
# features: "5462"
# features: "5463"
# features: "5464"
# features: "5465"
# features: "5466"
# features: "5467"
# features: "5468"
# features: "5469"
# features: "547"
# features: "5470"
# features: "5471"
# features: "5472"
# features: "5473"
# features: "5474"
# features: "5475"
# features: "5476"
# features: "5477"
# features: "5478"
# features: "5479"
# features: "548"
# features: "5480"
# features: "5481"
# features: "5482"
# features: "5483"
# features: "5484"
# features: "5485"
# features: "5486"
# features: "5487"
# features: "5488"
# features: "5489"
# features: "549"
# features: "5490"
# features: "5491"
# features: "5492"
# features: "5493"
# features: "5494"
# features: "5495"
# features: "5496"
# features: "5497"
# features: "5498"
# features: "5499"
# features: "55"
# features: "550"
# features: "5500"
# features: "5501"
# features: "5502"
# features: "5503"
# features: "5504"
# features: "5505"
# features: "5506"
# features: "5507"
# features: "5508"
# features: "5509"
# features: "551"
# features: "5510"
# features: "5511"
# features: "5512"
# features: "5513"
# features: "5514"
# features: "5515"
# features: "5516"
# features: "5517"
# features: "5518"
# features: "5519"
# features: "552"
# features: "5520"
# features: "5521"
# features: "5522"
# features: "5523"
# features: "5524"
# features: "5525"
# features: "5526"
# features: "5527"
# features: "5528"
# features: "5529"
# features: "553"
# features: "5530"
# features: "5531"
# features: "5532"
# features: "5533"
# features: "5534"
# features: "5535"
# features: "5536"
# features: "5537"
# features: "5538"
# features: "5539"
# features: "554"
# features: "5540"
# features: "5541"
# features: "5542"
# features: "5543"
# features: "5544"
# features: "5545"
# features: "5546"
# features: "5547"
# features: "5548"
# features: "5549"
# features: "555"
# features: "5550"
# features: "5551"
# features: "5552"
# features: "5553"
# features: "5554"
# features: "5555"
# features: "5556"
# features: "5557"
# features: "5558"
# features: "5559"
# features: "556"
# features: "5560"
# features: "5561"
# features: "5562"
# features: "5563"
# features: "5564"
# features: "5565"
# features: "5566"
# features: "5567"
# features: "5568"
# features: "5569"
# features: "557"
# features: "5570"
# features: "5571"
# features: "5572"
# features: "5573"
# features: "5574"
# features: "5575"
# features: "5576"
# features: "5577"
# features: "5578"
# features: "5579"
# features: "558"
# features: "5580"
# features: "5581"
# features: "5582"
# features: "5583"
# features: "5584"
# features: "5585"
# features: "5586"
# features: "5587"
# features: "5588"
# features: "5589"
# features: "559"
# features: "5590"
# features: "5591"
# features: "5592"
# features: "5593"
# features: "5594"
# features: "5595"
# features: "5596"
# features: "5597"
# features: "5598"
# features: "5599"
# features: "56"
# features: "560"
# features: "5600"
# features: "5601"
# features: "5602"
# features: "5603"
# features: "5604"
# features: "5605"
# features: "5606"
# features: "5607"
# features: "5608"
# features: "5609"
# features: "561"
# features: "5610"
# features: "5611"
# features: "5612"
# features: "5613"
# features: "5614"
# features: "5615"
# features: "5616"
# features: "5617"
# features: "5618"
# features: "5619"
# features: "562"
# features: "5620"
# features: "5621"
# features: "5622"
# features: "5623"
# features: "5624"
# features: "5625"
# features: "5626"
# features: "5627"
# features: "5628"
# features: "5629"
# features: "563"
# features: "5630"
# features: "5631"
# features: "5632"
# features: "5633"
# features: "5634"
# features: "5635"
# features: "5636"
# features: "5637"
# features: "5638"
# features: "5639"
# features: "564"
# features: "5640"
# features: "5641"
# features: "5642"
# features: "5643"
# features: "5644"
# features: "5645"
# features: "5646"
# features: "5647"
# features: "5648"
# features: "5649"
# features: "565"
# features: "5650"
# features: "5651"
# features: "5652"
# features: "5653"
# features: "5654"
# features: "5655"
# features: "5656"
# features: "5657"
# features: "5658"
# features: "5659"
# features: "566"
# features: "5660"
# features: "5661"
# features: "5662"
# features: "5663"
# features: "5664"
# features: "5665"
# features: "5666"
# features: "5667"
# features: "5668"
# features: "5669"
# features: "567"
# features: "5670"
# features: "5671"
# features: "5672"
# features: "5673"
# features: "5674"
# features: "5675"
# features: "5676"
# features: "5677"
# features: "5678"
# features: "5679"
# features: "568"
# features: "5680"
# features: "5681"
# features: "5682"
# features: "5683"
# features: "5684"
# features: "5685"
# features: "5686"
# features: "5687"
# features: "5688"
# features: "5689"
# ...
# features: "7317"
# features: "7318"
# features: "7319"
# features: "732"
# features: "7320"
# features: "7321"
# features: "7322"
# features: "7323"
# features: "7324"
# features: "7325"
# features: "7326"
# features: "7327"
# features: "7328"
# features: "7329"
# features: "733"
# features: "7330"
# features: "7331"
# features: "7332"
# features: "7333"
# features: "7334"
# features: "7335"
# features: "7336"
# features: "7337"
# features: "7338"
# features: "7339"
# features: "734"
# features: "7340"
# features: "7341"
# features: "7342"
# features: "7343"
# features: "7344"
# features: "7345"
# features: "7346"
# features: "7347"
# features: "7348"
# features: "7349"
# features: "735"
# features: "7350"
# features: "7351"
# features: "7352"
# features: "7353"
# features: "7354"
# features: "7355"
# features: "7356"
# features: "7357"
# features: "7358"
# features: "7359"
# features: "736"
# features: "7360"
# features: "7361"
# features: "7362"
# features: "7363"
# features: "7364"
# features: "7365"
# features: "7366"
# features: "7367"
# features: "7368"
# features: "7369"
# features: "737"
# features: "7370"
# features: "7371"
# features: "7372"
# features: "7373"
# features: "7374"
# features: "7375"
# features: "7376"
# features: "7377"
# features: "7378"
# features: "7379"
# features: "738"
# features: "7380"
# features: "7381"
# features: "7382"
# features: "7383"
# features: "7384"
# features: "7385"
# features: "7386"
# features: "7387"
# features: "7388"
# features: "7389"
# features: "739"
# features: "7390"
# features: "7391"
# features: "7392"
# features: "7393"
# features: "7394"
# features: "7395"
# features: "7396"
# features: "7397"
# features: "7398"
# features: "7399"
# features: "74"
# features: "740"
# features: "7400"
# features: "7401"
# features: "7402"
# features: "7403"
# features: "7404"
# features: "7405"
# features: "7406"
# features: "7407"
# features: "7408"
# features: "7409"
# features: "741"
# features: "7410"
# features: "7411"
# features: "7412"
# features: "7413"
# features: "7414"
# features: "7415"
# features: "7416"
# features: "7417"
# features: "7418"
# features: "7419"
# features: "742"
# features: "7420"
# features: "7421"
# features: "7422"
# features: "7423"
# features: "7424"
# features: "7425"
# features: "7426"
# features: "7427"
# features: "7428"
# features: "7429"
# features: "743"
# features: "7430"
# features: "7431"
# features: "7432"
# features: "7433"
# features: "7434"
# features: "7435"
# features: "7436"
# features: "7437"
# features: "7438"
# features: "7439"
# features: "744"
# features: "7440"
# features: "7441"
# features: "7442"
# features: "7443"
# features: "7444"
# features: "7445"
# features: "7446"
# features: "7447"
# features: "7448"
# features: "7449"
# features: "745"
# features: "7450"
# features: "7451"
# features: "7452"
# features: "7453"
# features: "7454"
# features: "7455"
# features: "7456"
# features: "7457"
# features: "7458"
# features: "7459"
# features: "746"
# features: "7460"
# features: "7461"
# features: "7462"
# features: "7463"
# features: "7464"
# features: "7465"
# features: "7466"
# features: "7467"
# features: "7468"
# features: "7469"
# features: "747"
# features: "7470"
# features: "7471"
# features: "7472"
# features: "7473"
# features: "7474"
# features: "7475"
# features: "7476"
# features: "7477"
# features: "7478"
# features: "7479"
# features: "748"
# features: "7480"
# features: "7481"
# features: "7482"
# features: "7483"
# features: "7484"
# features: "7485"
# features: "7486"
# features: "7487"
# features: "7488"
# features: "7489"
# features: "749"
# features: "7490"
# features: "7491"
# features: "7492"
# features: "7493"
# features: "7494"
# features: "7495"
# features: "7496"
# features: "7497"
# features: "7498"
# features: "7499"
# features: "75"
# features: "750"
# features: "7500"
# features: "7501"
# features: "7502"
# features: "7503"
# features: "7504"
# features: "7505"
# features: "7506"
# features: "7507"
# features: "7508"
# features: "7509"
# features: "751"
# features: "7510"
# features: "7511"
# features: "7512"
# features: "7513"
# features: "7514"
# features: "7515"
# features: "7516"
# features: "7517"
# features: "7518"
# features: "7519"
# features: "752"
# features: "7520"
# features: "7521"
# features: "7522"
# features: "7523"
# features: "7524"
# features: "7525"
# features: "7526"
# features: "7527"
# features: "7528"
# features: "7529"
# features: "753"
# features: "7530"
# features: "7531"
# features: "7532"
# features: "7533"
# features: "7534"
# features: "7535"
# features: "7536"
# features: "7537"
# features: "7538"
# features: "7539"
# features: "754"
# features: "7540"
# features: "7541"
# features: "7542"
# features: "7543"
# features: "7544"
# features: "7545"
# features: "7546"
# features: "7547"
# features: "7548"
# features: "7549"
# features: "755"
# features: "7550"
# features: "7551"
# features: "7552"
# features: "7553"
# features: "7554"
# features: "7555"
# features: "7556"
# features: "7557"
# features: "7558"
# features: "7559"
# features: "756"
# features: "7560"
# features: "7561"
# features: "7562"
# features: "7563"
# features: "7564"
# features: "7565"
# features: "7566"
# features: "7567"
# features: "7568"
# features: "7569"
# features: "757"
# features: "7570"
# features: "7571"
# features: "7572"
# features: "7573"
# features: "7574"
# features: "7575"
# features: "7576"
# features: "7577"
# features: "7578"
# features: "7579"
# features: "758"
# features: "7580"
# features: "7581"
# features: "7582"
# features: "7583"
# features: "7584"
# features: "7585"
# features: "7586"
# features: "7587"
# features: "7588"
# features: "7589"
# features: "759"
# features: "7590"
# features: "7591"
# features: "7592"
# features: "7593"
# features: "7594"
# features: "7595"
# features: "7596"
# features: "7597"
# features: "7598"
# features: "7599"
# features: "76"
# features: "760"
# features: "7600"
# features: "7601"
# features: "7602"
# features: "7603"
# features: "7604"
# features: "7605"
# features: "7606"
# features: "7607"
# features: "7608"
# features: "7609"
# features: "761"
# features: "7610"
# features: "7611"
# features: "7612"
# features: "7613"
# features: "7614"
# features: "7615"
# features: "7616"
# features: "7617"
# features: "7618"
# features: "7619"
# features: "762"
# features: "7620"
# features: "7621"
# features: "7622"
# features: "7623"
# features: "7624"
# features: "7625"
# features: "7626"
# features: "7627"
# features: "7628"
# features: "7629"
# features: "763"
# features: "7630"
# features: "7631"
# features: "7632"
# features: "7633"
# features: "7634"
# features: "7635"
# features: "7636"
# features: "7637"
# features: "7638"
# features: "7639"
# features: "764"
# features: "7640"
# features: "7641"
# features: "7642"
# features: "7643"
# features: "7644"
# features: "7645"
# features: "7646"
# features: "7647"
# features: "7648"
# features: "7649"
# features: "765"
# features: "7650"
# features: "7651"
# features: "7652"
# features: "7653"
# features: "7654"
# features: "7655"
# features: "7656"
# features: "7657"
# features: "7658"
# features: "7659"
# features: "766"
# features: "7660"
# features: "7661"
# features: "7662"
# features: "7663"
# features: "7664"
# features: "7665"
# features: "7666"
# features: "7667"
# features: "7668"
# features: "7669"
# features: "767"
# features: "7670"
# features: "7671"
# features: "7672"
# features: "7673"
# features: "7674"
# features: "7675"
# features: "7676"
# features: "7677"
# features: "7678"
# features: "7679"
# features: "768"
# features: "7680"
# features: "7681"
# features: "7682"
# features: "7683"
# features: "7684"
# features: "7685"
# features: "7686"
# features: "7687"
# features: "7688"
# features: "7689"
# features: "769"
# features: "7690"
# features: "7691"
# features: "7692"
# features: "7693"
# features: "7694"
# features: "7695"
# features: "7696"
# features: "7697"
# features: "7698"
# features: "7699"
# features: "77"
# features: "770"
# features: "7700"
# features: "7701"
# features: "7702"
# features: "7703"
# features: "7704"
# features: "7705"
# features: "7706"
# features: "7707"
# features: "7708"
# features: "7709"
# features: "771"
# features: "7710"
# features: "7711"
# features: "7712"
# features: "7713"
# features: "7714"
# features: "7715"
# features: "7716"
# features: "7717"
# features: "7718"
# features: "7719"
# features: "772"
# features: "7720"
# features: "7721"
# features: "7722"
# features: "7723"
# features: "7724"
# features: "7725"
# features: "7726"
# features: "7727"
# features: "7728"
# features: "7729"
# features: "773"
# features: "7730"
# features: "7731"
# features: "7732"
# features: "7733"
# features: "7734"
# features: "7735"
# features: "7736"
# features: "7737"
# features: "7738"
# features: "7739"
# features: "774"
# features: "7740"
# features: "7741"
# features: "7742"
# features: "7743"
# features: "7744"
# features: "7745"
# features: "7746"
# features: "7747"
# features: "7748"
# features: "7749"
# features: "775"
# features: "7750"
# features: "7751"
# features: "7752"
# features: "7753"
# features: "7754"
# features: "7755"
# features: "7756"
# features: "7757"
# features: "7758"
# features: "7759"
# features: "776"
# features: "7760"
# features: "7761"
# features: "7762"
# features: "7763"
# features: "7764"
# features: "7765"
# features: "7766"
# features: "7767"
# features: "7768"
# features: "7769"
# features: "777"
# features: "7770"
# features: "7771"
# features: "7772"
# features: "7773"
# features: "7774"
# features: "7775"
# features: "7776"
# features: "7777"
# features: "7778"
# features: "7779"
# features: "778"
# features: "7780"
# features: "7781"
# features: "7782"
# features: "7783"
# features: "7784"
# features: "7785"
# features: "7786"
# features: "7787"
# features: "7788"
# features: "7789"
# features: "779"
# features: "7790"
# features: "7791"
# features: "7792"
# features: "7793"
# features: "7794"
# features: "7795"
# features: "7796"
# features: "7797"
# features: "7798"
# features: "7799"
# features: "78"
# features: "780"
# features: "7800"
# features: "7801"
# features: "7802"
# features: "7803"
# features: "7804"
# features: "7805"
# features: "7806"
# features: "7807"
# features: "7808"
# features: "781"
# features: "782"
# features: "783"
# features: "784"
# features: "785"
# features: "786"
# features: "787"
# features: "788"
# features: "789"
# features: "79"
# features: "790"
# features: "791"
# features: "792"
# features: "793"
# features: "794"
# features: "795"
# features: "796"
# features: "797"
# features: "798"
# features: "799"
# features: "8"
# features: "80"
# features: "800"
# features: "801"
# features: "802"
# features: "803"
# features: "804"
# features: "805"
# features: "806"
# features: "807"
# features: "808"
# features: "809"
# features: "81"
# features: "810"
# features: "811"
# features: "812"
# features: "813"
# features: "814"
# features: "815"
# features: "816"
# features: "817"
# features: "818"
# features: "819"
# features: "82"
# features: "820"
# features: "821"
# features: "822"
# features: "823"
# features: "824"
# features: "825"
# features: "826"
# features: "827"
# features: "828"
# features: "829"
# features: "83"
# features: "830"
# features: "831"
# features: "832"
# features: "833"
# features: "834"
# features: "835"
# features: "836"
# features: "837"
# features: "838"
# features: "839"
# features: "84"
# features: "840"
# features: "841"
# features: "842"
# features: "843"
# features: "844"
# features: "845"
# features: "846"
# features: "847"
# features: "848"
# features: "849"
# features: "85"
# features: "850"
# features: "851"
# features: "852"
# features: "853"
# features: "854"
# features: "855"
# features: "856"
# features: "857"
# features: "858"
# features: "859"
# features: "86"
# features: "860"
# features: "861"
# features: "862"
# features: "863"
# features: "864"
# features: "865"
# features: "866"
# features: "867"
# features: "868"
# features: "869"
# features: "87"
# features: "870"
# features: "871"
# features: "872"
# features: "873"
# features: "874"
# features: "875"
# features: "876"
# features: "877"
# features: "878"
# features: "879"
# features: "88"
# features: "880"
# features: "881"
# features: "882"
# features: "883"
# features: "884"
# features: "885"
# features: "886"
# features: "887"
# features: "888"
# features: "889"
# features: "89"
# features: "890"
# features: "891"
# features: "892"
# features: "893"
# features: "894"
# features: "895"
# features: "896"
# features: "897"
# features: "898"
# features: "899"
# features: "9"
# features: "90"
# features: "900"
# features: "901"
# features: "902"
# features: "903"
# features: "904"
# features: "905"
# features: "906"
# features: "907"
# features: "908"
# features: "909"
# features: "91"
# features: "910"
# features: "911"
# features: "912"
# features: "913"
# features: "914"
# features: "915"
# features: "916"
# features: "917"
# features: "918"
# features: "919"
# features: "92"
# features: "920"
# features: "921"
# features: "922"
# features: "923"
# features: "924"
# features: "925"
# features: "926"
# features: "927"
# features: "928"
# features: "929"
# features: "93"
# features: "930"
# features: "931"
# features: "932"
# features: "933"
# features: "934"
# features: "935"
# features: "936"
# features: "937"
# features: "938"
# features: "939"
# features: "94"
# features: "940"
# features: "941"
# features: "942"
# features: "943"
# features: "944"
# features: "945"
# features: "946"
# features: "947"
# features: "948"
# features: "949"
# features: "95"
# features: "950"
# features: "951"
# features: "952"
# features: "953"
# features: "954"
# features: "955"
# features: "956"
# features: "957"
# features: "958"
# features: "959"
# features: "96"
# features: "960"
# features: "961"
# features: "962"
# features: "963"
# features: "964"
# features: "965"
# features: "966"
# features: "967"
# features: "968"
# features: "969"
# features: "97"
# features: "970"
# features: "971"
# features: "972"
# features: "973"
# features: "974"
# features: "975"
# features: "976"
# features: "977"
# features: "978"
# features: "979"
# features: "98"
# features: "980"
# features: "981"
# features: "982"
# features: "983"
# features: "984"
# features: "985"
# features: "986"
# features: "987"
# features: "988"
# features: "989"
# features: "99"
# features: "990"
# features: "991"
# features: "992"
# features: "993"
# features: "994"
# features: "995"
# features: "996"
# features: "997"
# features: "998"
# features: "999"
# label: "__LABEL"
# task: CLASSIFICATION
# random_seed: 123456
# metadata {
#   framework: "TF Keras"
# }
# [yggdrasil_decision_forests.model.gradient_boosted_trees.proto.gradient_boosted_trees_config] {
#   num_trees: 300
#   decision_tree {
#     max_depth: 6
#     min_examples: 5
#     in_split_min_examples_check: true
#     keep_non_leaf_label_distribution: true
#     num_candidate_attributes: -1
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_best_first_global {
#     }
#     categorical {
#       random {
#       }
#     }
#     sparse_oblique_split {
#       num_projections_exponent: 1
#       normalization: MIN_MAX
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#     uplift {
#       min_examples_in_treatment: 5
#       split_score: KULLBACK_LEIBLER
#     }
#   }
#   shrinkage: 0.1
#   loss: DEFAULT
#   validation_set_ratio: 0.1
#   validation_interval_in_trees: 1
#   early_stopping: VALIDATION_LOSS_INCREASE
#   early_stopping_num_trees_look_ahead: 30
#   l2_regularization: 0
#   lambda_loss: 1
#   mart {
#   }
#   adapt_subsample_for_maximum_training_duration: false
#   l1_regularization: 0
#   use_hessian_gain: false
#   l2_regularization_categorical: 1
#   apply_link_function: true
#   compute_permutation_variable_importance: false
# }
#
# [INFO kernel.cc:849] Deployment config:
# cache_path: "/tmp/tmpfkylzgl2/working_cache"
# num_threads: 40
# try_resume_training: true
#
# [INFO kernel.cc:878] Train model
# [INFO gradient_boosted_trees.cc:406] Default loss set to MULTINOMIAL_LOG_LIKELIHOOD
# [INFO gradient_boosted_trees.cc:1003] Training gradient boosted tree on 52 example(s) and 7808 feature(s).
# [INFO gradient_boosted_trees.cc:1046] 49 examples used for training and 3 examples used for validation
# [INFO gradient_boosted_trees.cc:1428] 	num-trees:1 train-loss:1.737159 train-accuracy:0.918367 valid-loss:2.355946 valid-accuracy:0.333333
# [INFO gradient_boosted_trees.cc:1430] 	num-trees:2 train-loss:1.357962 train-accuracy:0.959184 valid-loss:2.261037 valid-accuracy:0.333333
# [INFO gradient_boosted_trees.cc:1430] 	num-trees:3 train-loss:1.102553 train-accuracy:0.979592 valid-loss:2.075774 valid-accuracy:0.666667
# [INFO gradient_boosted_trees.cc:1430] 	num-trees:4 train-loss:0.900001 train-accuracy:0.979592 valid-loss:1.962993 valid-accuracy:0.666667
# [INFO gradient_boosted_trees.cc:1430] 	num-trees:5 train-loss:0.741467 train-accuracy:1.000000 valid-loss:1.971328 valid-accuracy:0.666667
# [INFO gradient_boosted_trees.cc:1430] 	num-trees:6 train-loss:0.614747 train-accuracy:1.000000 valid-loss:1.960584 valid-accuracy:0.333333
# [INFO gradient_boosted_trees.cc:1430] 	num-trees:7 train-loss:0.512319 train-accuracy:1.000000 valid-loss:1.856987 valid-accuracy:0.333333
# [INFO gradient_boosted_trees.cc:1430] 	num-trees:8 train-loss:0.427805 train-accuracy:1.000000 valid-loss:1.791342 valid-accuracy:0.666667

# %%
# NOTE: There was internal validation above with some percent of the dataset.
gbt_classification_evaluation = gbt_classification_model.evaluate(testing_classification_ds_tf, return_dict=True)
print()

for name, value in gbt_classification_evaluation.items():
  print(f"{name}: {value:.4f}")
# Out:
# 1/1 [==============================] - 30s 30s/step - loss: 0.0000e+00 - accuracy: 0.5714
#
# loss: 0.0000
# accuracy: 0.5714

# %%
logs = gbt_classification_model.make_inspector().training_logs()

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")

plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")

plt.show()

# %% [markdown]
# #### WIP Code for sklearn

# %%
# First do some data cleaning for TensorFlow

CELL_LABELS = list(CELL_TYPE_TO_FILE_ID.keys())

# TODO: Is there a cleaner approach here?

# Make one-hot encoded training labels, e.g. [0,0,1,0,0,...]
binarizer = sklearn.preprocessing.LabelBinarizer()
labels_binarized = binarizer.fit_transform(CELL_LABELS)
CELL_LABELS_ENCODED = dict(zip(CELL_LABELS, labels_binarized.tolist()))

training_data = []
training_labels = []
testing_data = []
testing_labels = []

for cell_type in CELL_LABELS:
    for k, v in CELL_TYPE_TO_FILE_ID_TRAIN.items():
        for file_id in v:
            training_labels.append(CELL_LABELS_ENCODED[k])
            training_data.append(FILE_ID_TO_CPG_CALLS[file_id]['chr1'])

    for k, v in CELL_TYPE_TO_FILE_ID_TEST.items():
        for file_id in v:
            testing_labels.append(CELL_LABELS_ENCODED[k])
            testing_data.append(FILE_ID_TO_CPG_CALLS[file_id]['chr1'])



svm = sklearn.svm.LinearSVC(random_state=42)
multiclass_classifier = sklearn.multiclass.OneVsRestClassifier(svm, n_jobs=-1) # -1 specifies all threads

# multilabel_classifier = sklearn.multioutput.MultiOutputClassifier(svm, n_jobs=-1) # -1 specifies all threads

# Fit our data
multiclass_classifier = multiclass_classifier.fit(training_data, training_labels)
# multilabel_classifier = multilabel_classifier.fit(training_data, training_labels)

# Get predictions on test data
testing_preds = multiclass_classifier.predict(testing_data)
# testing_preds = multilabel_classifier.predict(testing_data)

# Confusion matricies (how'd we do?)
matrices = sklearn.metrics.multilabel_confusion_matrix(testing_labels, testing_preds)
confusion_matrix(testing_labels, testing_preds))

# Plotting matrices: code
cmd = sklearn.metrics.ConfusionMatrixDisplay(matrices[0], display_labels=np.unique(testing_labels)).plot()
plt.title('Confusion Matrix for label 1 (type)')
plt.show()
cmd = sklearn.metrics.ConfusionMatrixDisplay(matrices[1], display_labels=np.unique(testing_labels)).plot()
plt.title('Confusion Matrix for label 2 (color)')
plt.show()

# %% [markdown]
# ## Evaluate per-cell type fingerprints (individual CpG only)
#
# Since there are so few samples available, evaluation is hard. We can hold out samples for testing, but then we can't train much data. We can train on all data, but then we can't easily tell if we're overfit.
#
# One option for an independent test dataset is an in-house defined mixture of WGBS data. Abul performed a mixture of defined cell types in known proportions, which underwent WGBS. Raw .bam files stored here:
# `/home/ialahi/ialahi_ris/RIS/Active/work/analysis/AllBlueprintBamTogether/Healthy-PBMC-WGBS_bam`
#
# Note that we also called DMRs

# %%
#

# %% [markdown]
# #### Perform gradient-boosted tree multi-label classification (individual CpG only)

# %%
# TODO: Implement GBT, likely from Yggdrasil for TF

# %% [markdown]
# ## Compute Fingerprints -- Read-Level Approach
#
# The above multi-label classifier ignores methylation co-occurrence data. That's because the bs_call data loses some of the information content from the raw reads.
#
# Let's take, for example, two cell types ("Cell A", "Cell B"), with only two CpGs. One can imagine linked methylation states that would be lost in bs_call data.
#
# Cell Type | CpG 1 | CpG 2
# -- | -- | --
# Cell A | X | O
# Cell A | O | X
# Cell B | X | X
# Cell B | O | O
# **bs_call % methylation** | **0.5** | **0.5**
#
# In this example, Cell A's CpGs are mutually exclusive. Whereas in Cell B, they are both on or off. One can imagine these (or even more complex states) that may reflect different subtypes or states of a given cell.
#
# To train a read counting model, need to determine information content/clustering on a per-read basis. We can build a model of per-read information one of two ways:
#
# 1. From a fingerprint matrix of individual reads (above) or,
# 2. Training on raw reads themselves
#
# In approach #1, we can assign a delta score to every individual CpG. Then for each read, we can compute a composite delta score. Unfortunately, this ignores co-occurrence data (two or more CpGs within the same read) -- but if we assume CpGs appear in clusters, we may incidentally capture some co-occurrence.
#
# In approach #2, we train on co-occurence data itself -- that is, train on the individual .bam files.
#
# We can do this via a sliding window across all potential CpGs. Let's define a sliding window (a vector, or rank-1 tensor) equal to the maximum read size, e.g. 150bp. We can then store three states: -1 (not a CpG), 0 (unmethylated), and 1 (methylated).
#
# e.g. [-1 -1 -1 0 -1 -1 1] = 150 bits (max bp of a read)
#
# We can then build these vectors per-sample class, and store them as a tensor, for input to multi-label classification in TensorFlow.

# %% [markdown]
# ### Visualize Performance

# %%
# Sample hierarhical clutering between 2 cell types's CpG on Chr1
import sys
sys.setrecursionlimit(100000) # Ugly hack
import pandas as pd
import seaborn as sns
d = {'c1': FILE_ID_TO_CPG_CALLS['S009W451']['chr1'], 
     'c2': FILE_ID_TO_CPG_CALLS['S008H151']['chr1']}
df = pd.DataFrame(d)
sns.clustermap(df)

# %% [markdown]
# ## Evaluation on Array Data
#
# Lots of data exist from array platforms (e.g. Illumina's Infinium MethylationEPIC). How do we perform using those data?
#
# We can use a matrix to call those, but largely have undefined data (no read level of course) for TensorFlow.
#
# We could make two modes for our model; one of CpG-only (no read-level) fingerprints (presumably less accurate), and one of read-level modeling.
#
# **TODO: Can we train on array data?**

# %% [markdown]
# ### Array vs Blueprint CpG Coverage
#
# High level statistics on overlapping CpGs and coverage differences.

# %%
# How do the CpGs covered by Blueprint compare to 40k and Infinium arrays?

# %% [markdown]
# ## Naïve Fingerprints
#
# Here, we assign each cell a simple fingerprint, treating each CpG as independent.
#
# | Cell Type | CpG-0 | CpG-1 | ... | CpG-N |
# | - | - | - | - | - |
# | CD4+ T cell | O | X | … | … |
# | CD8+ T cell | X | O | … | … |
#
# We then train a gradient boosted decision tree on all available CpG data.

# %% [markdown]
# ## Per-fragment Fingerprints
#
# Here, we assign each cell a fingerprint based not on individual CpGs, but their co-occurrence within a given read from a raw .bam file.
#
# This preserves some state data. e.g. if CpG 1 and CpG 2 are in the same raw read, we note their states, e.g. [0 1].
#
# | Cell Type | [ CpG-0  CpG-1 ] | [ CpG-1  CpG-2 ] | … |
# | - | - | - | - |
# | CD4+ T cell | O | X | … |
# | CD8+ T cell | X | O | … |
#
# Note that we treat this as a ~150 BP rolling window across all possible positions in a 150 BP read (e.g. in a theoretical window of 150 BP, maybe we have 150 GC sites].
#
# TODO: Prune this aggressively to the max number of true called CpGs.

# %% [markdown]
# ## Validation with CyTOF & Internal Truth

# %%
# PBMC Ground Truth Internal Data:

CELL_TYPES = ['T_CD4_naive', 'T_CD4_central_memory', 'T_CD4_effector_memory', 'T_CD8_naive', 'T_CD8_central_memory', 'T_CD8_effector_memory', 'T_CD8_effector_memory_terminal', 'Treg', 'NK_Cell', 'B_Cell_naive', 'B_Cell_memory', 'Plasma_Cell', 'Monocyte', 'Dendritic']
CELL_TYPES_DOTS = [i.replace('_', '.') for i in CELL_TYPES]

## PBMC Mixture --> Ground Truth Percentages
# This maps sample ID to cell type percentage.
PBMC_MIXTURE_TRUTH_BY_CYTOF = {
    '03': [11.42,9.7,9.5,8.9,1.9,8.9,5.4,0.29,8.3,5.92,1.86,0.02,7.54,1.8],
    '14': [7.83,7,6.9,9.96,1.2,10.3,2.8,0.14,12.7,8.44,2.05,0.01,6.65,1.3],
    '24': [15.1,12.2,14.6,8.63,1,7.2,4.5,0.5,7.08,4.92,1.82,0.05,4.12,1.22],
    '31': [10.8,6.9,9.9,8.4,0.8,7.3,4.9,0.12,14.96,5.58,1.99,0.01,5.13,1.25],
    '49': [9.84,8.4,16.6,10.8,1.2,8.2,4.5,0.19,5.49,7.64,2.00,0.01,7.63,1.12],
    '50': [6.2,4.3,5.9,4.04,0.9,3.5,1.8,0.27,9.43,5.66,1.21,0.13,7.14,1.75],
    '51': [10.4,6.1,7.1,5.2,0.4,3,2.1,0.18,14.17,6.50,4.39,0.02,10.5,1.65],
}

# Using "Second Flow" in Abul's. spreadsheet
PBMC_MIXTURE_TRUTH_BY_FLOW_SECOND = {
    '03': [11.55,6.910,7.244,21.07,None,None,None,0.34,4.45,5.70,2.36,None,6.31,1.16],
    '14': [8.56,6.504,3.649,19.89,None,None,None,0.22,5.15,7.23,5.29,None,5.78,0.81],
    '24': [24.75,9.305,5.088,14.26,None,None,None,0.44,5.02,4.76,1.99,None,5.02,1.12],
    '31': [13.5,6.967,4.343,14.77,None,None,None,0.18,4.98,2.23,0.97,None,3.22,0.88],
    '49': [13.68,7.324,8.396,21.25,None,None,None,0.16,3.9,6.73,3.27,None,8.8,0.5],
    '50': [8.56,5.823,2.675,6.12,None,None,None,0.22,6.14,5.76,1.25,None,15.9,0.83],
    '51': [10.61,5.612,3.489,9.11,None,None,None,0.21,10.12,3.83,3.55,None,10.21,1.02],
}

# Using "First Flow" in Abul's. spreadsheet
# One flow experiment with missing samples and no corresponding CyTOF
PBMC_MIXTURE_TRUTH_BY_FLOW_FIRST = {
    '03': [13.95,10.146,4.844,24.16,None,None,None,0.28,6.2,5.25,2.29,None,5.43,0.69],
    '14': [11.51,8.508,3.232,23.85,None,None,None,0.12,11.99,4.73,4.29,None,4.94,0.44],
    '31': [15.48,8.244,3.624,23.93,None,None,None,0.11,14.17,5.58,2.94,None,7.77,0.35],
    '49': [12.74,8.389,6.605,23.95,None,None,None,0.19,3.74,6.96,3.06,None,6.39,0.34],
    '50': [14.53,7.674,1.654,10.83,None,None,None,0.14,6.16,8.99,2.14,None,22.45,0.52],
}

assert all([len(e) == len(CELL_TYPES) for e in PBMC_MIXTURE_TRUTH_BY_CYTOF.values()])
assert all([len(e) == len(CELL_TYPES) for e in PBMC_MIXTURE_TRUTH_BY_FLOW_SECOND.values()])
assert all([len(e) == len(CELL_TYPES) for e in PBMC_MIXTURE_TRUTH_BY_FLOW_FIRST.values()])

# Nested dicts, so you can run:
#  PBMC_TRUTH_DICT_FLOW['03']['Treg']
PBMC_TRUTH_DICT_FLOW = {k:dict.fromkeys(CELL_TYPES_DOTS, v) for k,v in PBMC_MIXTURE_TRUTH_BY_FLOW}
PBMC_TRUTH_DICT_CYTOF = {k:dict.fromkeys(CELL_TYPES_DOTS, v) for k,v in PBMC_MIXTURE_TRUTH_BY_CYTOF}

# %% [markdown]
# ## Attic: Rewrite of Irfan's Pure Fragment Counting Approach

# %%
QUALITY_THRESHOLD=40

### Get our processing files

## Raw .BAM file (~100 MB)
# Original source: /Users/irffanalahi/Research/Research_code/gitignorefolder/MHB_per_read/softreadcounting/testtheidea/veryefficient/CD4allrange_NR_1000000_insilmix41_sorted
! wget --no-config -q --no-clobber -O CD4allrange_NR_1000000_insilmix41_sorted https://wustl.box.com/shared/static/0lil5uevu1vxid2z3bvr8tvehvxwa7ha
bam_file = "CD4allrange_NR_1000000_insilmix41_sorted"
# Index, too
! wget --no-config -q --no-clobber -O CD4allrange_NR_1000000_insilmix41_sorted.bai https://wustl.box.com/shared/static/fegloiy2qi4nnsvhcqp6zlsmt5910fl2.bai

## Delta scores (~50 KB)
# Original source: /Users/irffanalahi/Research/Research_code/gitignorefolder/MHB_per_read/softreadcounting/testtheidea/veryefficient/BL14_all_matrixCin_nr0.4_imputed_rowmean.txt_bg_intesectedwith_CD4DMRofBL14atleast.2SM_g1_CD4_3_g2_others_33_withheader.txt_othermean.txt
#
# This is a tiny ~50kb .bed-like file (tsv) with a header. Scores are the delta scores of each CpG and are FLOATS.
# Header: chrom start cell-line-1 cell-line-2 ...
# Entries: chr1 123   SCORE       SCORE
! wget --no-config -q --no-clobber -O BL14_all_matrixCin_nr0.4_imputed_rowmean.txt_bg_intesectedwith_CD4DMRofBL14atleast.2SM_g1_CD4_3_g2_others_33_withheader.txt_othermean.txt https://wustl.box.com/shared/static/vn8c9ec3dg9hs3gs4s8l1qjyqgeh9hwl.txt
score_matrix_file = "BL14_all_matrixCin_nr0.4_imputed_rowmean.txt_bg_intesectedwith_CD4DMRofBL14atleast.2SM_g1_CD4_3_g2_others_33_withheader.txt_othermean.txt"

# %%
## Load our score matrix
score_matrix_df = pd.read_csv(score_matrix_file, sep='\t', index_col=['chrom','start'])
# Let's remove the _df overhead
# We can just load this as a dict to begin with, but Irfan likes pd.DataFrame better.
#   dict of: ('chr1', 32387132): {'CD4-others': -0.7072564106153847,  'CD8-others': -0.3920769230769232, … }
score_matrix_dict = score_matrix_df.to_dict(orient='index')

# On the plus side, the pd is pretty.
score_matrix_df.head()

# %%
# Big picture: We want to compute CpG scores for each fragment in an input .bam file.
# Each fragment is a read pair, and may have one (or more) CpGs.
# Some key points:
#   * We only count one of the two read pairs; one is a template strand and ignored (this indicated by tag XB or YD)
#   * Each read contains >=1 CpG, we need to count them all (if methylated)

# Start the clock!
start_time = time.time()

DEBUG = False
# DEBUG = True

print(f"Number of CpGs: {len(score_matrix_df)}")
print(f"Number of cell states: {score_matrix_df.shape[1]}")

# Dict mapping from:
#  read_id: delta_scores (List of scores)
# For example:
#  "CD8.HWI-ST537_205:8:1207:20921:3430#19": [0, 1.23, 0.4, …]
#
# The list of scores is the same length as the number of cell states.
# We want a zero-filled list for easy math later.
number_of_cell_states = len(list(score_matrix_dict.values())[0])
read_score_dict = defaultdict(lambda: [0] * number_of_cell_states)

input_bam = pysam.AlignmentFile(bam_file, 'rb')
# Most input .bams are enormous, and our CpG list is relatively small.
# Since we use an indexed .bam, lookups are O(1), so let's randomly access the .bam.

# Loop over all CpG sites from the score matrix
for cpg_location, cpg_scores in score_matrix_dict.items():
    # For each site, grab the pileup (all reads overlapping that exact site)
    # NOTE: A read could be returned by multiple loop iterations (i.e. a ~100bp read could be overlapping multiple CpGs)

    # truncate = return only the *exact* position, not the surrounding overlaps
    # There will only be one turn through this loop; pileup should return only one entry.
    for pileupcolumn in input_bam.pileup(cpg_location[0], start=cpg_location[1], stop=cpg_location[1]+1,
                                         truncate=True, max_depth=10000, min_mapping_quality=QUALITY_THRESHOLD):
        if DEBUG: print(f"Coverage at CpG: {cpg_location} = {pileupcolumn.nsegments}")
        # ?get_query_positions(self)
        # reference_pos = pileupcolumn.reference_pos
        # Loop over all the reads overlapping this exact CpG location
        for pileupread in pileupcolumn.pileups:
            # Skip reads that land on deletions/refskips
            # e.g. This would skip a read that encompasses a CpG, but at the BP of interest, there's a deletion
            if not pileupread.is_del and not pileupread.is_refskip:
                if DEBUG: print(f"\t Raw read: {pileupread.alignment.query_name}")
                # if DEBUG: print(f"\t Raw read: {pileupread}")
                
                assert pileupread.alignment.is_paired is True
                assert pileupread.alignment.is_proper_pair is True
                assert pileupread.alignment.is_qcfail is False
                assert pileupread.alignment.is_unmapped is False
                assert pileupread.alignment.is_duplicate is False
                assert pileupread.alignment.has_tag("XB") or pileupread.alignment.has_tag("YD")
                # assert pileupread.alignment.query_alignment_sequence == pileupread.alignment.query_sequence

                # We have paired-end reads; one half should (the "parent strand") has the methylation data.
                # The other half (the "daughter strand") was the complement created by PCR, which we don't care about.
                # TODO: Let's think about this -- is this correct? 

                bisulfite_parent_strand_is_reverse = None
                if pileupread.alignment.has_tag("XB"): # gem3 / blueprint tag
                    xb_tag = pileupread.alignment.get_tag("XB") # XB:C = Forward / Reference was CG
                    # TODO: Double check one or two of these gem3 tags manually.
                    if xb_tag == "C":
                        bisulfite_parent_strand_is_reverse = False
                    elif xb_tag == "G": # XB:G = Reverse / Reference was GA
                        bisulfite_parent_strand_is_reverse = True
                elif pileupread.alignment.has_tag("YD"): # Biscuit tag
                    yd_tag = pileupread.alignment.get_tag("YD")
                    if yd_tag == "f": # Forward = C→T
                        bisulfite_parent_strand_is_reverse = False
                    elif yd_tag == "r": # Reverse = G→A
                        bisulfite_parent_strand_is_reverse = True

                # Skip if we're not on the bisulfite-converted parent strand.
                if bisulfite_parent_strand_is_reverse != pileupread.alignment.is_reverse:
                    if DEBUG: print(f"\t\t Not on methylated strand, skipping.")
                    continue

                # Ok we're on the same strand as the methylation, let's compare this BP to reference.
                # Let's refresh how bisulfite actually works:
                #   A methylated C will be *unchanged* and read as C (pair G)
                #   An unmethylated C will be *changed* and read as T (pair A)
                query_bp = pileupread.alignment.query_sequence[pileupread.query_position]
                # TODO: Shift this up to the level of the pileupcolum?
                reference_bp = pileupread.alignment.get_reference_sequence()[pileupread.alignment.reference_start - pileupcolumn.reference_pos].upper()
                
                # If query == reference, we're methylated.
                # If query != reference, we're unmethylated.
                if query_bp == reference_bp.upper():
                    # If the read is methylated, add the score to the read_score_dict
                    if DEBUG: print(f"\t\t Methylated, adding scores.")

                    # Add our scores to the read_score_dict
                    # Note: A read might overlap multiple CpG sites, so we modify our dict as we go.
                    # TODO: Ifran negates scores if they're on the negative strand (I think). Why??
                    read_score_dict[pileupread.alignment.query_name] = list(map(add,
                                                                            read_score_dict[pileupread.alignment.query_name],
                                                                            cpg_scores.values()
                                                                            ))
                else:
                    # If the read is unmethylated, we don't need to do anything.
                    if DEBUG: print(f"\t\t Unmethylated, skipping.")


print("Elapsed Time: %.2f seconds" % (time.time() - start_time))

# %%
output_scores = pd.DataFrame.from_dict(read_score_dict, orient='index', columns=score_matrix_df.columns)
output_scores.to_csv(bam_file + "_scores.tsv", sep="\t")
print(f"Number of reads with scores: {len(output_scores)}")

# %% [markdown]
# Old cache decorator

# %%
# TODO: Finalize this decorator (not fully working/tested yet)

# Note, we can't just use the @cache decorator (from 3.9), since it doesn't expose the raw cache values.
# See, e.g. https://stackoverflow.com/questions/15585493/store-the-cache-to-a-file-functools-lru-cache-in-python-3-2
from functools import wraps
# A caching decorator to load .json (not .pkl) cached objects.
def try_cache(func):
    func.cache = {}
    cache_file = "~/.ltme-cache/" + cache_pretty_name + ".json"
    @wraps(func)
    def wrapper(*args, **kwargs):
        try:
            return func.cache[args]
        except KeyError:
            func.cache[args] = result = fn(*args)
            return result   
    return wrapper
